# %%
import os
import numpy as np
import math
import joblib
import schedule
import pandas as pd
import time as st_time
from datetime import datetime, date, timedelta, time
os.environ['TZ'] ='America/New_York'

#import yfinance as yf

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

from ib_async import *
util.startLoop()

# %% [markdown]
# ### Data Prep for Inferencing

# %%
ib = IB()
ib.connect(port=5901, clientId=0)
# Out:
# API connection failed: ConnectionRefusedError(10061, "Connect call failed ('127.0.0.1', 5901)")
# Make sure API port on TWS/IBG is open
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[26], line 2
#       1 ib = IB()
# ----> 2 ib.connect(port=5901, clientId=0)
#
# File ~\anaconda3\envs\sky\Lib\site-packages\ib_async\ib.py:367, in IB.connect(self, host, port, clientId, timeout, readonly, account, raiseSyncErrors, fetchFields)
#     327 def connect(
#     328     self,
#     329     host: str = "127.0.0.1",
#    (...)    336     fetchFields: StartupFetch = StartupFetchALL,
#     337 ):
#     338     """
#     339     Connect to a running TWS or IB gateway application.
#     340     After the connection is made the client is fully synchronized
#    (...)    365           to the ``fetchFields`` parameter as needed.
#     366     """
# --> 367     return self._run(
#     368         self.connectAsync(
#     369             host,
#     370             port,
#     371             clientId,
#     372             timeout,
#     373             readonly,
#     374             account,
#     375             raiseSyncErrors,
#     376             fetchFields,
#     377         )
#     378     )
#
# File ~\anaconda3\envs\sky\Lib\site-packages\ib_async\ib.py:418, in IB._run(self, *awaitables)
#     417 def _run(self, *awaitables: Awaitable):
# --> 418     return util.run(*awaitables, timeout=self.RequestTimeout)
#
# File ~\anaconda3\envs\sky\Lib\site-packages\ib_async\util.py:360, in run(timeout, *awaitables)
#     358 globalErrorEvent.connect(onError)
#     359 try:
# --> 360     result = loop.run_until_complete(task)
#     361 except asyncio.CancelledError as e:
#     362     raise globalErrorEvent.value() or e
#
# File ~\anaconda3\envs\sky\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\anaconda3\envs\sky\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File ~\anaconda3\envs\sky\Lib\asyncio\tasks.py:306, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     304         result = coro.send(None)
#     305     else:
# --> 306         result = coro.throw(exc)
#     307 except StopIteration as exc:
#     308     if self._must_cancel:
#     309         # Task is cancelled right before coro stops.
#
# File ~\anaconda3\envs\sky\Lib\site-packages\ib_async\ib.py:2020, in IB.connectAsync(self, host, port, clientId, timeout, readonly, account, raiseSyncErrors, fetchFields)
#    2017 timeout = timeout or None
#    2018 try:
#    2019     # establish API connection
# -> 2020     await self.client.connectAsync(host, port, clientId, timeout)
#    2022     # autobind manual orders
#    2023     if clientId == 0:
#
# File ~\anaconda3\envs\sky\Lib\site-packages\ib_async\client.py:217, in Client.connectAsync(self, host, port, clientId, timeout)
#     215 self.connState = Client.CONNECTING
#     216 timeout = timeout or None
# --> 217 await asyncio.wait_for(self.conn.connectAsync(host, port), timeout)
#     218 self._logger.info("Connected")
#     219 msg = b"API\0" + self._prefix(
#     220     b"v%d..%d%s"
#     221     % (
#    (...)    225     )
#     226 )
#
# File ~\anaconda3\envs\sky\Lib\asyncio\tasks.py:507, in wait_for(fut, timeout)
#     504         raise TimeoutError from exc
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File ~\anaconda3\envs\sky\Lib\site-packages\ib_async\connection.py:39, in Connection.connectAsync(self, host, port)
#      37 self.reset()
#      38 loop = getLoop()
# ---> 39 self.transport, _ = await loop.create_connection(lambda: self, host, port)
#
# File ~\anaconda3\envs\sky\Lib\asyncio\base_events.py:1166, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, ssl_shutdown_timeout, happy_eyeballs_delay, interleave, all_errors)
#    1164     raise ExceptionGroup("create_connection failed", exceptions)
#    1165 if len(exceptions) == 1:
# -> 1166     raise exceptions[0]
#    1167 else:
#    1168     # If they all have the same str(), raise one.
#    1169     model = str(exceptions[0])
#
# File ~\anaconda3\envs\sky\Lib\asyncio\base_events.py:1141, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, ssl_shutdown_timeout, happy_eyeballs_delay, interleave, all_errors)
#    1139 for addrinfo in infos:
#    1140     try:
# -> 1141         sock = await self._connect_sock(
#    1142             exceptions, addrinfo, laddr_infos)
#    1143         break
#    1144     except OSError:
#
# File ~\anaconda3\envs\sky\Lib\asyncio\base_events.py:1044, in BaseEventLoop._connect_sock(self, exceptions, addr_info, local_addr_infos)
#    1042             else:
#    1043                 raise OSError(f"no matching local address with {family=} found")
# -> 1044     await self.sock_connect(sock, address)
#    1045     return sock
#    1046 except OSError as exc:
#
# File ~\anaconda3\envs\sky\Lib\asyncio\selector_events.py:641, in BaseSelectorEventLoop.sock_connect(self, sock, address)
#     639 self._sock_connect(fut, sock, address)
#     640 try:
# --> 641     return await fut
#     642 finally:
#     643     # Needed to break cycles when an exception occurs.
#     644     fut = None
#
# File ~\anaconda3\envs\sky\Lib\asyncio\futures.py:286, in Future.__await__(self)
#     284 if not self.done():
#     285     self._asyncio_future_blocking = True
# --> 286     yield self  # This tells Task to wait for completion.
#     287 if not self.done():
#     288     raise RuntimeError("await wasn't used with future")
#
# File ~\anaconda3\envs\sky\Lib\asyncio\tasks.py:375, in Task.__wakeup(self, future)
#     373 def __wakeup(self, future):
#     374     try:
# --> 375         future.result()
#     376     except BaseException as exc:
#     377         # This may also be a cancellation.
#     378         self.__step(exc)
#
# File ~\anaconda3\envs\sky\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File ~\anaconda3\envs\sky\Lib\asyncio\selector_events.py:681, in BaseSelectorEventLoop._sock_connect_cb(self, fut, sock, address)
#     678     err = sock.getsockopt(socket.SOL_SOCKET, socket.SO_ERROR)
#     679     if err != 0:
#     680         # Jump to any except clause below.
# --> 681         raise OSError(err, f'Connect call failed {address}')
#     682 except (BlockingIOError, InterruptedError):
#     683     # socket is still registered, the callback will be retried later
#     684     pass
#
# ConnectionRefusedError: [Errno 10061] Connect call failed ('127.0.0.1', 5901)

# %%
contract = Contract(symbol='NFLX', secType='STK', exchange='SMART', currency='USD')
ib.qualifyContracts(contract)

contract_vix = Contract(symbol= 'VIX', secType = 'IND',exchange = 'CBOE', currency='USD')
ib.qualifyContracts(contract_vix)

contract_nas = Contract(symbol= 'TQQQ', secType = 'STK',exchange = 'SMART', currency='USD')
ib.qualifyContracts(contract_nas)
# Out:
# [Contract(secType='STK', conId=72539702, symbol='TQQQ', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='TQQQ', tradingClass='NMS')]

# %%
class Data_Request :

    """
    Returns PD data containning equity price with specific time control

    Returns:
        pd: information regarding the contract of interst.
    """
    
    def __init__(self, list_days, contract, barsize, duration, *,specific_time= None, specific_pick_time= None):

        self.list_days = list_days
        self.contract = contract
        #self.init_date = init_date
        self.barsize = barsize
        self.duration = duration
        self.specific_time = specific_time # cut off time . Time object: time(14, 30, 0)
        self.specific_pick_time= specific_pick_time

    def D_request(self):

        his_df =pd.DataFrame()
        
        for i in range(len(self.list_days)):
            init_date=self.list_days[i]
            bars = ib.reqHistoricalData(self.contract, init_date, barSizeSetting=self.barsize, durationStr=self.duration, whatToShow="TRADES", useRTH=True)
            add_his_df = pd.DataFrame(bars)
            add_his_df['date'] = pd.to_datetime(add_his_df['date'])
            print(f'retriveing data for {init_date}')

            if self.specific_time is not None:
                cut_off = datetime.combine(self.list_days[i],self.specific_time)  # need logic if specific_time is defined
                pd_cut_off = pd.to_datetime(cut_off).tz_localize('US/Eastern')
            #datetime64_eastern = pd.Timestamp(date_time_str).tz_localize('US/Eastern')
                add_his_df = add_his_df[add_his_df['date'] > pd_cut_off]
            
            if self.specific_pick_time is not None:
                pick_time = datetime.combine(self.list_days[i],self.specific_pick_time)  # need logic if specific_time is defined
                pd_pick_time = pd.to_datetime(pick_time).tz_localize('US/Eastern')
            #datetime64_eastern = pd.Timestamp(date_time_str).tz_localize('US/Eastern')
                add_his_df = add_his_df[add_his_df['date'] == pd_pick_time]

            
            his_df = pd.concat([his_df, add_his_df], ignore_index=True)
            his_df['Date_Only'] = his_df['date'].dt.date
            print(len(his_df))

        
        return his_df

# %%
# picking out Friday and before specific-time data

#specific_time = time(14, 30, 0)
def data_filter_v46(df_initial, list_days, specific_time_before = None, specific_time_after= None, on_time= None):
    his_df = pd.DataFrame()

    df_trimmed = df_initial[df_initial['date'].dt.date.isin(list_days)]

    if specific_time_before is not None:

        his_df = df_trimmed[(df_trimmed['date'].dt.time < specific_time_before)]
        
            
    if specific_time_after is not None:

        his_df = df_trimmed[(df_trimmed['date'].dt.time >= specific_time_after)]

    if on_time is not None:
        his_df = df_trimmed[(df_trimmed['date'].dt.time == on_time)]

    if (specific_time_before is None and specific_time_after is None) and on_time is None:

        his_df = df_trimmed
        
    return his_df

# %%
def data_cleaning(df, in_days):
    df_his = pd.DataFrame()
    df_return = pd.DataFrame()
    
    df.drop_duplicates(inplace = True)
    df_his = df[df["Date_Only"].isin(in_days)]
    df_return = df_his[(df_his['date'].dt.time > time(9,29,40)) & (df_his['date'].dt.time < time(16,00))]

    for i in df_return['Date_Only'].unique():
        if df_return[df_return['Date_Only'] ==i].shape[0] % 390 != 0:
            print(i)
    
    return df_return

# %%
def data_sparcing_construc(df, sp_day, *, cut_time = None):
    #df_group = df.groupby("Date_Only").std(numeric_only=True)
    df_filter_prior = data_filter_v46(df, sp_day, specific_time_before = cut_time )
    df_group_prior = df_filter_prior.groupby("Date_Only").std(numeric_only=True)
    
    #df_filter_after = data_filter(df, sp_day, specific_time_after = cut_time )
    #df_group_after = df_filter_after.groupby("Date_Only").std(numeric_only=True)


    df_group_train =pd.DataFrame()
    #df_group_train['Target_std'] = pd.DataFrame(df_group_after[['open','high','low','close']].max(axis=1))
    df_group_train['prior_std'] = pd.DataFrame(df_group_prior[['open','high','low','close']].max(axis=1))
    df_group_train['prior_Vol'] = pd.DataFrame(df_filter_prior.groupby("Date_Only").mean()['volume'])
    df_group_train['prior_spread'] = df_filter_prior.groupby('Date_Only')['open'].max() - df_filter_prior.groupby('Date_Only')['open'].min()


    df_group_train['prior_range'] =pd.DataFrame(df_filter_prior.groupby('Date_Only')['close'].max() -df_filter_prior.groupby('Date_Only')['close'].min() )

    df_initial = df_filter_prior
    new_time = time(cut_time.hour, cut_time.minute -1)
    #df_group_train['cut_open'] = df_initial[(df_initial['date'].dt.time == new_time)]['open'].values
    df_group_train['cut_close'] = df_initial[(df_initial['date'].dt.time == new_time)]['close'].values
    
    cut_name =['cut_1hr','cut_2hr']
    for i in range(len(cut_name)):
        print(f'time avaiable {i}')
        prior = time(cut_time.hour - (i+1), cut_time.minute)
        df_group_train[cut_name[i]] = df_initial[(df_initial['date'].dt.time == new_time)]['open'].values- df_initial[(df_initial['date'].dt.time == prior)]['open'].values

    #df_group_train['Class_target'] = df_filter_after[(df_filter_after['date'].dt.time == time(15, 49, 0))]['close'].values- df_initial[(df_initial['date'].dt.time == new_time)]['open'].values
    
    return df_group_train, df_filter_prior, df_group_prior

# %%
def get_option_chain(symbol):
    contract = Stock(symbol=symbol, exchange='EDGX', currency='USD')
    ib.qualifyContracts(contract)
    chains = ib.reqSecDefOptParams(underlyingSymbol=contract.symbol, futFopExchange="", underlyingSecType=contract.secType, underlyingConId=contract.conId)
    chain = [ c for c in chains if c.exchange =='EDGX'][0]
    return chain

def get_options_chain_for_expiry(symbol, expiry, min_strike=0, max_strike=np.inf):
    option_chain = get_option_chain(symbol)
    options=[]
    for strike in option_chain.strikes:
        if strike <= max_strike and strike >= min_strike:
            for right in ['C', 'P']:
                option = Option(symbol=symbol, lastTradeDateOrContractMonth=expiry, strike=strike, right=right, exchange='SMART', currency='USD')
                options.append(option)
    valid_options=ib.qualifyContracts(*options)
    return valid_options

# %%
def round_up_to_nearest_ten(num):
  """Rounds a number up to the nearest ten."""
  return math.ceil(num / 10) * 10


def find_closest_number(numbers, target):
  """
  Finds the number in a list that is closest to a target number.

  Args:
    numbers: A list of numbers.
    target: The target number.

  Returns:
    The number in the list that is closest to the target number.
  """
  if not numbers:
    return None
  
  closest_number = numbers[0]
  min_difference = abs(numbers[0] - target)

  for number in numbers:
    difference = abs(number - target)
    if difference < min_difference:
      min_difference = difference
      closest_number = number

  return closest_number

# %% [markdown]
# ### Inferencing Data Set Collection ###

# %%
now =datetime.now()
#print(now.date())
#print(now.time().minute)
#infer_time = time(now.time().hour, now.time().minute -15 )
#infer_time = time(now.time().hour, now.time().minute)
#inferencing_date = now.date() - timedelta(3)
inferencing_date = now.date() 
#infer_time = time(14,30,0)
infer_time = time(now.time().hour, now.time().minute)
## put option expiration date in 20250411 format
to_day = "20250425"
print(to_day)
# Out:
# 20250425

# %%
barsize ="30 secs"
duration = "1 D"
#DR_stock_NFLX = Data_Request( " ",contract, barsize, duration)
DR_stock_NFLX = Data_Request([inferencing_date], contract, barsize, duration)
df_all_days_stock = DR_stock_NFLX.D_request()

DR_IND_VIX = Data_Request([inferencing_date], contract_vix, barsize, duration)
DR_STK_TQQQ = Data_Request([inferencing_date], contract_nas, barsize, duration)
df_all_days_VIX = DR_IND_VIX.D_request()
df_all_days_TQQQ = DR_STK_TQQQ.D_request()

df_stock = data_cleaning(df_all_days_stock,[inferencing_date])
df_VIX = data_cleaning(df_all_days_VIX,[inferencing_date])
df_TQQQ = data_cleaning(df_all_days_TQQQ,[inferencing_date])


df_group_train, df_filter_prior, df_group_prior = data_sparcing_construc(df_all_days_stock, [inferencing_date], cut_time= infer_time)
df_group_train_tqqq, *_ = data_sparcing_construc(df_all_days_TQQQ, [inferencing_date], cut_time= infer_time)

# need to check
vix_infer_time = time(now.time().hour -1, now.time().minute )
#vix_infer_time = infer_time 
df_group_train_vix, *_ = data_sparcing_construc(df_all_days_VIX, [inferencing_date], cut_time= vix_infer_time)

df_final_joninted_vix=pd.DataFrame()
df_final_joninted_all=pd.DataFrame()

df_group_train_vix.columns =['vix_prior_std','vix_Vol','vix_pr_spread','vix_prior_range','vix_cut_open','vix_cut_1hr','vix_cut_2hr']
df_final_jointed_vix = pd.concat([df_group_train,df_group_train_vix], axis=1)
df_group_train_tqqq.columns =['tqqq_prior_std','tqqq_Vol','tqqq_pr_spread','tqqq_prior_range','tqqq_cut_open','tqqq_cut_1hr','tqqq_cut_2hr']
df_final_jointed_all = pd.concat([df_final_jointed_vix,df_group_train_tqqq], axis=1)
df_final_jointed_all.drop(['vix_Vol'], axis=1, inplace=True)

df_final_jointed_all
# Out:
# retriveing data for 2025-04-25
# 253
# retriveing data for 2025-04-25
# 973
# retriveing data for 2025-04-25
# 253
# 2025-04-25
# 2025-04-25
# 2025-04-25
# time avaiable 0
# time avaiable 1
# time avaiable 0
# time avaiable 1
# time avaiable 0
# time avaiable 1
#             prior_std    prior_Vol  prior_spread  prior_range  cut_close  \
# Date_Only
# 2025-04-25    2.76912  3204.634921         13.92        14.38     1095.4
#
#             cut_1hr  cut_2hr  vix_prior_std  vix_pr_spread  vix_prior_range  \
# Date_Only
# 2025-04-25    -1.69    -5.09       0.386463           1.61             1.62
#
#             vix_cut_open  vix_cut_1hr  vix_cut_2hr  tqqq_prior_std  \
# Date_Only
# 2025-04-25         25.65        -1.08        -0.77        0.322996
#
#                  tqqq_Vol  tqqq_pr_spread  tqqq_prior_range  tqqq_cut_open  \
# Date_Only
# 2025-04-25  162036.690476            1.34              1.32          52.42
#
#             tqqq_cut_1hr  tqqq_cut_2hr
# Date_Only
# 2025-04-25          0.53          0.17

# %%
df_all_days_VIX
# Out:
#                          date   open   high    low  close  volume  average  \
# 0   2025-04-25 02:15:00-05:00  26.22  26.22  26.19  26.19     0.0      0.0
# 1   2025-04-25 02:15:30-05:00  26.14  26.14  26.12  26.12     0.0      0.0
# 2   2025-04-25 02:16:00-05:00  26.10  26.10  26.10  26.10     0.0      0.0
# 3   2025-04-25 02:16:30-05:00  26.00  26.09  26.00  26.09     0.0      0.0
# 4   2025-04-25 02:17:00-05:00  26.11  26.11  26.11  26.11     0.0      0.0
# ..                        ...    ...    ...    ...    ...     ...      ...
# 968 2025-04-25 10:34:00-05:00  25.64  25.64  25.63  25.63     0.0      0.0
# 969 2025-04-25 10:34:30-05:00  25.68  25.68  25.65  25.65     0.0      0.0
# 970 2025-04-25 10:35:00-05:00  25.65  25.65  25.65  25.65     0.0      0.0
# 971 2025-04-25 10:35:30-05:00  25.67  25.67  25.63  25.63     0.0      0.0
# 972 2025-04-25 10:36:00-05:00  25.67  25.67  25.67  25.67     0.0      0.0
#
#      barCount   Date_Only
# 0           2  2025-04-25
# 1           2  2025-04-25
# 2           1  2025-04-25
# 3           2  2025-04-25
# 4           1  2025-04-25
# ..        ...         ...
# 968         2  2025-04-25
# 969         2  2025-04-25
# 970         0  2025-04-25
# 971         2  2025-04-25
# 972         1  2025-04-25
#
# [973 rows x 9 columns]

# %%
### use model to predict block

df_final_jointed_all.reset_index(inplace=True)
inference_data = df_final_jointed_all.drop('Date_Only', axis=1)
inference_data.shape

filename = 'xgb_model_NFLX_price_spread_update.joblib'
loaded_model = joblib.load(filename)

yhat = loaded_model.predict(inference_data)
print(f'yhat {yhat}')

Entry = df_all_days_stock.tail(1)['close'].values

y_value = Entry
y_value_p = Entry + yhat[0]
y_value_m = Entry - yhat[0]

print(y_value_p, Entry ,y_value_m )

df_all_days_stock['close'].plot()
plt.xlabel('time')
plt.axhline(y=y_value, color='r', linestyle='--', label=f'y = {y_value}')
plt.axhline(y=y_value_p, color='black', linestyle='--', label=f'y = {y_value_p}')
plt.axhline(y=y_value_m, color='black', linestyle='--', label=f'y = {y_value_m}')
# Out:
# yhat [9.639222]
# [1105.37922215] [1095.74] [1086.10077785]

# %%
def get_option_chain(symbol):
    contract = Stock(symbol=symbol, exchange='SMART', currency='USD')
    ib.qualifyContracts(contract)
    chains = ib.reqSecDefOptParams(underlyingSymbol=contract.symbol, futFopExchange="", underlyingSecType=contract.secType, underlyingConId=contract.conId)
    #chain = [ c for c in chains if c.exchange =='EDGE'][1]
    return chains

# %%
chain = get_option_chain('NFLX')

# %%
###  GETTTING OPTION information
Rd_up_Entry = round_up_to_nearest_ten(Entry[0])

# getting valid option chains

valid_options = get_options_chain_for_expiry("NFLX", to_day , min_strike= Rd_up_Entry  -30, max_strike=Rd_up_Entry +30,)
#print(valid_options)

list_strke = []
for list_str in valid_options:
    list_strke.append(list_str.strike)
    
    ### OPTION to find closes available strike price
#print(list_strke)
upper_strk_number = find_closest_number(list_strke, y_value_p[0])

#global Up_Call
Up_Call = upper_strk_number
#Up_Call = 1000
lower_strk_number = find_closest_number(list_strke, y_value_m[0])

#global Down_Put
Down_Put = lower_strk_number 

#Down_Put =960
tickers_dict = {}
    
for option in valid_options:
    tickers_dict[(option.right, option.strike)] = ib.reqMktData(contract =option, genericTickList="", snapshot=False, regulatorySnapshot=False)

## call empty call to wait
ib.sleep(5)
###
ticker_call_to_sell_target = tickers_dict['C', Up_Call]
UCV = ticker_call_to_sell_target.midpoint()

ticker_put_to_sell_target = tickers_dict['P', Down_Put]
LPV = ticker_put_to_sell_target.midpoint()

print(f'current price({Entry})')
print(f'upper_strike ({Up_Call}) at {UCV}')
print(f'lower_strike ({Down_Put}) at {LPV}')

#############################
#SELL options
#############################

#
#get price of the asset

spot = ib.reqMktData(contract = contract, genericTickList="", snapshot=False, regulatorySnapshot=False)
stock_price = spot.last

# Sample DataFrame
Total_sum = UCV + LPV

print(f'Total_sum ({Total_sum})')
    
df = pd.DataFrame([{'time':datetime.now(),'upper_Call_value': UCV, 'stock_price':stock_price, 'lower_Put_value': LPV, 'Total_sum': Total_sum}])
df.to_pickle('price_move_416.pkl')
# Out:
# current price([1095.74])
# upper_strike (1105.0) at 1.3199999999999998
# lower_strike (1085.0) at 1.255
# Total_sum (2.5749999999999997)

# %%
def job(valid_options, Up_Call, Down_Put ):
    
    tickers_dict = {}
    
    for option in valid_options:
        tickers_dict[(option.right, option.strike)] = ib.reqMktData(contract =option, genericTickList="", snapshot=False, regulatorySnapshot=False)

    
    #print(tickers_dict)

    ib.sleep(5)
    
    ticker_call_to_sell_target = tickers_dict['C', Up_Call]
    UCV = ticker_call_to_sell_target.midpoint()
    
    ticker_put_to_sell_target = tickers_dict['P', Down_Put]
    LPV = ticker_put_to_sell_target.midpoint()


    spot = ib.reqMktData(contract = contract, genericTickList="", snapshot=False, regulatorySnapshot=False)

    ib.sleep(5)
    stock_price = spot.last
  
    
    print(f'current price({stock_price})')
    print(f'upper_strike price({Up_Call})')
    print(f'lower_strike price({Down_Put})')

    df = pd.read_pickle('price_move_416.pkl')

    Total_sum = UCV + LPV
    print(f'Total_sum ({Total_sum})')
    
    new_row = pd.DataFrame([{'time':datetime.now(),'upper_Call_value': UCV, 'stock_price':stock_price, 'lower_Put_value': LPV, 'Total_sum': Total_sum}])

        # Append the new row using concat
    df = pd.concat([df, new_row], ignore_index=True)
    
    df.to_pickle('price_move_416.pkl')
    print(df)

# %%
#import schedule
#import time as st_time

# def job():
#     # Replace this with the code you want to run
#     print("Running script...", datetime.datetime.now())

def run_within_time_window(start_time_str, end_time_str, interval_seconds):
    start_time = datetime.strptime(start_time_str, '%H:%M:%S').time()
    end_time = datetime.strptime(end_time_str, '%H:%M:%S').time()

    while True:
        now = datetime.now()
        current_time = now.time()

        if start_time <= current_time <= end_time:
            schedule.run_pending()
        elif current_time > end_time:
            print("Time window ended.")
            break
        else:
            print("Waiting for time window...")

        ib.sleep(10)

if __name__ == "__main__":
    start_time_str = '11:50:00'  # Start time (HH:MM:SS)
    end_time_str = '16:00:00'    # End time (HH:MM:SS)
    interval_seconds = 60   # Run every hour

    schedule.every(interval_seconds).seconds.do(job, valid_options = valid_options, Up_Call = Up_Call,  Down_Put = Down_Put)

    run_within_time_window(start_time_str, end_time_str, interval_seconds)
# Out:
# current price(1095.02)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.615)
#                         time  upper_Call_value  stock_price  lower_Put_value  \
# 0 2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1 2025-04-25 11:56:20.955063             1.355      1095.02            1.260
#
#    Total_sum
# 0      2.575
# 1      2.615
# current price(1096.0)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.425)
#                         time  upper_Call_value  stock_price  lower_Put_value  \
# 0 2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1 2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2 2025-04-25 11:57:20.988862             1.380      1096.00            1.045
#
#    Total_sum
# 0      2.575
# 1      2.615
# 2      2.425
# current price(1095.7)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.465)
#                         time  upper_Call_value  stock_price  lower_Put_value  \
# 0 2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1 2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2 2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3 2025-04-25 11:57:41.022902             1.400      1095.70            1.065
#
#    Total_sum
# 0      2.575
# 1      2.615
# 2      2.425
# 3      2.465
# current price(1096.76)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.4800000000000004)
#                         time  upper_Call_value  stock_price  lower_Put_value  \
# 0 2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1 2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2 2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3 2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4 2025-04-25 11:58:31.075817             1.495      1096.76            0.985
#
#    Total_sum
# 0      2.575
# 1      2.615
# 2      2.425
# 3      2.465
# 4      2.480
# current price(1096.0)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.5700000000000003)
#                         time  upper_Call_value  stock_price  lower_Put_value  \
# 0 2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1 2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2 2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3 2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4 2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5 2025-04-25 11:58:51.086227             1.625      1096.00            0.945
#
#    Total_sum
# 0      2.575
# 1      2.615
# 2      2.425
# 3      2.465
# 4      2.480
# 5      2.570
# current price(1096.68)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.63)
#                         time  upper_Call_value  stock_price  lower_Put_value  \
# 0 2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1 2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2 2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3 2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4 2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5 2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6 2025-04-25 11:59:41.149217             1.710      1096.68            0.920
#
#    Total_sum
# 0      2.575
# 1      2.615
# 2      2.425
# 3      2.465
# 4      2.480
# 5      2.570
# 6      2.630
# current price(1096.53)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.605)
#                         time  upper_Call_value  stock_price  lower_Put_value  \
# 0 2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1 2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2 2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3 2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4 2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5 2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6 2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7 2025-04-25 12:00:01.166186             1.695      1096.53            0.910
#
#    Total_sum
# 0      2.575
# 1      2.615
# 2      2.425
# 3      2.465
# 4      2.480
# 5      2.570
# 6      2.630
# 7      2.605
# current price(1097.75)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.685)
#                         time  upper_Call_value  stock_price  lower_Put_value  \
# 0 2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1 2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2 2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3 2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4 2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5 2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6 2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7 2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8 2025-04-25 12:00:51.218591             1.820      1097.75            0.865
#
#    Total_sum
# 0      2.575
# 1      2.615
# 2      2.425
# 3      2.465
# 4      2.480
# 5      2.570
# 6      2.630
# 7      2.605
# 8      2.685
# current price(1097.05)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.605)
#                         time  upper_Call_value  stock_price  lower_Put_value  \
# 0 2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1 2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2 2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3 2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4 2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5 2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6 2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7 2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8 2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9 2025-04-25 12:01:11.244184             1.690      1097.05            0.915
#
#    Total_sum
# 0      2.575
# 1      2.615
# 2      2.425
# 3      2.465
# 4      2.480
# 5      2.570
# 6      2.630
# 7      2.605
# 8      2.685
# 9      2.605
# current price(1096.43)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.59)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# current price(1095.69)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.605)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# current price(1096.07)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.45)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# current price(1096.09)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.455)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# current price(1095.19)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.385)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# current price(1095.07)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.42)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# current price(1095.29)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.37)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
# 16 2025-04-25 12:05:31.551261             1.265      1095.29            1.105
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# 16      2.370
# current price(1096.32)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.43)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
# 16 2025-04-25 12:05:31.551261             1.265      1095.29            1.105
# 17 2025-04-25 12:05:51.576882             1.410      1096.32            1.020
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# 16      2.370
# 17      2.430
# current price(1095.98)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.38)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
# 16 2025-04-25 12:05:31.551261             1.265      1095.29            1.105
# 17 2025-04-25 12:05:51.576882             1.410      1096.32            1.020
# 18 2025-04-25 12:06:41.616588             1.285      1095.98            1.095
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# 16      2.370
# 17      2.430
# 18      2.380
# current price(1095.41)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.365)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
# 16 2025-04-25 12:05:31.551261             1.265      1095.29            1.105
# 17 2025-04-25 12:05:51.576882             1.410      1096.32            1.020
# 18 2025-04-25 12:06:41.616588             1.285      1095.98            1.095
# 19 2025-04-25 12:07:01.648925             1.290      1095.41            1.075
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# 16      2.370
# 17      2.430
# 18      2.380
# 19      2.365
# current price(1096.3)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.48)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
# 16 2025-04-25 12:05:31.551261             1.265      1095.29            1.105
# 17 2025-04-25 12:05:51.576882             1.410      1096.32            1.020
# 18 2025-04-25 12:06:41.616588             1.285      1095.98            1.095
# 19 2025-04-25 12:07:01.648925             1.290      1095.41            1.075
# 20 2025-04-25 12:07:51.704027             1.465      1096.30            1.015
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# 16      2.370
# 17      2.430
# 18      2.380
# 19      2.365
# 20      2.480
# current price(1096.3)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.475)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
# 16 2025-04-25 12:05:31.551261             1.265      1095.29            1.105
# 17 2025-04-25 12:05:51.576882             1.410      1096.32            1.020
# 18 2025-04-25 12:06:41.616588             1.285      1095.98            1.095
# 19 2025-04-25 12:07:01.648925             1.290      1095.41            1.075
# 20 2025-04-25 12:07:51.704027             1.465      1096.30            1.015
# 21 2025-04-25 12:08:11.722900             1.485      1096.30            0.990
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# 16      2.370
# 17      2.430
# 18      2.380
# 19      2.365
# 20      2.480
# 21      2.475
# current price(1096.82)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.5149999999999997)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
# 16 2025-04-25 12:05:31.551261             1.265      1095.29            1.105
# 17 2025-04-25 12:05:51.576882             1.410      1096.32            1.020
# 18 2025-04-25 12:06:41.616588             1.285      1095.98            1.095
# 19 2025-04-25 12:07:01.648925             1.290      1095.41            1.075
# 20 2025-04-25 12:07:51.704027             1.465      1096.30            1.015
# 21 2025-04-25 12:08:11.722900             1.485      1096.30            0.990
# 22 2025-04-25 12:09:01.759135             1.650      1096.82            0.865
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# 16      2.370
# 17      2.430
# 18      2.380
# 19      2.365
# 20      2.480
# 21      2.475
# 22      2.515
# current price(1097.22)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.46)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
# 16 2025-04-25 12:05:31.551261             1.265      1095.29            1.105
# 17 2025-04-25 12:05:51.576882             1.410      1096.32            1.020
# 18 2025-04-25 12:06:41.616588             1.285      1095.98            1.095
# 19 2025-04-25 12:07:01.648925             1.290      1095.41            1.075
# 20 2025-04-25 12:07:51.704027             1.465      1096.30            1.015
# 21 2025-04-25 12:08:11.722900             1.485      1096.30            0.990
# 22 2025-04-25 12:09:01.759135             1.650      1096.82            0.865
# 23 2025-04-25 12:09:21.780045             1.605      1097.22            0.855
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# 16      2.370
# 17      2.430
# 18      2.380
# 19      2.365
# 20      2.480
# 21      2.475
# 22      2.515
# 23      2.460
# current price(1096.81)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.44)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
# 16 2025-04-25 12:05:31.551261             1.265      1095.29            1.105
# 17 2025-04-25 12:05:51.576882             1.410      1096.32            1.020
# 18 2025-04-25 12:06:41.616588             1.285      1095.98            1.095
# 19 2025-04-25 12:07:01.648925             1.290      1095.41            1.075
# 20 2025-04-25 12:07:51.704027             1.465      1096.30            1.015
# 21 2025-04-25 12:08:11.722900             1.485      1096.30            0.990
# 22 2025-04-25 12:09:01.759135             1.650      1096.82            0.865
# 23 2025-04-25 12:09:21.780045             1.605      1097.22            0.855
# 24 2025-04-25 12:10:11.814447             1.560      1096.81            0.880
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# 16      2.370
# 17      2.430
# 18      2.380
# 19      2.365
# 20      2.480
# 21      2.475
# 22      2.515
# 23      2.460
# 24      2.440
# current price(1096.86)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.455)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
# 16 2025-04-25 12:05:31.551261             1.265      1095.29            1.105
# 17 2025-04-25 12:05:51.576882             1.410      1096.32            1.020
# 18 2025-04-25 12:06:41.616588             1.285      1095.98            1.095
# 19 2025-04-25 12:07:01.648925             1.290      1095.41            1.075
# 20 2025-04-25 12:07:51.704027             1.465      1096.30            1.015
# 21 2025-04-25 12:08:11.722900             1.485      1096.30            0.990
# 22 2025-04-25 12:09:01.759135             1.650      1096.82            0.865
# 23 2025-04-25 12:09:21.780045             1.605      1097.22            0.855
# 24 2025-04-25 12:10:11.814447             1.560      1096.81            0.880
# 25 2025-04-25 12:10:31.837618             1.550      1096.86            0.905
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# 16      2.370
# 17      2.430
# 18      2.380
# 19      2.365
# 20      2.480
# 21      2.475
# 22      2.515
# 23      2.460
# 24      2.440
# 25      2.455
# current price(1097.23)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.5)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
# 16 2025-04-25 12:05:31.551261             1.265      1095.29            1.105
# 17 2025-04-25 12:05:51.576882             1.410      1096.32            1.020
# 18 2025-04-25 12:06:41.616588             1.285      1095.98            1.095
# 19 2025-04-25 12:07:01.648925             1.290      1095.41            1.075
# 20 2025-04-25 12:07:51.704027             1.465      1096.30            1.015
# 21 2025-04-25 12:08:11.722900             1.485      1096.30            0.990
# 22 2025-04-25 12:09:01.759135             1.650      1096.82            0.865
# 23 2025-04-25 12:09:21.780045             1.605      1097.22            0.855
# 24 2025-04-25 12:10:11.814447             1.560      1096.81            0.880
# 25 2025-04-25 12:10:31.837618             1.550      1096.86            0.905
# 26 2025-04-25 12:11:21.883195             1.650      1097.23            0.850
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# 16      2.370
# 17      2.430
# 18      2.380
# 19      2.365
# 20      2.480
# 21      2.475
# 22      2.515
# 23      2.460
# 24      2.440
# 25      2.455
# 26      2.500
# current price(1097.23)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.475)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
# 16 2025-04-25 12:05:31.551261             1.265      1095.29            1.105
# 17 2025-04-25 12:05:51.576882             1.410      1096.32            1.020
# 18 2025-04-25 12:06:41.616588             1.285      1095.98            1.095
# 19 2025-04-25 12:07:01.648925             1.290      1095.41            1.075
# 20 2025-04-25 12:07:51.704027             1.465      1096.30            1.015
# 21 2025-04-25 12:08:11.722900             1.485      1096.30            0.990
# 22 2025-04-25 12:09:01.759135             1.650      1096.82            0.865
# 23 2025-04-25 12:09:21.780045             1.605      1097.22            0.855
# 24 2025-04-25 12:10:11.814447             1.560      1096.81            0.880
# 25 2025-04-25 12:10:31.837618             1.550      1096.86            0.905
# 26 2025-04-25 12:11:21.883195             1.650      1097.23            0.850
# 27 2025-04-25 12:11:41.918572             1.655      1097.23            0.820
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# 16      2.370
# 17      2.430
# 18      2.380
# 19      2.365
# 20      2.480
# 21      2.475
# 22      2.515
# 23      2.460
# 24      2.440
# 25      2.455
# 26      2.500
# 27      2.475
# current price(1098.3)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.475)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# 5  2025-04-25 11:58:51.086227             1.625      1096.00            0.945
# 6  2025-04-25 11:59:41.149217             1.710      1096.68            0.920
# 7  2025-04-25 12:00:01.166186             1.695      1096.53            0.910
# 8  2025-04-25 12:00:51.218591             1.820      1097.75            0.865
# 9  2025-04-25 12:01:11.244184             1.690      1097.05            0.915
# 10 2025-04-25 12:02:01.283366             1.540      1096.43            1.050
# 11 2025-04-25 12:02:21.312334             1.420      1095.69            1.185
# 12 2025-04-25 12:03:11.372821             1.370      1096.07            1.080
# 13 2025-04-25 12:03:31.406949             1.420      1096.09            1.035
# 14 2025-04-25 12:04:21.473866             1.230      1095.19            1.155
# 15 2025-04-25 12:04:41.488157             1.200      1095.07            1.220
# 16 2025-04-25 12:05:31.551261             1.265      1095.29            1.105
# 17 2025-04-25 12:05:51.576882             1.410      1096.32            1.020
# 18 2025-04-25 12:06:41.616588             1.285      1095.98            1.095
# 19 2025-04-25 12:07:01.648925             1.290      1095.41            1.075
# 20 2025-04-25 12:07:51.704027             1.465      1096.30            1.015
# 21 2025-04-25 12:08:11.722900             1.485      1096.30            0.990
# 22 2025-04-25 12:09:01.759135             1.650      1096.82            0.865
# 23 2025-04-25 12:09:21.780045             1.605      1097.22            0.855
# 24 2025-04-25 12:10:11.814447             1.560      1096.81            0.880
# 25 2025-04-25 12:10:31.837618             1.550      1096.86            0.905
# 26 2025-04-25 12:11:21.883195             1.650      1097.23            0.850
# 27 2025-04-25 12:11:41.918572             1.655      1097.23            0.820
# 28 2025-04-25 12:12:31.971481             1.770      1098.30            0.705
#
#     Total_sum
# 0       2.575
# 1       2.615
# 2       2.425
# 3       2.465
# 4       2.480
# 5       2.570
# 6       2.630
# 7       2.605
# 8       2.685
# 9       2.605
# 10      2.590
# 11      2.605
# 12      2.450
# 13      2.455
# 14      2.385
# 15      2.420
# 16      2.370
# 17      2.430
# 18      2.380
# 19      2.365
# 20      2.480
# 21      2.475
# 22      2.515
# 23      2.460
# 24      2.440
# 25      2.455
# 26      2.500
# 27      2.475
# 28      2.475
# current price(1098.86)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (2.62)
#                          time  upper_Call_value  stock_price  lower_Put_value  \
# 0  2025-04-25 11:55:50.960660             1.320      1095.23            1.255
# 1  2025-04-25 11:56:20.955063             1.355      1095.02            1.260
# 2  2025-04-25 11:57:20.988862             1.380      1096.00            1.045
# 3  2025-04-25 11:57:41.022902             1.400      1095.70            1.065
# 4  2025-04-25 11:58:31.075817             1.495      1096.76            0.985
# ...
# 3              1.065      2.465
# 4              0.985      2.480
# ..               ...        ...
# 349            0.355      1.150
# 350            0.355      1.150
# 351            0.355      1.150
# 352            0.355      1.150
# 353            0.355      1.150
#
# [354 rows x 5 columns]
# current price(1098.45)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (1.15)
#                           time  upper_Call_value  stock_price  \
# 0   2025-04-25 11:55:50.960660             1.320      1095.23
# 1   2025-04-25 11:56:20.955063             1.355      1095.02
# 2   2025-04-25 11:57:20.988862             1.380      1096.00
# 3   2025-04-25 11:57:41.022902             1.400      1095.70
# 4   2025-04-25 11:58:31.075817             1.495      1096.76
# ..                         ...               ...          ...
# 350 2025-04-25 15:20:40.614233             0.795      1098.45
# 351 2025-04-25 15:21:00.644000             0.795      1098.45
# 352 2025-04-25 15:21:50.697253             0.795      1098.45
# 353 2025-04-25 15:22:10.726062             0.795      1098.45
# 354 2025-04-25 15:53:52.548645             0.795      1098.45
#
#      lower_Put_value  Total_sum
# 0              1.255      2.575
# 1              1.260      2.615
# 2              1.045      2.425
# 3              1.065      2.465
# 4              0.985      2.480
# ..               ...        ...
# 350            0.355      1.150
# 351            0.355      1.150
# 352            0.355      1.150
# 353            0.355      1.150
# 354            0.355      1.150
#
# [355 rows x 5 columns]
# current price(1098.45)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (1.15)
#                           time  upper_Call_value  stock_price  \
# 0   2025-04-25 11:55:50.960660             1.320      1095.23
# 1   2025-04-25 11:56:20.955063             1.355      1095.02
# 2   2025-04-25 11:57:20.988862             1.380      1096.00
# 3   2025-04-25 11:57:41.022902             1.400      1095.70
# 4   2025-04-25 11:58:31.075817             1.495      1096.76
# ..                         ...               ...          ...
# 351 2025-04-25 15:21:00.644000             0.795      1098.45
# 352 2025-04-25 15:21:50.697253             0.795      1098.45
# 353 2025-04-25 15:22:10.726062             0.795      1098.45
# 354 2025-04-25 15:53:52.548645             0.795      1098.45
# 355 2025-04-25 15:54:02.570317             0.795      1098.45
#
#      lower_Put_value  Total_sum
# 0              1.255      2.575
# 1              1.260      2.615
# 2              1.045      2.425
# 3              1.065      2.465
# 4              0.985      2.480
# ..               ...        ...
# 351            0.355      1.150
# 352            0.355      1.150
# 353            0.355      1.150
# 354            0.355      1.150
# 355            0.355      1.150
#
# [356 rows x 5 columns]
# current price(1098.45)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (1.15)
#                           time  upper_Call_value  stock_price  \
# 0   2025-04-25 11:55:50.960660             1.320      1095.23
# 1   2025-04-25 11:56:20.955063             1.355      1095.02
# 2   2025-04-25 11:57:20.988862             1.380      1096.00
# 3   2025-04-25 11:57:41.022902             1.400      1095.70
# 4   2025-04-25 11:58:31.075817             1.495      1096.76
# ..                         ...               ...          ...
# 352 2025-04-25 15:21:50.697253             0.795      1098.45
# 353 2025-04-25 15:22:10.726062             0.795      1098.45
# 354 2025-04-25 15:53:52.548645             0.795      1098.45
# 355 2025-04-25 15:54:02.570317             0.795      1098.45
# 356 2025-04-25 15:55:02.626780             0.795      1098.45
#
#      lower_Put_value  Total_sum
# 0              1.255      2.575
# 1              1.260      2.615
# 2              1.045      2.425
# 3              1.065      2.465
# 4              0.985      2.480
# ..               ...        ...
# 352            0.355      1.150
# 353            0.355      1.150
# 354            0.355      1.150
# 355            0.355      1.150
# 356            0.355      1.150
#
# [357 rows x 5 columns]
# current price(1098.45)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (1.15)
#                           time  upper_Call_value  stock_price  \
# 0   2025-04-25 11:55:50.960660             1.320      1095.23
# 1   2025-04-25 11:56:20.955063             1.355      1095.02
# 2   2025-04-25 11:57:20.988862             1.380      1096.00
# 3   2025-04-25 11:57:41.022902             1.400      1095.70
# 4   2025-04-25 11:58:31.075817             1.495      1096.76
# ..                         ...               ...          ...
# 353 2025-04-25 15:22:10.726062             0.795      1098.45
# 354 2025-04-25 15:53:52.548645             0.795      1098.45
# 355 2025-04-25 15:54:02.570317             0.795      1098.45
# 356 2025-04-25 15:55:02.626780             0.795      1098.45
# 357 2025-04-25 15:55:22.651855             0.795      1098.45
#
#      lower_Put_value  Total_sum
# 0              1.255      2.575
# 1              1.260      2.615
# 2              1.045      2.425
# 3              1.065      2.465
# 4              0.985      2.480
# ..               ...        ...
# 353            0.355      1.150
# 354            0.355      1.150
# 355            0.355      1.150
# 356            0.355      1.150
# 357            0.355      1.150
#
# [358 rows x 5 columns]
# current price(1098.45)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (1.15)
#                           time  upper_Call_value  stock_price  \
# 0   2025-04-25 11:55:50.960660             1.320      1095.23
# 1   2025-04-25 11:56:20.955063             1.355      1095.02
# 2   2025-04-25 11:57:20.988862             1.380      1096.00
# 3   2025-04-25 11:57:41.022902             1.400      1095.70
# 4   2025-04-25 11:58:31.075817             1.495      1096.76
# ..                         ...               ...          ...
# 354 2025-04-25 15:53:52.548645             0.795      1098.45
# 355 2025-04-25 15:54:02.570317             0.795      1098.45
# 356 2025-04-25 15:55:02.626780             0.795      1098.45
# 357 2025-04-25 15:55:22.651855             0.795      1098.45
# 358 2025-04-25 15:56:12.701846             0.795      1098.45
#
#      lower_Put_value  Total_sum
# 0              1.255      2.575
# 1              1.260      2.615
# 2              1.045      2.425
# 3              1.065      2.465
# 4              0.985      2.480
# ..               ...        ...
# 354            0.355      1.150
# 355            0.355      1.150
# 356            0.355      1.150
# 357            0.355      1.150
# 358            0.355      1.150
#
# [359 rows x 5 columns]
# current price(1098.45)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (1.15)
#                           time  upper_Call_value  stock_price  \
# 0   2025-04-25 11:55:50.960660             1.320      1095.23
# 1   2025-04-25 11:56:20.955063             1.355      1095.02
# 2   2025-04-25 11:57:20.988862             1.380      1096.00
# 3   2025-04-25 11:57:41.022902             1.400      1095.70
# 4   2025-04-25 11:58:31.075817             1.495      1096.76
# ..                         ...               ...          ...
# 355 2025-04-25 15:54:02.570317             0.795      1098.45
# 356 2025-04-25 15:55:02.626780             0.795      1098.45
# 357 2025-04-25 15:55:22.651855             0.795      1098.45
# 358 2025-04-25 15:56:12.701846             0.795      1098.45
# 359 2025-04-25 15:56:32.741684             0.795      1098.45
#
#      lower_Put_value  Total_sum
# 0              1.255      2.575
# 1              1.260      2.615
# 2              1.045      2.425
# 3              1.065      2.465
# 4              0.985      2.480
# ..               ...        ...
# 355            0.355      1.150
# 356            0.355      1.150
# 357            0.355      1.150
# 358            0.355      1.150
# 359            0.355      1.150
#
# [360 rows x 5 columns]
# current price(1098.45)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (1.15)
#                           time  upper_Call_value  stock_price  \
# 0   2025-04-25 11:55:50.960660             1.320      1095.23
# 1   2025-04-25 11:56:20.955063             1.355      1095.02
# 2   2025-04-25 11:57:20.988862             1.380      1096.00
# 3   2025-04-25 11:57:41.022902             1.400      1095.70
# 4   2025-04-25 11:58:31.075817             1.495      1096.76
# ..                         ...               ...          ...
# 356 2025-04-25 15:55:02.626780             0.795      1098.45
# 357 2025-04-25 15:55:22.651855             0.795      1098.45
# 358 2025-04-25 15:56:12.701846             0.795      1098.45
# 359 2025-04-25 15:56:32.741684             0.795      1098.45
# 360 2025-04-25 15:57:22.808956             0.795      1098.45
#
#      lower_Put_value  Total_sum
# 0              1.255      2.575
# 1              1.260      2.615
# 2              1.045      2.425
# 3              1.065      2.465
# 4              0.985      2.480
# ..               ...        ...
# 356            0.355      1.150
# 357            0.355      1.150
# 358            0.355      1.150
# 359            0.355      1.150
# 360            0.355      1.150
#
# [361 rows x 5 columns]
# current price(1098.45)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (1.15)
#                           time  upper_Call_value  stock_price  \
# 0   2025-04-25 11:55:50.960660             1.320      1095.23
# 1   2025-04-25 11:56:20.955063             1.355      1095.02
# 2   2025-04-25 11:57:20.988862             1.380      1096.00
# 3   2025-04-25 11:57:41.022902             1.400      1095.70
# 4   2025-04-25 11:58:31.075817             1.495      1096.76
# ..                         ...               ...          ...
# 357 2025-04-25 15:55:22.651855             0.795      1098.45
# 358 2025-04-25 15:56:12.701846             0.795      1098.45
# 359 2025-04-25 15:56:32.741684             0.795      1098.45
# 360 2025-04-25 15:57:22.808956             0.795      1098.45
# 361 2025-04-25 15:57:42.843792             0.795      1098.45
#
#      lower_Put_value  Total_sum
# 0              1.255      2.575
# 1              1.260      2.615
# 2              1.045      2.425
# 3              1.065      2.465
# 4              0.985      2.480
# ..               ...        ...
# 357            0.355      1.150
# 358            0.355      1.150
# 359            0.355      1.150
# 360            0.355      1.150
# 361            0.355      1.150
#
# [362 rows x 5 columns]
# current price(1098.45)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (1.15)
#                           time  upper_Call_value  stock_price  \
# 0   2025-04-25 11:55:50.960660             1.320      1095.23
# 1   2025-04-25 11:56:20.955063             1.355      1095.02
# 2   2025-04-25 11:57:20.988862             1.380      1096.00
# 3   2025-04-25 11:57:41.022902             1.400      1095.70
# 4   2025-04-25 11:58:31.075817             1.495      1096.76
# ..                         ...               ...          ...
# 358 2025-04-25 15:56:12.701846             0.795      1098.45
# 359 2025-04-25 15:56:32.741684             0.795      1098.45
# 360 2025-04-25 15:57:22.808956             0.795      1098.45
# 361 2025-04-25 15:57:42.843792             0.795      1098.45
# 362 2025-04-25 15:58:32.896661             0.795      1098.45
#
#      lower_Put_value  Total_sum
# 0              1.255      2.575
# 1              1.260      2.615
# 2              1.045      2.425
# 3              1.065      2.465
# 4              0.985      2.480
# ..               ...        ...
# 358            0.355      1.150
# 359            0.355      1.150
# 360            0.355      1.150
# 361            0.355      1.150
# 362            0.355      1.150
#
# [363 rows x 5 columns]
# current price(1098.45)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (1.15)
#                           time  upper_Call_value  stock_price  \
# 0   2025-04-25 11:55:50.960660             1.320      1095.23
# 1   2025-04-25 11:56:20.955063             1.355      1095.02
# 2   2025-04-25 11:57:20.988862             1.380      1096.00
# 3   2025-04-25 11:57:41.022902             1.400      1095.70
# 4   2025-04-25 11:58:31.075817             1.495      1096.76
# ..                         ...               ...          ...
# 359 2025-04-25 15:56:32.741684             0.795      1098.45
# 360 2025-04-25 15:57:22.808956             0.795      1098.45
# 361 2025-04-25 15:57:42.843792             0.795      1098.45
# 362 2025-04-25 15:58:32.896661             0.795      1098.45
# 363 2025-04-25 15:58:52.943699             0.795      1098.45
#
#      lower_Put_value  Total_sum
# 0              1.255      2.575
# 1              1.260      2.615
# 2              1.045      2.425
# 3              1.065      2.465
# 4              0.985      2.480
# ..               ...        ...
# 359            0.355      1.150
# 360            0.355      1.150
# 361            0.355      1.150
# 362            0.355      1.150
# 363            0.355      1.150
#
# [364 rows x 5 columns]
# current price(1098.45)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (1.15)
#                           time  upper_Call_value  stock_price  \
# 0   2025-04-25 11:55:50.960660             1.320      1095.23
# 1   2025-04-25 11:56:20.955063             1.355      1095.02
# 2   2025-04-25 11:57:20.988862             1.380      1096.00
# 3   2025-04-25 11:57:41.022902             1.400      1095.70
# 4   2025-04-25 11:58:31.075817             1.495      1096.76
# ..                         ...               ...          ...
# 360 2025-04-25 15:57:22.808956             0.795      1098.45
# 361 2025-04-25 15:57:42.843792             0.795      1098.45
# 362 2025-04-25 15:58:32.896661             0.795      1098.45
# 363 2025-04-25 15:58:52.943699             0.795      1098.45
# 364 2025-04-25 15:59:42.998419             0.795      1098.45
#
#      lower_Put_value  Total_sum
# 0              1.255      2.575
# 1              1.260      2.615
# 2              1.045      2.425
# 3              1.065      2.465
# 4              0.985      2.480
# ..               ...        ...
# 360            0.355      1.150
# 361            0.355      1.150
# 362            0.355      1.150
# 363            0.355      1.150
# 364            0.355      1.150
#
# [365 rows x 5 columns]
# current price(1098.45)
# upper_strike price(1105.0)
# lower_strike price(1085.0)
# Total_sum (1.15)
#                           time  upper_Call_value  stock_price  \
# 0   2025-04-25 11:55:50.960660             1.320      1095.23
# 1   2025-04-25 11:56:20.955063             1.355      1095.02
# 2   2025-04-25 11:57:20.988862             1.380      1096.00
# 3   2025-04-25 11:57:41.022902             1.400      1095.70
# 4   2025-04-25 11:58:31.075817             1.495      1096.76
# ..                         ...               ...          ...
# 361 2025-04-25 15:57:42.843792             0.795      1098.45
# 362 2025-04-25 15:58:32.896661             0.795      1098.45
# 363 2025-04-25 15:58:52.943699             0.795      1098.45
# 364 2025-04-25 15:59:42.998419             0.795      1098.45
# 365 2025-04-25 16:00:03.032890             0.795      1098.45
#
#      lower_Put_value  Total_sum
# 0              1.255      2.575
# 1              1.260      2.615
# 2              1.045      2.425
# 3              1.065      2.465
# 4              0.985      2.480
# ..               ...        ...
# 361            0.355      1.150
# 362            0.355      1.150
# 363            0.355      1.150
# 364            0.355      1.150
# 365            0.355      1.150
#
# [366 rows x 5 columns]
# Time window ended.

# %%
df_review = pd.read_pickle('price_move_416.pkl')

df_review['time'] =df_review['time'].dt.strftime("%Y-%m-%d %H:%M:%S")
df_review['time'] = pd.to_datetime(df_review['time'])
df_review.index = df_review['time']
df_review.drop('time',axis=1, inplace=True)
df_review['Total_sum'].plot()
# Out:
# <Axes: xlabel='time'>

# %%
df_review
