# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, max_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df_option = pd.read_pickle("dev_MSFT_df_final_jointed_all_train_beta.pkl")

# %%
#def is_third_friday(date_ts):
#    return date_ts.weekday() == 4 and 15 <= date_ts.day <= 21

# %%
df_option.columns
# Out:
# Index(['Target_std', 'Target_spread', 'prior_std', 'prior_Vol', 'prior_spread',
#        'prior_range', 'cut_open', 'cut_1hr', 'cut_2hr', 'cut_3hr',
#        'vix_prior_std', 'vix_pr_spread', 'vix_prior_range', 'vix_cut_open',
#        'vix_cut_1hr', 'vix_cut_2hr', 'vix_cut_3hr', 'tqqq_prior_std',
#        'tqqq_Vol', 'tqqq_pr_spread', 'tqqq_prior_range', 'tqqq_cut_open',
#        'tqqq_cut_1hr', 'tqqq_cut_2hr', 'tqqq_cut_3hr'],
#       dtype='object')

# %%
len(df_option.columns)
# Out:
# 25

# %%
#df_option.drop(['Class_target','vix_class', 'tqqq_class'], axis=1, inplace =True)

# %%
#sns.pairplot(df_option[['Target_std','prior_std','vix_prior_std','tqqq_prior_std']], hue='Target_std')

# %% [markdown]
# ---
# ---

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df_option.corr(numeric_only=True),cmap='viridis',annot=True)

# %%
df_option.Target_std.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#sns.catplot(x='OP_EXP',y='Target_std',data=df_option, kind='box')

# %%
df_option.reset_index(inplace=True)

# %% [markdown]
# ## Splitting the Data

# %%
# spread or Std model

# %%
# X = df_option.drop(['Date_Only','Target_std','Target_spread'], axis=1)  
# #y = df_option['Target_std']
# y = df_option['Target_spread']

# %%
X = df_option.drop(['Date_Only','Target_std','Target_spread'], axis=1)  
#y = df_option['Target_std']
y = df_option['Target_std']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
X_train.columns
# Out:
# Index(['prior_std', 'prior_Vol', 'prior_spread', 'prior_range', 'cut_open',
#        'cut_1hr', 'cut_2hr', 'cut_3hr', 'vix_prior_std', 'vix_pr_spread',
#        'vix_prior_range', 'vix_cut_open', 'vix_cut_1hr', 'vix_cut_2hr',
#        'vix_cut_3hr', 'tqqq_prior_std', 'tqqq_Vol', 'tqqq_pr_spread',
#        'tqqq_prior_range', 'tqqq_cut_open', 'tqqq_cut_1hr', 'tqqq_cut_2hr',
#        'tqqq_cut_3hr'],
#       dtype='object')

# %%
X_train.shape
# Out:
# (230, 23)

# %%
y_train.shape
# Out:
# (230,)

# %% [markdown]
# ## Evaluation Run Model with the Data

# %%
def run_model(model,X_train,y_train,X_test,y_test):
    
    # Fit Model
    model.fit(X_train,y_train)
    
    # Get Metrics
    
    preds = model.predict(X_test)
    
    mae = mean_absolute_error(y_test,preds)
    print(f'mae : {mae}')
   
    
    plt.figure(figsize=(12,8),dpi=200)
    plt.scatter(y_test, preds)
    plt.plot(y_test, y_test, color='green', linestyle='dashed')
    plt.xlabel('real_std')

    return model

# %%
# Define the parameter grid for GridSearchCV
dt_regressor = DecisionTreeRegressor()

param_grid = {
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 3, 5],
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson']
}

# %%
grid_search = GridSearchCV(
    estimator=dt_regressor,  # The model to tune
    param_grid=param_grid,  # The parameter grid
    scoring='neg_root_mean_squared_error',  # Or other relevant scoring metric
    cv=10,  # Number of cross-validation folds
    verbose=2,  # Show progress
    n_jobs=-1  # Use all available cores
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [3, 5, 7], 'min_samples_leaf': [1, 3, 5],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='neg_root_mean_squared_error', verbose=2)

# %%
# Get the best parameters
best_params_tr = grid_search.best_params_
print("Best parameters:", best_params_tr)

# Get the best model
best_model_tr = grid_search.best_estimator_
# Out:
# Best parameters: {'criterion': 'absolute_error', 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 2}

# %%
run_model(best_model_tr,X_train, y_train, X_test, y_test)
# Out:
# mae : 0.23519507395953515
# DecisionTreeRegressor(criterion='absolute_error', max_depth=5,
#                       min_samples_leaf=3)

# %%
pd.DataFrame(index=X.columns, data = best_model_tr.feature_importances_, columns=['features'])

# %%
# import joblib
# # Assuming 'model' is your trained model object
# filename = 'tr_model_beta_33.joblib'
# joblib.dump(best_model_tr, filename)

# %%
### Default Decison Tree model

# %%
dt_regressor_default = DecisionTreeRegressor()

# %%
dt_model = run_model(dt_regressor_default,X_train, y_train, X_test, y_test)
# Out:
# mae : 0.3378358803603019

# %%
## RF Grid Search

# %%
# Define the parameter grid to search
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [5, 10, 15, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Instantiate the Random Forest Regressor
rf = RandomForestRegressor(random_state=42)

# Instantiate GridSearchCV
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=10, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit GridSearchCV to the training data
grid_search.fit(X_train, y_train)

# Print the best parameters and the best score
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# Evaluate the best model on the test set
rf_best_model = grid_search.best_estimator_
y_pred = rf_best_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error on test set:", mse)
# Out:
# Best parameters: {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Best score: -0.10272407657436547
# Mean Squared Error on test set: 0.11728463689211242

# %%
pd.DataFrame(index=X.columns,data=rf_best_model.feature_importances_,columns=['Feature Importance'])
# Out:
#                   Feature Importance
# prior_std                   0.034466
# prior_Vol                   0.087529
# prior_spread                0.019400
# prior_range                 0.018919
# cut_open                    0.035773
# cut_1hr                     0.030994
# cut_2hr                     0.013717
# cut_3hr                     0.013097
# vix_prior_std               0.015982
# vix_pr_spread               0.021541
# vix_prior_range             0.013116
# vix_cut_open                0.062674
# vix_cut_1hr                 0.156260
# vix_cut_2hr                 0.117015
# vix_cut_3hr                 0.100765
# tqqq_prior_std              0.016767
# tqqq_Vol                    0.035869
# tqqq_pr_spread              0.038061
# tqqq_prior_range            0.025020
# tqqq_cut_open               0.018022
# tqqq_cut_1hr                0.081394
# tqqq_cut_2hr                0.026858
# tqqq_cut_3hr                0.016763

# %%
import joblib
# Assuming 'model' is your trained model object
filename = 'rf_model.joblib'
joblib.dump(rf_best_model, filename)

# To load the model later:
#loaded_model = joblib.load(filename)

# %%
run_model(rf_best_model,X_train, y_train, X_test, y_test)
# Out:
# mae : 0.22834014274619535
# RandomForestRegressor(max_depth=20, min_samples_split=5, random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 3, 5],
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson']
}

# Instantiate Decision Tree Regressor
tree = DecisionTreeRegressor(random_state=10)

# Instantiate Grid Search
grid_search = GridSearchCV(estimator=tree, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')

# Fit Grid Search
grid_search.fit(X_train, y_train)

# Best parameters and score
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# Get the best model
best_tree = grid_search.best_estimator_

# Evaluate the best model on the test set (optional)
test_score = best_tree.score(X_test, y_test)
print("Test score:", test_score)
# Out:
# Best parameters: {'criterion': 'absolute_error', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Best score: -0.12242254323335744
# Test score: -0.5691935197590865

# %%
best_tree.feature_importances_
# Out:
# array([0.        , 0.13634241, 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.11656854,
#        0.        , 0.        , 0.        , 0.13255284, 0.        ,
#        0.        , 0.21015298, 0.40438323, 0.        , 0.        ,
#        0.        , 0.        , 0.        ])

# %%
pd.DataFrame(index=X.columns,data=best_tree.feature_importances_,columns=['Feature Importance'])
# Out:
#                   Feature Importance
# prior_std                   0.000000
# prior_Vol                   0.136342
# prior_spread                0.000000
# prior_range                 0.000000
# cut_open                    0.000000
# cut_1hr                     0.000000
# cut_2hr                     0.000000
# cut_3hr                     0.000000
# vix_prior_std               0.000000
# vix_pr_spread               0.116569
# vix_prior_range             0.000000
# vix_cut_open                0.000000
# vix_cut_1hr                 0.000000
# vix_cut_2hr                 0.132553
# vix_cut_3hr                 0.000000
# tqqq_prior_std              0.000000
# tqqq_Vol                    0.210153
# tqqq_pr_spread              0.404383
# tqqq_prior_range            0.000000
# tqqq_cut_open               0.000000
# tqqq_cut_1hr                0.000000
# tqqq_cut_2hr                0.000000
# tqqq_cut_3hr                0.000000

# %%
run_model(best_tree,X_train, y_train, X_test, y_test)
# Out:
# mae : 0.2680596314864141
# DecisionTreeRegressor(criterion='absolute_error', max_depth=3,
#                       min_samples_split=5, random_state=10)

# %%
filename = 'btr_model_36.joblib'
joblib.dump(best_tree, filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 filename = 'btr_model_36.joblib'
# ----> 2 joblib.dump(best_tree, filename)
#
# NameError: name 'joblib' is not defined

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(16,16))
plot_tree(best_tree);

# %% [markdown]
# ----
#
# ## KNN Regression

# %%
def run_model(model,X_train,y_train,X_test,y_test):
    
    # Fit Model
    model.fit(X_train,y_train)
    
    # Get Metrics
    
    preds = model.predict(X_test)
    
    mae = mean_absolute_error(y_test,preds)
    print(f'mae : {mae}')
   
    
    plt.figure(figsize=(12,8),dpi=200)
    plt.scatter(y_test, preds)
    plt.xlabel('real_std')

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
preds = {}
k_values = [3,4,5,6]
for n in k_values:
    
    model = KNeighborsRegressor(n_neighbors=n)
    run_model(model,X_train,y_train,X_test,y_test)
# Out:
# C:\Users\jepar\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\jepar\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\jepar\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jepar\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\jepar\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# mae : 0.2959628925604701
# mae : 0.2943429292150564
# mae : 0.28166765574616975
# mae : 0.27281169774602904

# %%
model = KNeighborsRegressor(n_neighbors=5)
run_model(model,X_train,y_train,X_test,y_test)

# %% [markdown]
# ---
# ## Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

run_model(model,X_train,y_train,X_test,y_test)

# %%
model.get_n_leaves()

# %% [markdown]
# ----
#
# ## Support Vector Regression

# %%
from sklearn.svm import SVR

# %%
from sklearn.model_selection import GridSearchCV

# %%
scaler = StandardScaler()
sc_X_train = scaler.fit_transform(X_train)
sc_X_test = scaler.transform(X_test)

# %%
param_grid = {'C':[0.01,0.1,1,5,10,100,1000],'gamma':['auto','scale']}
svr = SVR()

# %%
grid = GridSearchCV(svr,param_grid)

# %%
run_model(grid,sc_X_train,y_train,sc_X_test,y_test)
# Out:
# mae : 0.23015260812676822

# %%
scaler_filename = "scaler4svr.save"
joblib.dump(scaler, scaler_filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 scaler_filename = "scaler4svr.save"
# ----> 2 joblib.dump(scaler, scaler_filename)
#
# NameError: name 'joblib' is not defined

# %%
SVR_model = grid.best_estimator_

# %%
filename = 'SVR_model_35.joblib'
joblib.dump(SVR_model, filename)

# %% [markdown]
# ---
#
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# help(RandomForestRegressor)

# %%
trees = [10,50,100]
for n in trees:
    
    model = RandomForestRegressor(n_estimators=n)
    
    run_model(model,X_train,y_train,X_test,y_test)
# Out:
# mae : 0.2497756141679281
# mae : 0.2377695092575982
# mae : 0.23786036213768588

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
# help(GradientBoostingRegressor)

# %%
   
model = GradientBoostingRegressor()

run_model(model,X_train,y_train,X_test,y_test)
# Out:
# mae : 0.23351933895624166

# %% [markdown]
# ## Adaboost

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
model = GradientBoostingRegressor()

run_model(model,X_train,y_train,X_test,y_test)
# Out:
# mae : 0.23452108693300558

# %%
## XGBOOST

# %%
# !pip install xgboost

# %%
import xgboost as xgb
# Define the parameter grid to search
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 4, 5],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.6, 0.7, 0.8]
}

# Initialize XGBoost regressor
xgbr = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=xgbr,
                           param_grid=param_grid,
                           scoring='neg_mean_squared_error',
                           cv=10,
                           verbose=0,
                          n_jobs=-1)

# Fit GridSearchCV
grid_search.fit(X_train, y_train)

# Print best parameters and score
print("Best parameters:", grid_search.best_params_)
print("Best score:", np.sqrt(-grid_search.best_score_))

# Evaluate the best model on the test set
best_xgb_model = grid_search.best_estimator_
y_pred = best_xgb_model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("Test RMSE:", rmse)
# Out:
# Best parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.7}
# Best score: 0.32784942950963003
# Test RMSE: 0.3810682338362912

# %%
run_model(best_xgb_model,X_train,y_train,X_test,y_test)
# Out:
# mae : 0.26140600932650443

# %%
plt.plot(y_test, y_test)

# %%
pd.DataFrame(index=X.columns,data=best_xgb_model.feature_importances_,columns=['Feature Importance'])

# %%
import joblib
# Assuming 'model' is your trained model object
filename = 'xgb_model_w_all_std.joblib'
joblib.dump(best_xgb_model, filename)

# %% [markdown]
# ----
