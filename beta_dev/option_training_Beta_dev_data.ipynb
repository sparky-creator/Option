# %%
import os
import numpy as np
import pandas as pd
from datetime import datetime, date, timedelta, time
os.environ['TZ'] ='America/New_York'

import yfinance as yf

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

from ib_async import *
util.startLoop()

# %% [markdown]
# ### Data Prep for Inferencing

# %%
ib = IB()
ib.connect(port=4002, clientId=3)
# Out:
# <IB connected to 127.0.0.1:4002 clientId=3>

# %%
contract = Contract(symbol='META', secType='STK', exchange='SMART', currency='USD')
ib.qualifyContracts(contract)
# Out:
# [Contract(secType='STK', conId=107113386, symbol='META', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='META', tradingClass='NMS')]

# %%
contract_vix = Contract(symbol= 'VIX', secType = 'IND',exchange = 'CBOE', currency='USD')
ib.qualifyContracts(contract_vix)
# Out:
# [Contract(secType='IND', conId=13455763, symbol='VIX', exchange='CBOE', currency='USD', localSymbol='VIX')]

# %%
contract_nas = Contract(symbol= 'TQQQ', secType = 'STK',exchange = 'SMART', currency='USD')
ib.qualifyContracts(contract_nas)
# Out:
# [Contract(secType='STK', conId=72539702, symbol='TQQQ', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='TQQQ', tradingClass='NMS')]

# %%
class Data_Request :

    """
    Returns PD data containning equity price with specific time control

    Returns:
        pd: information regarding the contract of interst.
    """
    
    def __init__(self, list_days, contract, barsize, duration, *,specific_time= None, specific_pick_time= None):

        self.list_days = list_days
        self.contract = contract
        #self.init_date = init_date
        self.barsize = barsize
        self.duration = duration
        self.specific_time = specific_time # cut off time . Time object: time(14, 30, 0)
        self.specific_pick_time= specific_pick_time

    def D_request(self):

        his_df =pd.DataFrame()
        
        for i in range(len(self.list_days)):
            init_date=self.list_days[i]
            bars = ib.reqHistoricalData(self.contract, init_date, barSizeSetting=self.barsize, durationStr=self.duration, whatToShow="TRADES", useRTH=True)
            add_his_df = pd.DataFrame(bars)
            add_his_df['date'] = pd.to_datetime(add_his_df['date'])
            print(f'retriveing data for {init_date}')

            if self.specific_time is not None:
                cut_off = datetime.combine(self.list_days[i],self.specific_time)  # need logic if specific_time is defined
                pd_cut_off = pd.to_datetime(cut_off).tz_localize('US/Eastern')
            #datetime64_eastern = pd.Timestamp(date_time_str).tz_localize('US/Eastern')
                add_his_df = add_his_df[add_his_df['date'] > pd_cut_off]
            
            if self.specific_pick_time is not None:
                pick_time = datetime.combine(self.list_days[i],self.specific_pick_time)  # need logic if specific_time is defined
                pd_pick_time = pd.to_datetime(pick_time).tz_localize('US/Eastern')
            #datetime64_eastern = pd.Timestamp(date_time_str).tz_localize('US/Eastern')
                add_his_df = add_his_df[add_his_df['date'] == pd_pick_time]

            
            his_df = pd.concat([his_df, add_his_df], ignore_index=True)
            his_df['Date_Only'] = his_df['date'].dt.date
            print(len(his_df))

        
        return his_df

# %%
# picking out Friday and before specific-time data

#specific_time = time(14, 30, 0)
def data_filter(df_initial, list_days, specific_time_before = None, specific_time_after= None, on_time= None):
    his_df = pd.DataFrame()
    for i in range(len(list_days)):
        init_date=list_days[i]
        if specific_time_before is not None:
            add_his_df = df_initial[(df_initial['date'].dt.date == init_date) & (df_initial['date'].dt.time < specific_time_before)]
           
            
        if specific_time_after is not None:
            add_his_df = df_initial[(df_initial['date'].dt.date == init_date) & (df_initial['date'].dt.time >= specific_time_after)]

        if on_time is not None:
            add_his_df = df_initial[(df_initial['date'].dt.date == init_date) & (df_initial['date'].dt.time == on_time)]

        if (specific_time_before is None and specific_time_after is None) and on_time is None:
            add_his_df = df_initial[(df_initial['date'].dt.date == init_date)]
        
        print(len(his_df))
        print(f'retrieving {init_date}')
        per_proc = np.round(i+1/len(list_days)*100, decimals=1)
        print(f'{per_proc} percent is done')
        his_df = pd.concat([his_df, add_his_df], ignore_index=True)
        his_df.drop_duplicates(subset=None, keep='first', inplace=True)
        his_df['Date_Only'] = his_df['date'].dt.date
    return his_df

# %%
from datetime import date, timedelta

def calculate_business_days(start_date, end_date):
    """
    Calculates the number of business days between two dates, excluding weekends.

    Args:
        start_date (date): The start date.
        end_date (date): The end date.

    Returns:
        int: The number of business days.
    """
    business_days = 0
    current_date = start_date
    while current_date <= end_date:
        if current_date.weekday() < 5:  # Monday to Friday
            business_days += 1
        current_date += timedelta(days=1)
    return business_days

# Example usage:
start_date = date(2025, 2, 1)  # April 7, 2025 (Monday)
end_date = date(2025, 4, 3)  # April 18, 2025 (Friday)
num_business_days = calculate_business_days(start_date, end_date)
print(f"Number of business days between {start_date} and {end_date}: {num_business_days}")
# Out:
# Number of business days between 2025-02-01 and 2025-04-03: 44

# %%
def get_fridays_in_range(start_date, end_date):
    """
    Returns a list of dates that are Fridays within the given date range.

    Args:
        start_date (date): The start date of the range.
        end_date (date): The end date of the range.

    Returns:
        list: A list of date objects representing Fridays within the range.
    """
    fridays = []
    all_dates = []
    current_date = start_date
    all_current_date = start_date

    # Adjust to the first Friday
    days_until_friday = (4 - current_date.weekday()) % 7
    current_date += timedelta(days=days_until_friday)

    while current_date <= end_date:
        fridays.append(current_date)
        current_date += timedelta(days=7) # Move to the next Friday

    while all_current_date <= end_date:
        all_dates.append(all_current_date)
        all_current_date += timedelta(days=1)
    
    return fridays, all_dates

# Example Usage
start_date = date(2024, 2, 1)
end_date = date(2025, 4, 1)

fridays, all_dates = get_fridays_in_range(start_date, end_date)
# removing Non-trading Holidays

fridays.remove(date(2024, 3, 29))
fridays.remove(date(2024, 11, 29))

#all_dates.remove(date(2024, 1, 15))
all_dates.remove(date(2024, 2, 19))
all_dates.remove(date(2024, 3, 29))
all_dates.remove(date(2024, 5, 27))
all_dates.remove(date(2024, 6, 19))
all_dates.remove(date(2024, 7, 4))
all_dates.remove(date(2024, 9, 2))
all_dates.remove(date(2024, 11, 28))
all_dates.remove(date(2024, 11, 29))
all_dates.remove(date(2024, 12, 25))

all_dates.remove(date(2025, 1, 1))
all_dates.remove(date(2025, 1, 20))
all_dates.remove(date(2025, 2, 17))

# Wednesday, January 1, 2025: New Year's Day
# Monday, January 20, 2025: Martin Luther King Jr. Day
# Monday, February 17, 2025: Presidents' Day
# Friday, April 18, 2025: Good Friday
# Monday, May 26, 2025: Memorial Day
# Thursday, June 19, 2025: Juneteenth National Independence Day
# Friday, July 4, 2025: Independence Day
# Monday, September 1, 2025: Labor Day
# Thursday, November 27, 2025: Thanksgiving Day
# Thursday, December 25, 2025: Christmas Day

# %%
biz_dates = [ d for d in all_dates if d.weekday()<5]

# %%
now =datetime.now()
print(now.date())
# Out:
# 2025-04-03

# %% [markdown]
# ### Trainning Data Set Collection ###

# %%
barsize ="1 min"
duration = "1 D"
DR_stock_meta = Data_Request(biz_dates, contract, barsize, duration)
df_all_days_stock = DR_stock_meta.D_request()
# Out:
# retriveing data for 2024-02-01
# 390
# retriveing data for 2024-02-02
# 780
# retriveing data for 2024-02-05
# 1170
# retriveing data for 2024-02-06
# 1560
# retriveing data for 2024-02-07
# 1950
# retriveing data for 2024-02-08
# 2340
# retriveing data for 2024-02-09
# 2730
# retriveing data for 2024-02-12
# 3120
# retriveing data for 2024-02-13
# 3510
# retriveing data for 2024-02-14
# 3900
# retriveing data for 2024-02-15
# 4290
# retriveing data for 2024-02-16
# 4680
# retriveing data for 2024-02-20
# 5070
# retriveing data for 2024-02-21
# 5460
# retriveing data for 2024-02-22
# 5850
# retriveing data for 2024-02-23
# 6240
# retriveing data for 2024-02-26
# 6630
# retriveing data for 2024-02-27
# 7020
# retriveing data for 2024-02-28
# 7410
# retriveing data for 2024-02-29
# 7800
# retriveing data for 2024-03-01
# 8190
# retriveing data for 2024-03-04
# 8580
# retriveing data for 2024-03-05
# 8970
# retriveing data for 2024-03-06
# 9360
# retriveing data for 2024-03-07
# 9750
# retriveing data for 2024-03-08
# 10140
# retriveing data for 2024-03-11
# 10530
# retriveing data for 2024-03-12
# 10920
# retriveing data for 2024-03-13
# 11310
# retriveing data for 2024-03-14
# 11700
# retriveing data for 2024-03-15
# 12090
# retriveing data for 2024-03-18
# 12480
# retriveing data for 2024-03-19
# 12870
# retriveing data for 2024-03-20
# 13260
# retriveing data for 2024-03-21
# 13650
# retriveing data for 2024-03-22
# 14040
# retriveing data for 2024-03-25
# 14430
# retriveing data for 2024-03-26
# 14820
# retriveing data for 2024-03-27
# 15210
# retriveing data for 2024-03-28
# 15600
# retriveing data for 2024-04-01
# 15990
# retriveing data for 2024-04-02
# 16380
# retriveing data for 2024-04-03
# 16770
# retriveing data for 2024-04-04
# 17160
# retriveing data for 2024-04-05
# 17550
# retriveing data for 2024-04-08
# 17940
# retriveing data for 2024-04-09
# 18330
# retriveing data for 2024-04-10
# 18720
# retriveing data for 2024-04-11
# 19110
# retriveing data for 2024-04-12
# 19500
# retriveing data for 2024-04-15
# 19890
# retriveing data for 2024-04-16
# 20280
# retriveing data for 2024-04-17
# 20670
# retriveing data for 2024-04-18
# 21060
# retriveing data for 2024-04-19
# 21450
# retriveing data for 2024-04-22
# 21840
# retriveing data for 2024-04-23
# 22230
# retriveing data for 2024-04-24
# 22620
# retriveing data for 2024-04-25
# 23010
# retriveing data for 2024-04-26
# 23400
# retriveing data for 2024-04-29
# 23790
# retriveing data for 2024-04-30
# 24180
# retriveing data for 2024-05-01
# 24570
# retriveing data for 2024-05-02
# 24960
# retriveing data for 2024-05-03
# 25350
# retriveing data for 2024-05-06
# 25740
# retriveing data for 2024-05-07
# 26130
# retriveing data for 2024-05-08
# 26520
# retriveing data for 2024-05-09
# 26910
# retriveing data for 2024-05-10
# 27300
# retriveing data for 2024-05-13
# 27690
# retriveing data for 2024-05-14
# 28080
# retriveing data for 2024-05-15
# 28470
# retriveing data for 2024-05-16
# 28860
# retriveing data for 2024-05-17
# 29250
# retriveing data for 2024-05-20
# 29640
# retriveing data for 2024-05-21
# 30030
# retriveing data for 2024-05-22
# 30420
# retriveing data for 2024-05-23
# 30810
# retriveing data for 2024-05-24
# 31200
# retriveing data for 2024-05-28
# 31590
# retriveing data for 2024-05-29
# 31980
# retriveing data for 2024-05-30
# 32370
# retriveing data for 2024-05-31
# 32760
# retriveing data for 2024-06-03
# 33150
# retriveing data for 2024-06-04
# 33540
# retriveing data for 2024-06-05
# 33930
# retriveing data for 2024-06-06
# 34320
# retriveing data for 2024-06-07
# 34710
# retriveing data for 2024-06-10
# 35100
# retriveing data for 2024-06-11
# 35490
# retriveing data for 2024-06-12
# 35880
# retriveing data for 2024-06-13
# 36270
# retriveing data for 2024-06-14
# 36660
# retriveing data for 2024-06-17
# 37050
# retriveing data for 2024-06-18
# 37440
# retriveing data for 2024-06-20
# 37830
# retriveing data for 2024-06-21
# 38220
# retriveing data for 2024-06-24
# 38610
# retriveing data for 2024-06-25
# 39000
# retriveing data for 2024-06-26
# 39390
# retriveing data for 2024-06-27
# 39780
# retriveing data for 2024-06-28
# 40170
# retriveing data for 2024-07-01
# 40560
# retriveing data for 2024-07-02
# 40950
# retriveing data for 2024-07-03
# 41160
# retriveing data for 2024-07-05
# 41550
# retriveing data for 2024-07-08
# 41940
# retriveing data for 2024-07-09
# 42330
# retriveing data for 2024-07-10
# 42720
# retriveing data for 2024-07-11
# 43110
# retriveing data for 2024-07-12
# 43500
# retriveing data for 2024-07-15
# 43890
# retriveing data for 2024-07-16
# 44280
# retriveing data for 2024-07-17
# 44670
# retriveing data for 2024-07-18
# 45060
# retriveing data for 2024-07-19
# 45450
# retriveing data for 2024-07-22
# 45840
# retriveing data for 2024-07-23
# 46230
# retriveing data for 2024-07-24
# 46620
# retriveing data for 2024-07-25
# 47010
# retriveing data for 2024-07-26
# 47400
# retriveing data for 2024-07-29
# 47790
# retriveing data for 2024-07-30
# 48180
# retriveing data for 2024-07-31
# 48570
# retriveing data for 2024-08-01
# 48960
# retriveing data for 2024-08-02
# 49350
# retriveing data for 2024-08-05
# 49740
# retriveing data for 2024-08-06
# 50130
# retriveing data for 2024-08-07
# 50520
# retriveing data for 2024-08-08
# 50910
# retriveing data for 2024-08-09
# 51300
# retriveing data for 2024-08-12
# 51690
# retriveing data for 2024-08-13
# 52080
# retriveing data for 2024-08-14
# 52470
# retriveing data for 2024-08-15
# 52860
# retriveing data for 2024-08-16
# 53250
# retriveing data for 2024-08-19
# 53640
# retriveing data for 2024-08-20
# 54030
# retriveing data for 2024-08-21
# 54420
# retriveing data for 2024-08-22
# 54810
# retriveing data for 2024-08-23
# 55200
# retriveing data for 2024-08-26
# 55590
# retriveing data for 2024-08-27
# 55980
# retriveing data for 2024-08-28
# 56370
# retriveing data for 2024-08-29
# 56760
# retriveing data for 2024-08-30
# 57150
# retriveing data for 2024-09-03
# 57540
# retriveing data for 2024-09-04
# 57930
# retriveing data for 2024-09-05
# 58320
# retriveing data for 2024-09-06
# 58710
# retriveing data for 2024-09-09
# 59100
# retriveing data for 2024-09-10
# 59490
# retriveing data for 2024-09-11
# 59880
# retriveing data for 2024-09-12
# 60270
# retriveing data for 2024-09-13
# 60660
# retriveing data for 2024-09-16
# 61050
# retriveing data for 2024-09-17
# 61440
# retriveing data for 2024-09-18
# 61830
# retriveing data for 2024-09-19
# 62220
# retriveing data for 2024-09-20
# 62610
# retriveing data for 2024-09-23
# 63000
# retriveing data for 2024-09-24
# 63390
# retriveing data for 2024-09-25
# 63780
# retriveing data for 2024-09-26
# 64170
# retriveing data for 2024-09-27
# 64560
# retriveing data for 2024-09-30
# 64950
# retriveing data for 2024-10-01
# 65340
# retriveing data for 2024-10-02
# 65730
# retriveing data for 2024-10-03
# 66120
# retriveing data for 2024-10-04
# 66510
# retriveing data for 2024-10-07
# 66900
# retriveing data for 2024-10-08
# 67290
# retriveing data for 2024-10-09
# 67680
# retriveing data for 2024-10-10
# 68070
# retriveing data for 2024-10-11
# 68460
# retriveing data for 2024-10-14
# 68850
# retriveing data for 2024-10-15
# 69240
# retriveing data for 2024-10-16
# 69630
# retriveing data for 2024-10-17
# 70020
# retriveing data for 2024-10-18
# 70410
# retriveing data for 2024-10-21
# 70800
# retriveing data for 2024-10-22
# 71190
# retriveing data for 2024-10-23
# 71580
# retriveing data for 2024-10-24
# 71970
# retriveing data for 2024-10-25
# 72360
# retriveing data for 2024-10-28
# 72750
# retriveing data for 2024-10-29
# 73140
# retriveing data for 2024-10-30
# 73530
# retriveing data for 2024-10-31
# 73920
# retriveing data for 2024-11-01
# 74310
# retriveing data for 2024-11-04
# 74700
# retriveing data for 2024-11-05
# 75090
# retriveing data for 2024-11-06
# 75480
# retriveing data for 2024-11-07
# 75870
# retriveing data for 2024-11-08
# 76260
# retriveing data for 2024-11-11
# 76650
# retriveing data for 2024-11-12
# 77040
# retriveing data for 2024-11-13
# 77430
# retriveing data for 2024-11-14
# 77820
# retriveing data for 2024-11-15
# 78210
# retriveing data for 2024-11-18
# 78600
# retriveing data for 2024-11-19
# 78990
# retriveing data for 2024-11-20
# 79380
# retriveing data for 2024-11-21
# 79770
# retriveing data for 2024-11-22
# 80160
# retriveing data for 2024-11-25
# 80550
# retriveing data for 2024-11-26
# 80940
# retriveing data for 2024-11-27
# 81330
# retriveing data for 2024-12-02
# 81720
# retriveing data for 2024-12-03
# 82110
# retriveing data for 2024-12-04
# 82500
# retriveing data for 2024-12-05
# 82890
# retriveing data for 2024-12-06
# 83280
# retriveing data for 2024-12-09
# 83670
# retriveing data for 2024-12-10
# 84060
# retriveing data for 2024-12-11
# 84450
# retriveing data for 2024-12-12
# 84840
# retriveing data for 2024-12-13
# 85230
# retriveing data for 2024-12-16
# 85620
# retriveing data for 2024-12-17
# 86010
# retriveing data for 2024-12-18
# 86400
# retriveing data for 2024-12-19
# 86790
# retriveing data for 2024-12-20
# 87180
# retriveing data for 2024-12-23
# 87570
# retriveing data for 2024-12-24
# 87780
# retriveing data for 2024-12-26
# 88170
# retriveing data for 2024-12-27
# 88560
# retriveing data for 2024-12-30
# 88950
# retriveing data for 2024-12-31
# 89340
# retriveing data for 2025-01-02
# 89730
# retriveing data for 2025-01-03
# 90120
# retriveing data for 2025-01-06
# 90510
# retriveing data for 2025-01-07
# 90900
# retriveing data for 2025-01-08
# 91290
# retriveing data for 2025-01-09
# 91680
# retriveing data for 2025-01-10
# 92070
# retriveing data for 2025-01-13
# 92460
# retriveing data for 2025-01-14
# 92850
# retriveing data for 2025-01-15
# 93240
# retriveing data for 2025-01-16
# 93630
# retriveing data for 2025-01-17
# 94020
# retriveing data for 2025-01-21
# 94410
# retriveing data for 2025-01-22
# 94800
# retriveing data for 2025-01-23
# 95190
# retriveing data for 2025-01-24
# 95580
# retriveing data for 2025-01-27
# 95970
# retriveing data for 2025-01-28
# 96360
# retriveing data for 2025-01-29
# 96750
# retriveing data for 2025-01-30
# 97140
# retriveing data for 2025-01-31
# 97530
# retriveing data for 2025-02-03
# 97920
# retriveing data for 2025-02-04
# 98310
# retriveing data for 2025-02-05
# 98700
# retriveing data for 2025-02-06
# 99090
# retriveing data for 2025-02-07
# 99480
# retriveing data for 2025-02-10
# 99870
# retriveing data for 2025-02-11
# 100260
# retriveing data for 2025-02-12
# 100650
# retriveing data for 2025-02-13
# 101040
# retriveing data for 2025-02-14
# 101430
# retriveing data for 2025-02-18
# 101820
# retriveing data for 2025-02-19
# 102210
# retriveing data for 2025-02-20
# 102600
# retriveing data for 2025-02-21
# 102990
# retriveing data for 2025-02-24
# 103380
# retriveing data for 2025-02-25
# 103770
# retriveing data for 2025-02-26
# 104160
# retriveing data for 2025-02-27
# 104550
# retriveing data for 2025-02-28
# 104940
# retriveing data for 2025-03-03
# 105330
# retriveing data for 2025-03-04
# 105720
# retriveing data for 2025-03-05
# 106110
# retriveing data for 2025-03-06
# 106500
# retriveing data for 2025-03-07
# 106890
# retriveing data for 2025-03-10
# 107280
# retriveing data for 2025-03-11
# 107670
# retriveing data for 2025-03-12
# 108060
# retriveing data for 2025-03-13
# 108450
# retriveing data for 2025-03-14
# 108840
# retriveing data for 2025-03-17
# 109230
# retriveing data for 2025-03-18
# 109620
# retriveing data for 2025-03-19
# 110010
# retriveing data for 2025-03-20
# 110400
# retriveing data for 2025-03-21
# 110790
# retriveing data for 2025-03-24
# 111180
# retriveing data for 2025-03-25
# 111570
# retriveing data for 2025-03-26
# 111960
# retriveing data for 2025-03-27
# 112350
# retriveing data for 2025-03-28
# 112740
# retriveing data for 2025-03-31
# 113130
# retriveing data for 2025-04-01
# 113520

# %%
DR_IND_VIX = Data_Request(biz_dates, contract_vix, barsize, duration)
DR_STK_TQQQ = Data_Request(biz_dates, contract_nas, barsize, duration)
df_all_days_VIX = DR_IND_VIX.D_request()
# Out:
# retriveing data for 2024-02-01
# 810
# retriveing data for 2024-02-02
# 1620
# retriveing data for 2024-02-05
# 2430
# retriveing data for 2024-02-06
# 3240
# retriveing data for 2024-02-07
# 4050
# retriveing data for 2024-02-08
# 4860
# retriveing data for 2024-02-09
# 5670
# retriveing data for 2024-02-12
# 6480
# retriveing data for 2024-02-13
# 7290
# retriveing data for 2024-02-14
# 8100
# retriveing data for 2024-02-15
# 8910
# retriveing data for 2024-02-16
# 9720
# retriveing data for 2024-02-20
# 10530
# retriveing data for 2024-02-21
# 11340
# retriveing data for 2024-02-22
# 12150
# retriveing data for 2024-02-23
# 12960
# retriveing data for 2024-02-26
# 13770
# retriveing data for 2024-02-27
# 14580
# retriveing data for 2024-02-28
# 15390
# retriveing data for 2024-02-29
# 16200
# retriveing data for 2024-03-01
# 17010
# retriveing data for 2024-03-04
# 17820
# retriveing data for 2024-03-05
# 18630
# retriveing data for 2024-03-06
# 19440
# retriveing data for 2024-03-07
# 20250
# retriveing data for 2024-03-08
# 21060
# retriveing data for 2024-03-11
# 21870
# retriveing data for 2024-03-12
# 22680
# retriveing data for 2024-03-13
# 23490
# retriveing data for 2024-03-14
# 24300
# retriveing data for 2024-03-15
# 25110
# retriveing data for 2024-03-18
# 25920
# retriveing data for 2024-03-19
# 26730
# retriveing data for 2024-03-20
# 27540
# retriveing data for 2024-03-21
# 28350
# retriveing data for 2024-03-22
# 29160
# retriveing data for 2024-03-25
# 29970
# retriveing data for 2024-03-26
# 30780
# retriveing data for 2024-03-27
# 31590
# retriveing data for 2024-03-28
# 32400
# retriveing data for 2024-04-01
# 33210
# retriveing data for 2024-04-02
# 34020
# retriveing data for 2024-04-03
# 34830
# retriveing data for 2024-04-04
# 35640
# retriveing data for 2024-04-05
# 36450
# retriveing data for 2024-04-08
# 37260
# retriveing data for 2024-04-09
# 38070
# retriveing data for 2024-04-10
# 38880
# retriveing data for 2024-04-11
# 39690
# retriveing data for 2024-04-12
# 40500
# retriveing data for 2024-04-15
# 41310
# retriveing data for 2024-04-16
# 42120
# retriveing data for 2024-04-17
# 42930
# retriveing data for 2024-04-18
# 43740
# retriveing data for 2024-04-19
# 44550
# retriveing data for 2024-04-22
# 45360
# retriveing data for 2024-04-23
# 46170
# retriveing data for 2024-04-24
# 46980
# retriveing data for 2024-04-25
# 47790
# retriveing data for 2024-04-26
# 48600
# retriveing data for 2024-04-29
# 49410
# retriveing data for 2024-04-30
# 50220
# retriveing data for 2024-05-01
# 51030
# retriveing data for 2024-05-02
# 51840
# retriveing data for 2024-05-03
# 52650
# retriveing data for 2024-05-06
# 53460
# retriveing data for 2024-05-07
# 54270
# retriveing data for 2024-05-08
# 55080
# retriveing data for 2024-05-09
# 55890
# retriveing data for 2024-05-10
# 56700
# retriveing data for 2024-05-13
# 57510
# retriveing data for 2024-05-14
# 58320
# retriveing data for 2024-05-15
# 59130
# retriveing data for 2024-05-16
# 59940
# retriveing data for 2024-05-17
# 60750
# retriveing data for 2024-05-20
# 61560
# retriveing data for 2024-05-21
# 62370
# retriveing data for 2024-05-22
# 63180
# retriveing data for 2024-05-23
# 63990
# retriveing data for 2024-05-24
# 64800
# retriveing data for 2024-05-28
# 65610
# retriveing data for 2024-05-29
# 66420
# retriveing data for 2024-05-30
# 67230
# retriveing data for 2024-05-31
# 68040
# retriveing data for 2024-06-03
# 68850
# retriveing data for 2024-06-04
# 69660
# retriveing data for 2024-06-05
# 70470
# retriveing data for 2024-06-06
# 71280
# retriveing data for 2024-06-07
# 72090
# retriveing data for 2024-06-10
# 72900
# retriveing data for 2024-06-11
# 73710
# retriveing data for 2024-06-12
# 74520
# retriveing data for 2024-06-13
# 75330
# retriveing data for 2024-06-14
# 76140
# retriveing data for 2024-06-17
# 76950
# retriveing data for 2024-06-18
# 77760
# retriveing data for 2024-06-20
# 78570
# retriveing data for 2024-06-21
# 79380
# retriveing data for 2024-06-24
# 80190
# retriveing data for 2024-06-25
# 81000
# retriveing data for 2024-06-26
# 81810
# retriveing data for 2024-06-27
# 82620
# retriveing data for 2024-06-28
# 83430
# retriveing data for 2024-07-01
# 84240
# retriveing data for 2024-07-02
# 85050
# retriveing data for 2024-07-03
# 85633
# retriveing data for 2024-07-05
# 86443
# retriveing data for 2024-07-08
# 87253
# retriveing data for 2024-07-09
# 88063
# retriveing data for 2024-07-10
# 88873
# retriveing data for 2024-07-11
# 89683
# retriveing data for 2024-07-12
# 90493
# retriveing data for 2024-07-15
# 91303
# retriveing data for 2024-07-16
# 92113
# retriveing data for 2024-07-17
# 92923
# retriveing data for 2024-07-18
# 93733
# retriveing data for 2024-07-19
# 94543
# retriveing data for 2024-07-22
# 95353
# retriveing data for 2024-07-23
# 96163
# retriveing data for 2024-07-24
# 96973
# retriveing data for 2024-07-25
# 97783
# retriveing data for 2024-07-26
# 98593
# retriveing data for 2024-07-29
# 99403
# retriveing data for 2024-07-30
# 100213
# retriveing data for 2024-07-31
# 101023
# retriveing data for 2024-08-01
# 101833
# retriveing data for 2024-08-02
# 102643
# retriveing data for 2024-08-05
# 103453
# retriveing data for 2024-08-06
# 104263
# retriveing data for 2024-08-07
# 105073
# retriveing data for 2024-08-08
# 105883
# retriveing data for 2024-08-09
# 106693
# retriveing data for 2024-08-12
# 107503
# retriveing data for 2024-08-13
# 108313
# retriveing data for 2024-08-14
# 109123
# retriveing data for 2024-08-15
# 109933
# retriveing data for 2024-08-16
# 110743
# retriveing data for 2024-08-19
# 111553
# retriveing data for 2024-08-20
# 112363
# retriveing data for 2024-08-21
# 113173
# retriveing data for 2024-08-22
# 113983
# retriveing data for 2024-08-23
# 114793
# retriveing data for 2024-08-26
# 115603
# retriveing data for 2024-08-27
# 116413
# retriveing data for 2024-08-28
# 117223
# retriveing data for 2024-08-29
# 118033
# retriveing data for 2024-08-30
# 118843
# retriveing data for 2024-09-03
# 119653
# retriveing data for 2024-09-04
# 120463
# retriveing data for 2024-09-05
# 121273
# retriveing data for 2024-09-06
# 122083
# retriveing data for 2024-09-09
# 122893
# retriveing data for 2024-09-10
# 123703
# retriveing data for 2024-09-11
# 124513
# retriveing data for 2024-09-12
# 125323
# retriveing data for 2024-09-13
# 126133
# retriveing data for 2024-09-16
# 126943
# retriveing data for 2024-09-17
# 127753
# retriveing data for 2024-09-18
# 128563
# retriveing data for 2024-09-19
# 129373
# retriveing data for 2024-09-20
# 130183
# retriveing data for 2024-09-23
# 130993
# retriveing data for 2024-09-24
# 131803
# retriveing data for 2024-09-25
# 132613
# retriveing data for 2024-09-26
# 133423
# retriveing data for 2024-09-27
# 134233
# retriveing data for 2024-09-30
# 135043
# retriveing data for 2024-10-01
# 135853
# retriveing data for 2024-10-02
# 136663
# retriveing data for 2024-10-03
# 137473
# retriveing data for 2024-10-04
# 138283
# retriveing data for 2024-10-07
# 139093
# retriveing data for 2024-10-08
# 139903
# retriveing data for 2024-10-09
# 140713
# retriveing data for 2024-10-10
# 141523
# retriveing data for 2024-10-11
# 142333
# retriveing data for 2024-10-14
# 143143
# retriveing data for 2024-10-15
# 143953
# retriveing data for 2024-10-16
# 144763
# retriveing data for 2024-10-17
# 145573
# retriveing data for 2024-10-18
# 146383
# retriveing data for 2024-10-21
# 147193
# retriveing data for 2024-10-22
# 148003
# retriveing data for 2024-10-23
# 148813
# retriveing data for 2024-10-24
# 149623
# retriveing data for 2024-10-25
# 150433
# retriveing data for 2024-10-28
# 151243
# retriveing data for 2024-10-29
# 152053
# retriveing data for 2024-10-30
# 152863
# retriveing data for 2024-10-31
# 153673
# retriveing data for 2024-11-01
# 154483
# retriveing data for 2024-11-04
# 155293
# retriveing data for 2024-11-05
# 156103
# retriveing data for 2024-11-06
# 156913
# retriveing data for 2024-11-07
# 157723
# retriveing data for 2024-11-08
# 158533
# retriveing data for 2024-11-11
# 159343
# retriveing data for 2024-11-12
# 160153
# retriveing data for 2024-11-13
# 160963
# retriveing data for 2024-11-14
# 161773
# retriveing data for 2024-11-15
# 162583
# retriveing data for 2024-11-18
# 163393
# retriveing data for 2024-11-19
# 164203
# retriveing data for 2024-11-20
# 165013
# retriveing data for 2024-11-21
# 165823
# retriveing data for 2024-11-22
# 166633
# retriveing data for 2024-11-25
# 167443
# retriveing data for 2024-11-26
# 168253
# retriveing data for 2024-11-27
# 169063
# retriveing data for 2024-12-02
# 169873
# retriveing data for 2024-12-03
# 170683
# retriveing data for 2024-12-04
# 171493
# retriveing data for 2024-12-05
# 172303
# retriveing data for 2024-12-06
# 173113
# retriveing data for 2024-12-09
# 173923
# retriveing data for 2024-12-10
# 174733
# retriveing data for 2024-12-11
# 175543
# retriveing data for 2024-12-12
# 176353
# retriveing data for 2024-12-13
# 177163
# retriveing data for 2024-12-16
# 177973
# retriveing data for 2024-12-17
# 178783
# retriveing data for 2024-12-18
# 179593
# retriveing data for 2024-12-19
# 180403
# retriveing data for 2024-12-20
# 181213
# retriveing data for 2024-12-23
# 182023
# retriveing data for 2024-12-24
# 182606
# retriveing data for 2024-12-26
# 183416
# retriveing data for 2024-12-27
# 184226
# retriveing data for 2024-12-30
# 185036
# retriveing data for 2024-12-31
# 185846
# retriveing data for 2025-01-02
# 186656
# retriveing data for 2025-01-03
# 187466
# retriveing data for 2025-01-06
# 188276
# retriveing data for 2025-01-07
# 189086
# retriveing data for 2025-01-08
# 189896
# retriveing data for 2025-01-09
# 190706
# retriveing data for 2025-01-10
# 191516
# retriveing data for 2025-01-13
# 192326
# retriveing data for 2025-01-14
# 193136
# retriveing data for 2025-01-15
# 193946
# retriveing data for 2025-01-16
# 194756
# retriveing data for 2025-01-17
# 195566
# retriveing data for 2025-01-21
# 196376
# retriveing data for 2025-01-22
# 197186
# retriveing data for 2025-01-23
# 197996
# retriveing data for 2025-01-24
# 198806
# retriveing data for 2025-01-27
# 199616
# retriveing data for 2025-01-28
# 200426
# retriveing data for 2025-01-29
# 201236
# retriveing data for 2025-01-30
# 202046
# retriveing data for 2025-01-31
# 202856
# retriveing data for 2025-02-03
# 203666
# retriveing data for 2025-02-04
# 204476
# retriveing data for 2025-02-05
# 205286
# retriveing data for 2025-02-06
# 206096
# retriveing data for 2025-02-07
# 206906
# retriveing data for 2025-02-10
# 207716
# retriveing data for 2025-02-11
# 208526
# retriveing data for 2025-02-12
# 209336
# retriveing data for 2025-02-13
# 210146
# retriveing data for 2025-02-14
# 210956
# retriveing data for 2025-02-18
# 211766
# retriveing data for 2025-02-19
# 212576
# retriveing data for 2025-02-20
# 213386
# retriveing data for 2025-02-21
# 214196
# retriveing data for 2025-02-24
# 215006
# retriveing data for 2025-02-25
# 215816
# retriveing data for 2025-02-26
# 216626
# retriveing data for 2025-02-27
# 217436
# retriveing data for 2025-02-28
# 218246
# retriveing data for 2025-03-03
# 219056
# retriveing data for 2025-03-04
# 219866
# retriveing data for 2025-03-05
# 220676
# retriveing data for 2025-03-06
# 221486
# retriveing data for 2025-03-07
# 222296
# retriveing data for 2025-03-10
# 223106
# retriveing data for 2025-03-11
# 223916
# retriveing data for 2025-03-12
# 224726
# retriveing data for 2025-03-13
# 225536
# retriveing data for 2025-03-14
# 226346
# retriveing data for 2025-03-17
# 227156
# retriveing data for 2025-03-18
# 227966
# retriveing data for 2025-03-19
# 228776
# retriveing data for 2025-03-20
# 229586
# retriveing data for 2025-03-21
# 230396
# retriveing data for 2025-03-24
# 231206
# retriveing data for 2025-03-25
# 232016
# retriveing data for 2025-03-26
# 232826
# retriveing data for 2025-03-27
# 233636
# retriveing data for 2025-03-28
# 234446
# retriveing data for 2025-03-31
# 235256
# retriveing data for 2025-04-01
# 236066

# %%
df_all_days_TQQQ = DR_STK_TQQQ.D_request()
# Out:
# retriveing data for 2024-02-01
# 390
# retriveing data for 2024-02-02
# 780
# retriveing data for 2024-02-05
# 1170
# retriveing data for 2024-02-06
# 1560
# retriveing data for 2024-02-07
# 1950
# retriveing data for 2024-02-08
# 2340
# retriveing data for 2024-02-09
# 2730
# retriveing data for 2024-02-12
# 3120
# retriveing data for 2024-02-13
# 3510
# retriveing data for 2024-02-14
# 3900
# retriveing data for 2024-02-15
# 4290
# retriveing data for 2024-02-16
# 4680
# retriveing data for 2024-02-20
# 5070
# retriveing data for 2024-02-21
# 5460
# retriveing data for 2024-02-22
# 5850
# retriveing data for 2024-02-23
# 6240
# retriveing data for 2024-02-26
# 6630
# retriveing data for 2024-02-27
# 7020
# retriveing data for 2024-02-28
# 7410
# retriveing data for 2024-02-29
# 7800
# retriveing data for 2024-03-01
# 8190
# retriveing data for 2024-03-04
# 8580
# retriveing data for 2024-03-05
# 8970
# retriveing data for 2024-03-06
# 9360
# retriveing data for 2024-03-07
# 9750
# retriveing data for 2024-03-08
# 10140
# retriveing data for 2024-03-11
# 10530
# retriveing data for 2024-03-12
# 10920
# retriveing data for 2024-03-13
# 11310
# retriveing data for 2024-03-14
# 11700
# retriveing data for 2024-03-15
# 12090
# retriveing data for 2024-03-18
# 12480
# retriveing data for 2024-03-19
# 12870
# retriveing data for 2024-03-20
# 13260
# retriveing data for 2024-03-21
# 13650
# retriveing data for 2024-03-22
# 14040
# retriveing data for 2024-03-25
# 14430
# retriveing data for 2024-03-26
# 14820
# retriveing data for 2024-03-27
# 15210
# retriveing data for 2024-03-28
# 15600
# retriveing data for 2024-04-01
# 15990
# retriveing data for 2024-04-02
# 16380
# retriveing data for 2024-04-03
# 16770
# retriveing data for 2024-04-04
# 17160
# retriveing data for 2024-04-05
# 17550
# retriveing data for 2024-04-08
# 17940
# retriveing data for 2024-04-09
# 18330
# retriveing data for 2024-04-10
# 18720
# retriveing data for 2024-04-11
# 19110
# retriveing data for 2024-04-12
# 19500
# retriveing data for 2024-04-15
# 19890
# retriveing data for 2024-04-16
# 20280
# retriveing data for 2024-04-17
# 20670
# retriveing data for 2024-04-18
# 21060
# retriveing data for 2024-04-19
# 21450
# retriveing data for 2024-04-22
# 21840
# retriveing data for 2024-04-23
# 22230
# retriveing data for 2024-04-24
# 22620
# retriveing data for 2024-04-25
# 23010
# retriveing data for 2024-04-26
# 23400
# retriveing data for 2024-04-29
# 23790
# retriveing data for 2024-04-30
# 24180
# retriveing data for 2024-05-01
# 24570
# retriveing data for 2024-05-02
# 24960
# retriveing data for 2024-05-03
# 25350
# retriveing data for 2024-05-06
# 25740
# retriveing data for 2024-05-07
# 26130
# retriveing data for 2024-05-08
# 26520
# retriveing data for 2024-05-09
# 26910
# retriveing data for 2024-05-10
# 27300
# retriveing data for 2024-05-13
# 27690
# retriveing data for 2024-05-14
# 28080
# retriveing data for 2024-05-15
# 28470
# retriveing data for 2024-05-16
# 28860
# retriveing data for 2024-05-17
# 29250
# retriveing data for 2024-05-20
# 29640
# retriveing data for 2024-05-21
# 30030
# retriveing data for 2024-05-22
# 30420
# retriveing data for 2024-05-23
# 30810
# retriveing data for 2024-05-24
# 31200
# retriveing data for 2024-05-28
# 31590
# retriveing data for 2024-05-29
# 31980
# retriveing data for 2024-05-30
# 32370
# retriveing data for 2024-05-31
# 32760
# retriveing data for 2024-06-03
# 33150
# retriveing data for 2024-06-04
# 33540
# retriveing data for 2024-06-05
# 33930
# retriveing data for 2024-06-06
# 34320
# retriveing data for 2024-06-07
# 34710
# retriveing data for 2024-06-10
# 35100
# retriveing data for 2024-06-11
# 35490
# retriveing data for 2024-06-12
# 35880
# retriveing data for 2024-06-13
# 36270
# retriveing data for 2024-06-14
# 36660
# retriveing data for 2024-06-17
# 37050
# retriveing data for 2024-06-18
# 37440
# retriveing data for 2024-06-20
# 37830
# retriveing data for 2024-06-21
# 38220
# retriveing data for 2024-06-24
# 38610
# retriveing data for 2024-06-25
# 39000
# retriveing data for 2024-06-26
# 39390
# retriveing data for 2024-06-27
# 39780
# retriveing data for 2024-06-28
# 40170
# retriveing data for 2024-07-01
# 40560
# retriveing data for 2024-07-02
# 40950
# retriveing data for 2024-07-03
# 41160
# retriveing data for 2024-07-05
# 41550
# retriveing data for 2024-07-08
# 41940
# retriveing data for 2024-07-09
# 42330
# retriveing data for 2024-07-10
# 42720
# retriveing data for 2024-07-11
# 43110
# retriveing data for 2024-07-12
# 43500
# retriveing data for 2024-07-15
# 43890
# retriveing data for 2024-07-16
# 44280
# retriveing data for 2024-07-17
# 44670
# retriveing data for 2024-07-18
# 45060
# retriveing data for 2024-07-19
# 45450
# retriveing data for 2024-07-22
# 45840
# retriveing data for 2024-07-23
# 46230
# retriveing data for 2024-07-24
# 46620
# retriveing data for 2024-07-25
# 47010
# retriveing data for 2024-07-26
# 47400
# retriveing data for 2024-07-29
# 47790
# retriveing data for 2024-07-30
# 48180
# retriveing data for 2024-07-31
# 48570
# retriveing data for 2024-08-01
# 48960
# retriveing data for 2024-08-02
# 49350
# retriveing data for 2024-08-05
# 49740
# retriveing data for 2024-08-06
# 50130
# retriveing data for 2024-08-07
# 50520
# retriveing data for 2024-08-08
# 50910
# retriveing data for 2024-08-09
# 51300
# retriveing data for 2024-08-12
# 51690
# retriveing data for 2024-08-13
# 52080
# retriveing data for 2024-08-14
# 52470
# retriveing data for 2024-08-15
# 52860
# retriveing data for 2024-08-16
# 53250
# retriveing data for 2024-08-19
# 53640
# retriveing data for 2024-08-20
# 54030
# retriveing data for 2024-08-21
# 54420
# retriveing data for 2024-08-22
# 54810
# retriveing data for 2024-08-23
# 55200
# retriveing data for 2024-08-26
# 55590
# retriveing data for 2024-08-27
# 55980
# retriveing data for 2024-08-28
# 56370
# retriveing data for 2024-08-29
# 56760
# retriveing data for 2024-08-30
# 57150
# retriveing data for 2024-09-03
# 57540
# retriveing data for 2024-09-04
# 57930
# retriveing data for 2024-09-05
# 58320
# retriveing data for 2024-09-06
# 58710
# retriveing data for 2024-09-09
# 59100
# retriveing data for 2024-09-10
# 59490
# retriveing data for 2024-09-11
# 59880
# retriveing data for 2024-09-12
# 60270
# retriveing data for 2024-09-13
# 60660
# retriveing data for 2024-09-16
# 61050
# retriveing data for 2024-09-17
# 61440
# retriveing data for 2024-09-18
# 61830
# retriveing data for 2024-09-19
# 62220
# retriveing data for 2024-09-20
# 62610
# retriveing data for 2024-09-23
# 63000
# retriveing data for 2024-09-24
# 63390
# retriveing data for 2024-09-25
# 63780
# retriveing data for 2024-09-26
# 64170
# retriveing data for 2024-09-27
# 64560
# retriveing data for 2024-09-30
# 64950
# retriveing data for 2024-10-01
# 65340
# retriveing data for 2024-10-02
# 65730
# retriveing data for 2024-10-03
# 66120
# retriveing data for 2024-10-04
# 66510
# retriveing data for 2024-10-07
# 66900
# retriveing data for 2024-10-08
# 67290
# retriveing data for 2024-10-09
# 67680
# retriveing data for 2024-10-10
# 68070
# retriveing data for 2024-10-11
# 68460
# retriveing data for 2024-10-14
# 68850
# retriveing data for 2024-10-15
# 69240
# retriveing data for 2024-10-16
# 69630
# retriveing data for 2024-10-17
# 70020
# retriveing data for 2024-10-18
# 70410
# retriveing data for 2024-10-21
# 70800
# retriveing data for 2024-10-22
# 71190
# retriveing data for 2024-10-23
# 71580
# retriveing data for 2024-10-24
# 71970
# retriveing data for 2024-10-25
# 72360
# retriveing data for 2024-10-28
# 72750
# retriveing data for 2024-10-29
# 73140
# retriveing data for 2024-10-30
# 73530
# retriveing data for 2024-10-31
# 73920
# retriveing data for 2024-11-01
# 74310
# retriveing data for 2024-11-04
# 74700
# retriveing data for 2024-11-05
# 75090
# retriveing data for 2024-11-06
# 75480
# retriveing data for 2024-11-07
# 75870
# retriveing data for 2024-11-08
# 76260
# retriveing data for 2024-11-11
# 76650
# retriveing data for 2024-11-12
# 77040
# retriveing data for 2024-11-13
# 77430
# retriveing data for 2024-11-14
# 77820
# retriveing data for 2024-11-15
# 78210
# retriveing data for 2024-11-18
# 78600
# retriveing data for 2024-11-19
# 78990
# retriveing data for 2024-11-20
# 79380
# retriveing data for 2024-11-21
# 79770
# retriveing data for 2024-11-22
# 80160
# retriveing data for 2024-11-25
# 80550
# retriveing data for 2024-11-26
# 80940
# retriveing data for 2024-11-27
# 81330
# retriveing data for 2024-12-02
# 81720
# retriveing data for 2024-12-03
# 82110
# retriveing data for 2024-12-04
# 82500
# retriveing data for 2024-12-05
# 82890
# retriveing data for 2024-12-06
# 83280
# retriveing data for 2024-12-09
# 83670
# retriveing data for 2024-12-10
# 84060
# retriveing data for 2024-12-11
# 84450
# retriveing data for 2024-12-12
# 84840
# retriveing data for 2024-12-13
# 85230
# retriveing data for 2024-12-16
# 85620
# retriveing data for 2024-12-17
# 86010
# retriveing data for 2024-12-18
# 86400
# retriveing data for 2024-12-19
# 86790
# retriveing data for 2024-12-20
# 87180
# retriveing data for 2024-12-23
# 87570
# retriveing data for 2024-12-24
# 87780
# retriveing data for 2024-12-26
# 88170
# retriveing data for 2024-12-27
# 88560
# retriveing data for 2024-12-30
# 88950
# retriveing data for 2024-12-31
# 89340
# retriveing data for 2025-01-02
# 89730
# retriveing data for 2025-01-03
# 90120
# retriveing data for 2025-01-06
# 90510
# retriveing data for 2025-01-07
# 90900
# retriveing data for 2025-01-08
# 91290
# retriveing data for 2025-01-09
# 91680
# retriveing data for 2025-01-10
# 92070
# retriveing data for 2025-01-13
# 92460
# retriveing data for 2025-01-14
# 92850
# retriveing data for 2025-01-15
# 93240
# retriveing data for 2025-01-16
# 93630
# retriveing data for 2025-01-17
# 94020
# retriveing data for 2025-01-21
# 94410
# retriveing data for 2025-01-22
# 94800
# retriveing data for 2025-01-23
# 95190
# retriveing data for 2025-01-24
# 95580
# retriveing data for 2025-01-27
# 95970
# retriveing data for 2025-01-28
# 96360
# retriveing data for 2025-01-29
# 96750
# retriveing data for 2025-01-30
# 97140
# retriveing data for 2025-01-31
# 97530
# retriveing data for 2025-02-03
# 97920
# retriveing data for 2025-02-04
# 98310
# retriveing data for 2025-02-05
# 98700
# retriveing data for 2025-02-06
# 99090
# retriveing data for 2025-02-07
# 99480
# retriveing data for 2025-02-10
# 99870
# retriveing data for 2025-02-11
# 100260
# retriveing data for 2025-02-12
# 100650
# retriveing data for 2025-02-13
# 101040
# retriveing data for 2025-02-14
# 101430
# retriveing data for 2025-02-18
# 101820
# retriveing data for 2025-02-19
# 102210
# retriveing data for 2025-02-20
# 102600
# retriveing data for 2025-02-21
# 102990
# retriveing data for 2025-02-24
# 103380
# retriveing data for 2025-02-25
# 103770
# retriveing data for 2025-02-26
# 104160
# retriveing data for 2025-02-27
# 104550
# retriveing data for 2025-02-28
# 104940
# retriveing data for 2025-03-03
# 105330
# retriveing data for 2025-03-04
# 105720
# retriveing data for 2025-03-05
# 106110
# retriveing data for 2025-03-06
# 106500
# retriveing data for 2025-03-07
# 106890
# retriveing data for 2025-03-10
# 107280
# retriveing data for 2025-03-11
# 107670
# retriveing data for 2025-03-12
# 108060
# retriveing data for 2025-03-13
# 108450
# retriveing data for 2025-03-14
# 108840
# retriveing data for 2025-03-17
# 109230
# retriveing data for 2025-03-18
# 109620
# retriveing data for 2025-03-19
# 110010
# retriveing data for 2025-03-20
# 110400
# retriveing data for 2025-03-21
# 110790
# retriveing data for 2025-03-24
# 111180
# retriveing data for 2025-03-25
# 111570
# retriveing data for 2025-03-26
# 111960
# retriveing data for 2025-03-27
# 112350
# retriveing data for 2025-03-28
# 112740
# retriveing data for 2025-03-31
# 113130
# retriveing data for 2025-04-01
# 113520

# %%
df_TQQQ = df_all_days_TQQQ

# %%
df_VIX = df_all_days_VIX[(df_all_days_VIX['date'].dt.time >= time(9,30,0))].copy()

# %%
df_all_days_stock.to_csv('dev_master_stock_info.csv', index=False)
df_all_days_stock.to_pickle('dev_master_stock_info.pkl')

df_VIX.to_csv('dev_master_vix_info.csv', index=False)
df_VIX.to_pickle('dev_master_vix_info.pkl')

df_TQQQ.to_csv('dev_master_tqqq_info.csv', index=False)
df_TQQQ.to_pickle('dev_master_tqqq_info.pkl')

# %%
df_all_days_stock = pd.read_pickle('dev_master_stock_info.pkl')
df_VIX = pd.read_pickle('dev_master_vix_info.pkl')
df_TQQQ = pd.read_pickle('dev_master_tqqq_info.pkl')

# %%
cut_time = time(14, 30, 0)

# %%
# def calculate_rsi(prices, period=14):
#     """
#     Calculates the Relative Strength Index (RSI) for a given price series.

#     Args:
#         prices (pd.Series): A Pandas Series representing the price data.
#         period (int, optional): The lookback period for RSI calculation. Defaults to 14.

#     Returns:
#         pd.Series: A Pandas Series containing the RSI values.
#     """

#     delta = prices.diff()
#     gain = delta.where(delta > 0, 0)
#     loss = -delta.where(delta < 0, 0)

#     avg_gain = gain.rolling(window=period, min_periods=period).mean()
#     avg_loss = loss.rolling(window=period, min_periods=period).mean()

#     rs = avg_gain / avg_loss
#     rsi = 100 - (100 / (1 + rs))

#     return rsi

# %%
# Example usage:
# #data = {'Close': [45, 48, 50, 47, 49, 52, 55, 53, 51, 54]}
# #df = pd.DataFrame(data)
# df = pd.DataFrame()
# rsi_period = 14 
# df_all_days_stock['RSI_14'] = calculate_rsi(df_all_days_stock['close'], period=rsi_period)
# rsi_period = 30 
# df_all_days_stock['RSI_30'] = calculate_rsi(df_all_days_stock['close'], period=rsi_period)
# rsi_period = 60 
# df_all_days_stock['RSI_60'] = calculate_rsi(df_all_days_stock['close'], period=rsi_period)

# df_all_days_stock

# %%
df_filter_after.groupby('Date_Only')['open'].max()
# Out:
# Date_Only
# 2024-02-01    397.36
# 2024-02-02    480.83
# 2024-02-05    468.59
# 2024-02-06    457.25
# 2024-02-07    470.24
#                ...
# 2025-03-26    611.81
# 2025-03-27    608.14
# 2025-03-28    579.96
# 2025-03-31    578.09
# 2025-04-01    586.51
# Name: open, Length: 288, dtype: float64

# %%
df_filter_after.groupby('Date_Only')['close'].min()
# Out:
# Date_Only
# 2024-02-01    394.10
# 2024-02-02    472.81
# 2024-02-05    459.38
# 2024-02-06    454.09
# 2024-02-07    467.10
#                ...
# 2025-03-26    606.91
# 2025-03-27    601.90
# 2025-03-28    574.27
# 2025-03-31    573.25
# 2025-04-01    579.44
# Name: close, Length: 288, dtype: float64

# %%
def data_sparcing_construc(df, sp_day, *, cut_time = None):
    #df_group = df.groupby("Date_Only").std(numeric_only=True)
    df_filter_prior = data_filter(df, sp_day, specific_time_before = cut_time )
    df_group_prior = df_filter_prior.groupby("Date_Only").std(numeric_only=True)
    
    df_filter_after = data_filter(df, sp_day, specific_time_after = cut_time )
    df_group_after = df_filter_after.groupby("Date_Only").std(numeric_only=True)


    df_group_train =pd.DataFrame()
    df_group_train['Target_std'] = pd.DataFrame(df_group_after[['open','high','low','close']].max(axis=1))
    df_group_train['Target_spread'] = df_filter_after.groupby('Date_Only')['open'].max() - df_filter_after.groupby('Date_Only')['open'].min()
    
    df_group_train['prior_std'] = pd.DataFrame(df_group_prior[['open','high','low','close']].max(axis=1))
    df_group_train['prior_Vol'] = pd.DataFrame(df_filter_prior.groupby("Date_Only").mean()['volume'])
    df_group_train['prior_spread'] = df_filter_prior.groupby('Date_Only')['open'].max() - df_filter_prior.groupby('Date_Only')['open'].min()

    df_group_train['prior_range'] =pd.DataFrame(df_filter_prior.groupby('Date_Only')['close'].max() -df_filter_prior.groupby('Date_Only')['close'].min() )
    
    df_initial = df_filter_prior.copy()
    new_time = time(cut_time.hour, cut_time.minute -1)
    df_group_train['cut_open'] = df_initial[(df_initial['date'].dt.time == new_time)]['open'].values
   # df_group_train['RSI_14'] = df_initial[df_initial['date'].dt.time == new_time]['RSI_14'].values
   # df_group_train['RSI_30'] = df_initial[df_initial['date'].dt.time == new_time]['RSI_30'].values
   # df_group_train['RSI_60'] = df_initial[df_initial['date'].dt.time == new_time]['RSI_60'].values
    
    cut_name =['cut_1hr','cut_2hr','cut_3hr']
    for i in range(3):
        print(i)
        prior = time(cut_time.hour - (i+1), cut_time.minute)
        df_group_train[cut_name[i]] = df_initial[(df_initial['date'].dt.time == new_time)]['open'].values- df_initial[(df_initial['date'].dt.time == prior)]['open'].values

    #df_group_train['Class_target'] = df_filter_after[(df_filter_after['date'].dt.time == time(15, 49, 0))]['close'].values- df_initial[(df_initial['date'].dt.time == new_time)]['open'].values
    
    return df_group_train, df_filter_prior, df_filter_after, df_group_prior, df_group_after

# %%
df_group_train, df_filter_prior, df_filter_after, df_group_prior, df_group_after = data_sparcing_construc(df_all_days_stock, all_dates, cut_time= cut_time)
# Out:
# 0
# retrieving 2024-02-01
# 0.2 percent is done
# 300
# retrieving 2024-02-02
# 1.2 percent is done
# 600
# retrieving 2024-02-03
# 2.2 percent is done
# 600
# retrieving 2024-02-04
# 3.2 percent is done
# 600
# retrieving 2024-02-05
# 4.2 percent is done
# 900
# retrieving 2024-02-06
# 5.2 percent is done
# 1200
# retrieving 2024-02-07
# 6.2 percent is done
# 1500
# retrieving 2024-02-08
# 7.2 percent is done
# 1800
# retrieving 2024-02-09
# 8.2 percent is done
# 2100
# retrieving 2024-02-10
# 9.2 percent is done
# 2100
# retrieving 2024-02-11
# 10.2 percent is done
# 2100
# retrieving 2024-02-12
# 11.2 percent is done
# 2400
# retrieving 2024-02-13
# 12.2 percent is done
# 2700
# retrieving 2024-02-14
# 13.2 percent is done
# 3000
# retrieving 2024-02-15
# 14.2 percent is done
# 3300
# retrieving 2024-02-16
# 15.2 percent is done
# 3600
# retrieving 2024-02-17
# 16.2 percent is done
# 3600
# retrieving 2024-02-18
# 17.2 percent is done
# 3600
# retrieving 2024-02-20
# 18.2 percent is done
# 3900
# retrieving 2024-02-21
# 19.2 percent is done
# 4200
# retrieving 2024-02-22
# 20.2 percent is done
# 4500
# retrieving 2024-02-23
# 21.2 percent is done
# 4800
# retrieving 2024-02-24
# 22.2 percent is done
# 4800
# retrieving 2024-02-25
# 23.2 percent is done
# 4800
# retrieving 2024-02-26
# 24.2 percent is done
# 5100
# retrieving 2024-02-27
# 25.2 percent is done
# 5400
# retrieving 2024-02-28
# 26.2 percent is done
# 5700
# retrieving 2024-02-29
# 27.2 percent is done
# 6000
# retrieving 2024-03-01
# 28.2 percent is done
# 6300
# retrieving 2024-03-02
# 29.2 percent is done
# 6300
# retrieving 2024-03-03
# 30.2 percent is done
# 6300
# retrieving 2024-03-04
# 31.2 percent is done
# 6600
# retrieving 2024-03-05
# 32.2 percent is done
# 6900
# retrieving 2024-03-06
# 33.2 percent is done
# 7200
# retrieving 2024-03-07
# 34.2 percent is done
# 7500
# retrieving 2024-03-08
# 35.2 percent is done
# 7800
# retrieving 2024-03-09
# 36.2 percent is done
# 7800
# retrieving 2024-03-10
# 37.2 percent is done
# 7800
# retrieving 2024-03-11
# 38.2 percent is done
# 8100
# retrieving 2024-03-12
# 39.2 percent is done
# 8400
# retrieving 2024-03-13
# 40.2 percent is done
# 8700
# retrieving 2024-03-14
# 41.2 percent is done
# 9000
# retrieving 2024-03-15
# 42.2 percent is done
# 9300
# retrieving 2024-03-16
# 43.2 percent is done
# 9300
# retrieving 2024-03-17
# 44.2 percent is done
# 9300
# retrieving 2024-03-18
# 45.2 percent is done
# 9600
# retrieving 2024-03-19
# 46.2 percent is done
# 9900
# retrieving 2024-03-20
# 47.2 percent is done
# 10200
# retrieving 2024-03-21
# 48.2 percent is done
# 10500
# retrieving 2024-03-22
# 49.2 percent is done
# 10800
# retrieving 2024-03-23
# 50.2 percent is done
# 10800
# retrieving 2024-03-24
# 51.2 percent is done
# 10800
# retrieving 2024-03-25
# 52.2 percent is done
# 11100
# retrieving 2024-03-26
# 53.2 percent is done
# 11400
# retrieving 2024-03-27
# 54.2 percent is done
# 11700
# retrieving 2024-03-28
# 55.2 percent is done
# 12000
# retrieving 2024-03-30
# 56.2 percent is done
# 12000
# retrieving 2024-03-31
# 57.2 percent is done
# 12000
# retrieving 2024-04-01
# 58.2 percent is done
# 12300
# retrieving 2024-04-02
# 59.2 percent is done
# 12600
# retrieving 2024-04-03
# 60.2 percent is done
# 12900
# retrieving 2024-04-04
# 61.2 percent is done
# 13200
# retrieving 2024-04-05
# 62.2 percent is done
# 13500
# retrieving 2024-04-06
# 63.2 percent is done
# 13500
# retrieving 2024-04-07
# 64.2 percent is done
# 13500
# retrieving 2024-04-08
# 65.2 percent is done
# 13800
# retrieving 2024-04-09
# 66.2 percent is done
# 14100
# retrieving 2024-04-10
# 67.2 percent is done
# 14400
# retrieving 2024-04-11
# 68.2 percent is done
# 14700
# retrieving 2024-04-12
# 69.2 percent is done
# 15000
# retrieving 2024-04-13
# 70.2 percent is done
# 15000
# retrieving 2024-04-14
# 71.2 percent is done
# 15000
# retrieving 2024-04-15
# 72.2 percent is done
# 15300
# retrieving 2024-04-16
# 73.2 percent is done
# 15600
# retrieving 2024-04-17
# 74.2 percent is done
# 15900
# retrieving 2024-04-18
# 75.2 percent is done
# 16200
# retrieving 2024-04-19
# 76.2 percent is done
# 16500
# retrieving 2024-04-20
# 77.2 percent is done
# 16500
# retrieving 2024-04-21
# 78.2 percent is done
# 16500
# retrieving 2024-04-22
# 79.2 percent is done
# 16800
# retrieving 2024-04-23
# 80.2 percent is done
# 17100
# retrieving 2024-04-24
# 81.2 percent is done
# 17400
# retrieving 2024-04-25
# 82.2 percent is done
# 17700
# retrieving 2024-04-26
# 83.2 percent is done
# 18000
# retrieving 2024-04-27
# 84.2 percent is done
# 18000
# retrieving 2024-04-28
# 85.2 percent is done
# 18000
# retrieving 2024-04-29
# 86.2 percent is done
# 18300
# retrieving 2024-04-30
# 87.2 percent is done
# 18600
# retrieving 2024-05-01
# 88.2 percent is done
# 18900
# retrieving 2024-05-02
# 89.2 percent is done
# 19200
# retrieving 2024-05-03
# 90.2 percent is done
# 19500
# retrieving 2024-05-04
# 91.2 percent is done
# 19500
# retrieving 2024-05-05
# 92.2 percent is done
# 19500
# retrieving 2024-05-06
# 93.2 percent is done
# 19800
# retrieving 2024-05-07
# 94.2 percent is done
# 20100
# retrieving 2024-05-08
# 95.2 percent is done
# 20400
# retrieving 2024-05-09
# 96.2 percent is done
# 20700
# retrieving 2024-05-10
# 97.2 percent is done
# 21000
# retrieving 2024-05-11
# 98.2 percent is done
# 21000
# retrieving 2024-05-12
# 99.2 percent is done
# 21000
# retrieving 2024-05-13
# 100.2 percent is done
# 21300
# retrieving 2024-05-14
# 101.2 percent is done
# 21600
# retrieving 2024-05-15
# 102.2 percent is done
# 21900
# retrieving 2024-05-16
# 103.2 percent is done
# 22200
# retrieving 2024-05-17
# 104.2 percent is done
# 22500
# retrieving 2024-05-18
# 105.2 percent is done
# 22500
# retrieving 2024-05-19
# 106.2 percent is done
# 22500
# retrieving 2024-05-20
# 107.2 percent is done
# 22800
# retrieving 2024-05-21
# 108.2 percent is done
# 23100
# retrieving 2024-05-22
# 109.2 percent is done
# 23400
# retrieving 2024-05-23
# 110.2 percent is done
# 23700
# retrieving 2024-05-24
# 111.2 percent is done
# 24000
# retrieving 2024-05-25
# 112.2 percent is done
# 24000
# retrieving 2024-05-26
# 113.2 percent is done
# 24000
# retrieving 2024-05-28
# 114.2 percent is done
# 24300
# retrieving 2024-05-29
# 115.2 percent is done
# 24600
# retrieving 2024-05-30
# 116.2 percent is done
# 24900
# retrieving 2024-05-31
# 117.2 percent is done
# 25200
# retrieving 2024-06-01
# 118.2 percent is done
# 25200
# retrieving 2024-06-02
# 119.2 percent is done
# 25200
# retrieving 2024-06-03
# 120.2 percent is done
# 25500
# retrieving 2024-06-04
# 121.2 percent is done
# 25800
# retrieving 2024-06-05
# 122.2 percent is done
# 26100
# retrieving 2024-06-06
# 123.2 percent is done
# 26400
# retrieving 2024-06-07
# 124.2 percent is done
# 26700
# retrieving 2024-06-08
# 125.2 percent is done
# 26700
# retrieving 2024-06-09
# 126.2 percent is done
# 26700
# retrieving 2024-06-10
# 127.2 percent is done
# 27000
# retrieving 2024-06-11
# 128.2 percent is done
# 27300
# retrieving 2024-06-12
# 129.2 percent is done
# 27600
# retrieving 2024-06-13
# 130.2 percent is done
# 27900
# retrieving 2024-06-14
# 131.2 percent is done
# 28200
# retrieving 2024-06-15
# 132.2 percent is done
# 28200
# retrieving 2024-06-16
# 133.2 percent is done
# 28200
# retrieving 2024-06-17
# 134.2 percent is done
# 28500
# retrieving 2024-06-18
# 135.2 percent is done
# 28800
# retrieving 2024-06-20
# 136.2 percent is done
# 29100
# retrieving 2024-06-21
# 137.2 percent is done
# 29400
# retrieving 2024-06-22
# 138.2 percent is done
# 29400
# retrieving 2024-06-23
# 139.2 percent is done
# 29400
# retrieving 2024-06-24
# 140.2 percent is done
# 29700
# retrieving 2024-06-25
# 141.2 percent is done
# 30000
# retrieving 2024-06-26
# 142.2 percent is done
# 30300
# retrieving 2024-06-27
# 143.2 percent is done
# 30600
# retrieving 2024-06-28
# 144.2 percent is done
# 30900
# retrieving 2024-06-29
# 145.2 percent is done
# 30900
# retrieving 2024-06-30
# 146.2 percent is done
# 30900
# retrieving 2024-07-01
# 147.2 percent is done
# 31200
# retrieving 2024-07-02
# 148.2 percent is done
# 31500
# retrieving 2024-07-03
# 149.2 percent is done
# 31500
# retrieving 2024-07-05
# 150.2 percent is done
# 31800
# retrieving 2024-07-06
# 151.2 percent is done
# 31800
# retrieving 2024-07-07
# 152.2 percent is done
# 31800
# retrieving 2024-07-08
# 153.2 percent is done
# 32100
# retrieving 2024-07-09
# 154.2 percent is done
# 32400
# retrieving 2024-07-10
# 155.2 percent is done
# 32700
# retrieving 2024-07-11
# 156.2 percent is done
# 33000
# retrieving 2024-07-12
# 157.2 percent is done
# 33300
# retrieving 2024-07-13
# 158.2 percent is done
# 33300
# retrieving 2024-07-14
# 159.2 percent is done
# 33300
# retrieving 2024-07-15
# 160.2 percent is done
# 33600
# retrieving 2024-07-16
# 161.2 percent is done
# 33900
# retrieving 2024-07-17
# 162.2 percent is done
# 34200
# retrieving 2024-07-18
# 163.2 percent is done
# 34500
# retrieving 2024-07-19
# 164.2 percent is done
# 34800
# retrieving 2024-07-20
# 165.2 percent is done
# 34800
# retrieving 2024-07-21
# 166.2 percent is done
# 34800
# retrieving 2024-07-22
# 167.2 percent is done
# 35100
# retrieving 2024-07-23
# 168.2 percent is done
# 35400
# retrieving 2024-07-24
# 169.2 percent is done
# 35700
# retrieving 2024-07-25
# 170.2 percent is done
# 36000
# retrieving 2024-07-26
# 171.2 percent is done
# 36300
# retrieving 2024-07-27
# 172.2 percent is done
# 36300
# retrieving 2024-07-28
# 173.2 percent is done
# 36300
# retrieving 2024-07-29
# 174.2 percent is done
# 36600
# retrieving 2024-07-30
# 175.2 percent is done
# 36900
# retrieving 2024-07-31
# 176.2 percent is done
# 37200
# retrieving 2024-08-01
# 177.2 percent is done
# 37500
# retrieving 2024-08-02
# 178.2 percent is done
# 37800
# retrieving 2024-08-03
# 179.2 percent is done
# 37800
# retrieving 2024-08-04
# 180.2 percent is done
# 37800
# retrieving 2024-08-05
# 181.2 percent is done
# 38100
# retrieving 2024-08-06
# 182.2 percent is done
# 38400
# retrieving 2024-08-07
# 183.2 percent is done
# 38700
# retrieving 2024-08-08
# 184.2 percent is done
# 39000
# retrieving 2024-08-09
# 185.2 percent is done
# 39300
# retrieving 2024-08-10
# 186.2 percent is done
# 39300
# retrieving 2024-08-11
# 187.2 percent is done
# 39300
# retrieving 2024-08-12
# 188.2 percent is done
# 39600
# retrieving 2024-08-13
# 189.2 percent is done
# 39900
# retrieving 2024-08-14
# 190.2 percent is done
# 40200
# retrieving 2024-08-15
# 191.2 percent is done
# 40500
# retrieving 2024-08-16
# 192.2 percent is done
# 40800
# retrieving 2024-08-17
# 193.2 percent is done
# 40800
# retrieving 2024-08-18
# 194.2 percent is done
# 40800
# retrieving 2024-08-19
# 195.2 percent is done
# 41100
# retrieving 2024-08-20
# 196.2 percent is done
# 41400
# retrieving 2024-08-21
# 197.2 percent is done
# 41700
# retrieving 2024-08-22
# 198.2 percent is done
# 42000
# retrieving 2024-08-23
# 199.2 percent is done
# 42300
# retrieving 2024-08-24
# 200.2 percent is done
# 42300
# retrieving 2024-08-25
# 201.2 percent is done
# 42300
# retrieving 2024-08-26
# 202.2 percent is done
# 42600
# retrieving 2024-08-27
# 203.2 percent is done
# 42900
# retrieving 2024-08-28
# 204.2 percent is done
# 43200
# retrieving 2024-08-29
# 205.2 percent is done
# 43500
# retrieving 2024-08-30
# 206.2 percent is done
# 43800
# retrieving 2024-08-31
# 207.2 percent is done
# 43800
# retrieving 2024-09-01
# 208.2 percent is done
# 43800
# retrieving 2024-09-03
# 209.2 percent is done
# 44100
# retrieving 2024-09-04
# 210.2 percent is done
# 44400
# retrieving 2024-09-05
# 211.2 percent is done
# 44700
# retrieving 2024-09-06
# 212.2 percent is done
# 45000
# retrieving 2024-09-07
# 213.2 percent is done
# 45000
# retrieving 2024-09-08
# 214.2 percent is done
# 45000
# retrieving 2024-09-09
# 215.2 percent is done
# 45300
# retrieving 2024-09-10
# 216.2 percent is done
# 45600
# retrieving 2024-09-11
# 217.2 percent is done
# 45900
# retrieving 2024-09-12
# 218.2 percent is done
# 46200
# retrieving 2024-09-13
# 219.2 percent is done
# 46500
# retrieving 2024-09-14
# 220.2 percent is done
# 46500
# retrieving 2024-09-15
# 221.2 percent is done
# 46500
# retrieving 2024-09-16
# 222.2 percent is done
# 46800
# retrieving 2024-09-17
# 223.2 percent is done
# 47100
# retrieving 2024-09-18
# 224.2 percent is done
# 47400
# retrieving 2024-09-19
# 225.2 percent is done
# 47700
# retrieving 2024-09-20
# 226.2 percent is done
# 48000
# retrieving 2024-09-21
# 227.2 percent is done
# 48000
# retrieving 2024-09-22
# 228.2 percent is done
# 48000
# retrieving 2024-09-23
# 229.2 percent is done
# 48300
# retrieving 2024-09-24
# 230.2 percent is done
# 48600
# retrieving 2024-09-25
# 231.2 percent is done
# 48900
# retrieving 2024-09-26
# 232.2 percent is done
# 49200
# retrieving 2024-09-27
# 233.2 percent is done
# 49500
# retrieving 2024-09-28
# 234.2 percent is done
# 49500
# retrieving 2024-09-29
# 235.2 percent is done
# 49500
# retrieving 2024-09-30
# 236.2 percent is done
# 49800
# retrieving 2024-10-01
# 237.2 percent is done
# 50100
# retrieving 2024-10-02
# 238.2 percent is done
# 50400
# retrieving 2024-10-03
# 239.2 percent is done
# 50700
# retrieving 2024-10-04
# 240.2 percent is done
# 51000
# retrieving 2024-10-05
# 241.2 percent is done
# 51000
# retrieving 2024-10-06
# 242.2 percent is done
# 51000
# retrieving 2024-10-07
# 243.2 percent is done
# 51300
# retrieving 2024-10-08
# 244.2 percent is done
# 51600
# retrieving 2024-10-09
# 245.2 percent is done
# 51900
# retrieving 2024-10-10
# 246.2 percent is done
# 52200
# retrieving 2024-10-11
# 247.2 percent is done
# 52500
# retrieving 2024-10-12
# 248.2 percent is done
# 52500
# retrieving 2024-10-13
# 249.2 percent is done
# 52500
# retrieving 2024-10-14
# 250.2 percent is done
# 52800
# retrieving 2024-10-15
# 251.2 percent is done
# 53100
# retrieving 2024-10-16
# 252.2 percent is done
# 53400
# retrieving 2024-10-17
# 253.2 percent is done
# 53700
# retrieving 2024-10-18
# 254.2 percent is done
# 54000
# retrieving 2024-10-19
# 255.2 percent is done
# 54000
# retrieving 2024-10-20
# 256.2 percent is done
# 54000
# retrieving 2024-10-21
# 257.2 percent is done
# 54300
# retrieving 2024-10-22
# 258.2 percent is done
# 54600
# retrieving 2024-10-23
# 259.2 percent is done
# 54900
# retrieving 2024-10-24
# 260.2 percent is done
# 55200
# retrieving 2024-10-25
# 261.2 percent is done
# 55500
# retrieving 2024-10-26
# 262.2 percent is done
# 55500
# retrieving 2024-10-27
# 263.2 percent is done
# 55500
# retrieving 2024-10-28
# 264.2 percent is done
# 55800
# retrieving 2024-10-29
# 265.2 percent is done
# 56100
# retrieving 2024-10-30
# 266.2 percent is done
# 56400
# retrieving 2024-10-31
# 267.2 percent is done
# 56700
# retrieving 2024-11-01
# 268.2 percent is done
# 57000
# retrieving 2024-11-02
# 269.2 percent is done
# 57000
# retrieving 2024-11-03
# 270.2 percent is done
# 57000
# retrieving 2024-11-04
# 271.2 percent is done
# 57300
# retrieving 2024-11-05
# 272.2 percent is done
# 57600
# retrieving 2024-11-06
# 273.2 percent is done
# 57900
# retrieving 2024-11-07
# 274.2 percent is done
# 58200
# retrieving 2024-11-08
# 275.2 percent is done
# 58500
# retrieving 2024-11-09
# 276.2 percent is done
# 58500
# retrieving 2024-11-10
# 277.2 percent is done
# 58500
# retrieving 2024-11-11
# 278.2 percent is done
# 58800
# retrieving 2024-11-12
# 279.2 percent is done
# 59100
# retrieving 2024-11-13
# 280.2 percent is done
# 59400
# retrieving 2024-11-14
# 281.2 percent is done
# 59700
# retrieving 2024-11-15
# 282.2 percent is done
# 60000
# retrieving 2024-11-16
# 283.2 percent is done
# 60000
# retrieving 2024-11-17
# 284.2 percent is done
# 60000
# retrieving 2024-11-18
# 285.2 percent is done
# 60300
# retrieving 2024-11-19
# 286.2 percent is done
# 60600
# retrieving 2024-11-20
# 287.2 percent is done
# 60900
# retrieving 2024-11-21
# 288.2 percent is done
# 61200
# retrieving 2024-11-22
# 289.2 percent is done
# 61500
# retrieving 2024-11-23
# 290.2 percent is done
# 61500
# retrieving 2024-11-24
# 291.2 percent is done
# 61500
# retrieving 2024-11-25
# 292.2 percent is done
# 61800
# retrieving 2024-11-26
# 293.2 percent is done
# 62100
# retrieving 2024-11-27
# 294.2 percent is done
# 62400
# retrieving 2024-11-30
# 295.2 percent is done
# 62400
# retrieving 2024-12-01
# 296.2 percent is done
# 62400
# retrieving 2024-12-02
# 297.2 percent is done
# 62700
# retrieving 2024-12-03
# 298.2 percent is done
# 63000
# retrieving 2024-12-04
# 299.2 percent is done
# 63300
# retrieving 2024-12-05
# 300.2 percent is done
# 63600
# retrieving 2024-12-06
# 301.2 percent is done
# 63900
# retrieving 2024-12-07
# 302.2 percent is done
# 63900
# retrieving 2024-12-08
# 303.2 percent is done
# 63900
# retrieving 2024-12-09
# 304.2 percent is done
# 64200
# retrieving 2024-12-10
# 305.2 percent is done
# 64500
# retrieving 2024-12-11
# 306.2 percent is done
# 64800
# retrieving 2024-12-12
# 307.2 percent is done
# 65100
# retrieving 2024-12-13
# 308.2 percent is done
# 65400
# retrieving 2024-12-14
# 309.2 percent is done
# 65400
# retrieving 2024-12-15
# 310.2 percent is done
# 65400
# retrieving 2024-12-16
# 311.2 percent is done
# 65700
# retrieving 2024-12-17
# 312.2 percent is done
# 66000
# retrieving 2024-12-18
# 313.2 percent is done
# 66300
# retrieving 2024-12-19
# 314.2 percent is done
# 66600
# retrieving 2024-12-20
# 315.2 percent is done
# 66900
# retrieving 2024-12-21
# 316.2 percent is done
# 66900
# retrieving 2024-12-22
# 317.2 percent is done
# 66900
# retrieving 2024-12-23
# 318.2 percent is done
# 67200
# retrieving 2024-12-24
# 319.2 percent is done
# 67200
# retrieving 2024-12-26
# 320.2 percent is done
# 67500
# retrieving 2024-12-27
# 321.2 percent is done
# 67800
# retrieving 2024-12-28
# 322.2 percent is done
# 67800
# retrieving 2024-12-29
# 323.2 percent is done
# 67800
# retrieving 2024-12-30
# 324.2 percent is done
# 68100
# retrieving 2024-12-31
# 325.2 percent is done
# 68400
# retrieving 2025-01-02
# 326.2 percent is done
# 68700
# retrieving 2025-01-03
# 327.2 percent is done
# 69000
# retrieving 2025-01-04
# 328.2 percent is done
# 69000
# retrieving 2025-01-05
# 329.2 percent is done
# 69000
# retrieving 2025-01-06
# 330.2 percent is done
# 69300
# retrieving 2025-01-07
# 331.2 percent is done
# 69600
# retrieving 2025-01-08
# 332.2 percent is done
# 69600
# retrieving 2025-01-09
# 333.2 percent is done
# 69600
# retrieving 2025-01-10
# 334.2 percent is done
# 69900
# retrieving 2025-01-11
# 335.2 percent is done
# 69900
# retrieving 2025-01-12
# 336.2 percent is done
# 69900
# retrieving 2025-01-13
# 337.2 percent is done
# 70200
# retrieving 2025-01-14
# 338.2 percent is done
# 70500
# retrieving 2025-01-15
# 339.2 percent is done
# 70800
# retrieving 2025-01-16
# 340.2 percent is done
# 71100
# retrieving 2025-01-17
# 341.2 percent is done
# 71400
# retrieving 2025-01-18
# 342.2 percent is done
# 71400
# retrieving 2025-01-19
# 343.2 percent is done
# 71400
# retrieving 2025-01-21
# 344.2 percent is done
# 71700
# retrieving 2025-01-22
# 345.2 percent is done
# 72000
# retrieving 2025-01-23
# 346.2 percent is done
# 72300
# retrieving 2025-01-24
# 347.2 percent is done
# 72600
# retrieving 2025-01-25
# 348.2 percent is done
# 72600
# retrieving 2025-01-26
# 349.2 percent is done
# 72600
# retrieving 2025-01-27
# 350.2 percent is done
# 72900
# retrieving 2025-01-28
# 351.2 percent is done
# 73200
# retrieving 2025-01-29
# 352.2 percent is done
# 73500
# retrieving 2025-01-30
# 353.2 percent is done
# 73800
# retrieving 2025-01-31
# 354.2 percent is done
# 74100
# retrieving 2025-02-01
# 355.2 percent is done
# 74100
# retrieving 2025-02-02
# 356.2 percent is done
# 74100
# retrieving 2025-02-03
# 357.2 percent is done
# 74400
# retrieving 2025-02-04
# 358.2 percent is done
# 74700
# retrieving 2025-02-05
# 359.2 percent is done
# 75000
# retrieving 2025-02-06
# 360.2 percent is done
# 75300
# retrieving 2025-02-07
# 361.2 percent is done
# 75600
# retrieving 2025-02-08
# 362.2 percent is done
# 75600
# retrieving 2025-02-09
# 363.2 percent is done
# 75600
# retrieving 2025-02-10
# 364.2 percent is done
# 75900
# retrieving 2025-02-11
# 365.2 percent is done
# 76200
# retrieving 2025-02-12
# 366.2 percent is done
# 76500
# retrieving 2025-02-13
# 367.2 percent is done
# 76800
# retrieving 2025-02-14
# 368.2 percent is done
# 77100
# retrieving 2025-02-15
# 369.2 percent is done
# 77100
# retrieving 2025-02-16
# 370.2 percent is done
# 77100
# retrieving 2025-02-18
# 371.2 percent is done
# 77400
# retrieving 2025-02-19
# 372.2 percent is done
# 77700
# retrieving 2025-02-20
# 373.2 percent is done
# 78000
# retrieving 2025-02-21
# 374.2 percent is done
# 78300
# retrieving 2025-02-22
# 375.2 percent is done
# 78300
# retrieving 2025-02-23
# 376.2 percent is done
# 78300
# retrieving 2025-02-24
# 377.2 percent is done
# 78600
# retrieving 2025-02-25
# 378.2 percent is done
# 78900
# retrieving 2025-02-26
# 379.2 percent is done
# 79200
# retrieving 2025-02-27
# 380.2 percent is done
# 79500
# retrieving 2025-02-28
# 381.2 percent is done
# 79800
# retrieving 2025-03-01
# 382.2 percent is done
# 79800
# retrieving 2025-03-02
# 383.2 percent is done
# 79800
# retrieving 2025-03-03
# 384.2 percent is done
# 80100
# retrieving 2025-03-04
# 385.2 percent is done
# 80400
# retrieving 2025-03-05
# 386.2 percent is done
# 80700
# retrieving 2025-03-06
# 387.2 percent is done
# 81000
# retrieving 2025-03-07
# 388.2 percent is done
# 81300
# retrieving 2025-03-08
# 389.2 percent is done
# 81300
# retrieving 2025-03-09
# 390.2 percent is done
# 81300
# retrieving 2025-03-10
# 391.2 percent is done
# 81600
# retrieving 2025-03-11
# 392.2 percent is done
# 81900
# retrieving 2025-03-12
# 393.2 percent is done
# 82200
# retrieving 2025-03-13
# 394.2 percent is done
# 82500
# retrieving 2025-03-14
# 395.2 percent is done
# 82800
# retrieving 2025-03-15
# 396.2 percent is done
# 82800
# retrieving 2025-03-16
# 397.2 percent is done
# 82800
# retrieving 2025-03-17
# 398.2 percent is done
# 83100
# retrieving 2025-03-18
# 399.2 percent is done
# 83400
# retrieving 2025-03-19
# 400.2 percent is done
# 83700
# retrieving 2025-03-20
# 401.2 percent is done
# 84000
# retrieving 2025-03-21
# 402.2 percent is done
# 84300
# retrieving 2025-03-22
# 403.2 percent is done
# 84300
# retrieving 2025-03-23
# 404.2 percent is done
# 84300
# retrieving 2025-03-24
# 405.2 percent is done
# 84600
# retrieving 2025-03-25
# 406.2 percent is done
# 84900
# retrieving 2025-03-26
# 407.2 percent is done
# 85200
# retrieving 2025-03-27
# 408.2 percent is done
# 85500
# retrieving 2025-03-28
# 409.2 percent is done
# 85800
# retrieving 2025-03-29
# 410.2 percent is done
# 85800
# retrieving 2025-03-30
# 411.2 percent is done
# 85800
# retrieving 2025-03-31
# 412.2 percent is done
# 86100
# retrieving 2025-04-01
# 413.2 percent is done
# 0
# retrieving 2024-02-01
# 0.2 percent is done
# 90
# retrieving 2024-02-02
# 1.2 percent is done
# 180
# retrieving 2024-02-03
# 2.2 percent is done
# 180
# retrieving 2024-02-04
# 3.2 percent is done
# 180
# retrieving 2024-02-05
# 4.2 percent is done
# 270
# retrieving 2024-02-06
# 5.2 percent is done
# 360
# retrieving 2024-02-07
# 6.2 percent is done
# 450
# retrieving 2024-02-08
# 7.2 percent is done
# 540
# retrieving 2024-02-09
# 8.2 percent is done
# 630
# retrieving 2024-02-10
# 9.2 percent is done
# 630
# retrieving 2024-02-11
# 10.2 percent is done
# 630
# retrieving 2024-02-12
# 11.2 percent is done
# 720
# retrieving 2024-02-13
# 12.2 percent is done
# 810
# retrieving 2024-02-14
# 13.2 percent is done
# 900
# retrieving 2024-02-15
# 14.2 percent is done
# 990
# retrieving 2024-02-16
# 15.2 percent is done
# 1080
# retrieving 2024-02-17
# 16.2 percent is done
# 1080
# retrieving 2024-02-18
# 17.2 percent is done
# 1080
# retrieving 2024-02-20
# 18.2 percent is done
# 1170
# retrieving 2024-02-21
# 19.2 percent is done
# 1260
# retrieving 2024-02-22
# 20.2 percent is done
# 1350
# retrieving 2024-02-23
# 21.2 percent is done
# 1440
# retrieving 2024-02-24
# 22.2 percent is done
# 1440
# retrieving 2024-02-25
# 23.2 percent is done
# 1440
# retrieving 2024-02-26
# 24.2 percent is done
# 1530
# retrieving 2024-02-27
# 25.2 percent is done
# 1620
# retrieving 2024-02-28
# 26.2 percent is done
# 1710
# retrieving 2024-02-29
# 27.2 percent is done
# 1800
# retrieving 2024-03-01
# 28.2 percent is done
# 1890
# retrieving 2024-03-02
# 29.2 percent is done
# 1890
# retrieving 2024-03-03
# 30.2 percent is done
# 1890
# retrieving 2024-03-04
# 31.2 percent is done
# 1980
# retrieving 2024-03-05
# 32.2 percent is done
# 2070
# retrieving 2024-03-06
# 33.2 percent is done
# 2160
# retrieving 2024-03-07
# 34.2 percent is done
# 2250
# retrieving 2024-03-08
# 35.2 percent is done
# 2340
# retrieving 2024-03-09
# 36.2 percent is done
# 2340
# retrieving 2024-03-10
# 37.2 percent is done
# 2340
# retrieving 2024-03-11
# 38.2 percent is done
# 2430
# retrieving 2024-03-12
# 39.2 percent is done
# 2520
# retrieving 2024-03-13
# 40.2 percent is done
# 2610
# retrieving 2024-03-14
# 41.2 percent is done
# 2700
# retrieving 2024-03-15
# 42.2 percent is done
# 2790
# retrieving 2024-03-16
# 43.2 percent is done
# 2790
# retrieving 2024-03-17
# 44.2 percent is done
# 2790
# retrieving 2024-03-18
# 45.2 percent is done
# 2880
# retrieving 2024-03-19
# 46.2 percent is done
# 2970
# retrieving 2024-03-20
# 47.2 percent is done
# 3060
# retrieving 2024-03-21
# 48.2 percent is done
# 3150
# retrieving 2024-03-22
# 49.2 percent is done
# 3240
# retrieving 2024-03-23
# 50.2 percent is done
# 3240
# retrieving 2024-03-24
# 51.2 percent is done
# 3240
# retrieving 2024-03-25
# 52.2 percent is done
# 3330
# retrieving 2024-03-26
# 53.2 percent is done
# 3420
# retrieving 2024-03-27
# 54.2 percent is done
# 3510
# retrieving 2024-03-28
# 55.2 percent is done
# 3600
# retrieving 2024-03-30
# 56.2 percent is done
# 3600
# retrieving 2024-03-31
# 57.2 percent is done
# 3600
# retrieving 2024-04-01
# 58.2 percent is done
# 3690
# retrieving 2024-04-02
# 59.2 percent is done
# 3780
# retrieving 2024-04-03
# 60.2 percent is done
# 3870
# retrieving 2024-04-04
# 61.2 percent is done
# 3960
# retrieving 2024-04-05
# 62.2 percent is done
# 4050
# retrieving 2024-04-06
# 63.2 percent is done
# 4050
# retrieving 2024-04-07
# 64.2 percent is done
# 4050
# retrieving 2024-04-08
# 65.2 percent is done
# 4140
# retrieving 2024-04-09
# 66.2 percent is done
# 4230
# retrieving 2024-04-10
# 67.2 percent is done
# 4320
# retrieving 2024-04-11
# 68.2 percent is done
# 4410
# retrieving 2024-04-12
# 69.2 percent is done
# 4500
# retrieving 2024-04-13
# 70.2 percent is done
# 4500
# retrieving 2024-04-14
# 71.2 percent is done
# 4500
# retrieving 2024-04-15
# 72.2 percent is done
# 4590
# retrieving 2024-04-16
# 73.2 percent is done
# 4680
# retrieving 2024-04-17
# 74.2 percent is done
# 4770
# retrieving 2024-04-18
# 75.2 percent is done
# 4860
# retrieving 2024-04-19
# 76.2 percent is done
# 4950
# retrieving 2024-04-20
# 77.2 percent is done
# 4950
# retrieving 2024-04-21
# 78.2 percent is done
# 4950
# retrieving 2024-04-22
# 79.2 percent is done
# 5040
# retrieving 2024-04-23
# 80.2 percent is done
# 5130
# retrieving 2024-04-24
# 81.2 percent is done
# 5220
# retrieving 2024-04-25
# 82.2 percent is done
# 5310
# retrieving 2024-04-26
# 83.2 percent is done
# 5400
# retrieving 2024-04-27
# 84.2 percent is done
# 5400
# retrieving 2024-04-28
# 85.2 percent is done
# 5400
# retrieving 2024-04-29
# 86.2 percent is done
# 5490
# retrieving 2024-04-30
# 87.2 percent is done
# 5580
# retrieving 2024-05-01
# 88.2 percent is done
# 5670
# retrieving 2024-05-02
# 89.2 percent is done
# 5760
# retrieving 2024-05-03
# 90.2 percent is done
# 5850
# retrieving 2024-05-04
# 91.2 percent is done
# 5850
# retrieving 2024-05-05
# 92.2 percent is done
# 5850
# retrieving 2024-05-06
# 93.2 percent is done
# 5940
# retrieving 2024-05-07
# 94.2 percent is done
# 6030
# retrieving 2024-05-08
# 95.2 percent is done
# 6120
# retrieving 2024-05-09
# 96.2 percent is done
# 6210
# retrieving 2024-05-10
# 97.2 percent is done
# 6300
# retrieving 2024-05-11
# 98.2 percent is done
# 6300
# retrieving 2024-05-12
# 99.2 percent is done
# 6300
# retrieving 2024-05-13
# 100.2 percent is done
# 6390
# retrieving 2024-05-14
# 101.2 percent is done
# 6480
# retrieving 2024-05-15
# 102.2 percent is done
# 6570
# retrieving 2024-05-16
# 103.2 percent is done
# 6660
# retrieving 2024-05-17
# 104.2 percent is done
# 6750
# retrieving 2024-05-18
# 105.2 percent is done
# 6750
# retrieving 2024-05-19
# 106.2 percent is done
# 6750
# retrieving 2024-05-20
# 107.2 percent is done
# 6840
# retrieving 2024-05-21
# 108.2 percent is done
# 6930
# retrieving 2024-05-22
# 109.2 percent is done
# 7020
# retrieving 2024-05-23
# 110.2 percent is done
# 7110
# retrieving 2024-05-24
# 111.2 percent is done
# 7200
# retrieving 2024-05-25
# 112.2 percent is done
# 7200
# retrieving 2024-05-26
# 113.2 percent is done
# 7200
# retrieving 2024-05-28
# 114.2 percent is done
# 7290
# retrieving 2024-05-29
# 115.2 percent is done
# 7380
# retrieving 2024-05-30
# 116.2 percent is done
# 7470
# retrieving 2024-05-31
# 117.2 percent is done
# 7560
# retrieving 2024-06-01
# 118.2 percent is done
# 7560
# retrieving 2024-06-02
# 119.2 percent is done
# 7560
# retrieving 2024-06-03
# 120.2 percent is done
# 7650
# retrieving 2024-06-04
# 121.2 percent is done
# 7740
# retrieving 2024-06-05
# 122.2 percent is done
# 7830
# retrieving 2024-06-06
# 123.2 percent is done
# 7920
# retrieving 2024-06-07
# 124.2 percent is done
# 8010
# retrieving 2024-06-08
# 125.2 percent is done
# 8010
# retrieving 2024-06-09
# 126.2 percent is done
# 8010
# retrieving 2024-06-10
# 127.2 percent is done
# 8100
# retrieving 2024-06-11
# 128.2 percent is done
# 8190
# retrieving 2024-06-12
# 129.2 percent is done
# 8280
# retrieving 2024-06-13
# 130.2 percent is done
# 8370
# retrieving 2024-06-14
# 131.2 percent is done
# 8460
# retrieving 2024-06-15
# 132.2 percent is done
# 8460
# retrieving 2024-06-16
# 133.2 percent is done
# 8460
# retrieving 2024-06-17
# 134.2 percent is done
# 8550
# retrieving 2024-06-18
# 135.2 percent is done
# 8640
# retrieving 2024-06-20
# 136.2 percent is done
# 8730
# retrieving 2024-06-21
# 137.2 percent is done
# 8820
# retrieving 2024-06-22
# 138.2 percent is done
# 8820
# retrieving 2024-06-23
# 139.2 percent is done
# 8820
# retrieving 2024-06-24
# 140.2 percent is done
# 8910
# retrieving 2024-06-25
# 141.2 percent is done
# 9000
# retrieving 2024-06-26
# 142.2 percent is done
# 9090
# retrieving 2024-06-27
# 143.2 percent is done
# 9180
# retrieving 2024-06-28
# 144.2 percent is done
# 9270
# retrieving 2024-06-29
# 145.2 percent is done
# 9270
# retrieving 2024-06-30
# 146.2 percent is done
# 9270
# retrieving 2024-07-01
# 147.2 percent is done
# 9360
# retrieving 2024-07-02
# 148.2 percent is done
# 9450
# retrieving 2024-07-03
# 149.2 percent is done
# 9450
# retrieving 2024-07-05
# 150.2 percent is done
# 9540
# retrieving 2024-07-06
# 151.2 percent is done
# 9540
# retrieving 2024-07-07
# 152.2 percent is done
# 9540
# retrieving 2024-07-08
# 153.2 percent is done
# 9630
# retrieving 2024-07-09
# 154.2 percent is done
# 9720
# retrieving 2024-07-10
# 155.2 percent is done
# 9810
# retrieving 2024-07-11
# 156.2 percent is done
# 9900
# retrieving 2024-07-12
# 157.2 percent is done
# 9990
# retrieving 2024-07-13
# 158.2 percent is done
# 9990
# retrieving 2024-07-14
# 159.2 percent is done
# 9990
# retrieving 2024-07-15
# 160.2 percent is done
# 10080
# retrieving 2024-07-16
# 161.2 percent is done
# 10170
# retrieving 2024-07-17
# 162.2 percent is done
# 10260
# retrieving 2024-07-18
# 163.2 percent is done
# 10350
# retrieving 2024-07-19
# 164.2 percent is done
# 10440
# retrieving 2024-07-20
# 165.2 percent is done
# 10440
# retrieving 2024-07-21
# 166.2 percent is done
# 10440
# retrieving 2024-07-22
# 167.2 percent is done
# 10530
# retrieving 2024-07-23
# 168.2 percent is done
# 10620
# retrieving 2024-07-24
# 169.2 percent is done
# 10710
# retrieving 2024-07-25
# 170.2 percent is done
# 10800
# retrieving 2024-07-26
# 171.2 percent is done
# 10890
# retrieving 2024-07-27
# 172.2 percent is done
# 10890
# retrieving 2024-07-28
# 173.2 percent is done
# 10890
# retrieving 2024-07-29
# 174.2 percent is done
# 10980
# retrieving 2024-07-30
# 175.2 percent is done
# 11070
# retrieving 2024-07-31
# 176.2 percent is done
# 11160
# retrieving 2024-08-01
# 177.2 percent is done
# 11250
# retrieving 2024-08-02
# 178.2 percent is done
# 11340
# retrieving 2024-08-03
# 179.2 percent is done
# 11340
# retrieving 2024-08-04
# 180.2 percent is done
# 11340
# retrieving 2024-08-05
# 181.2 percent is done
# 11430
# retrieving 2024-08-06
# 182.2 percent is done
# 11520
# retrieving 2024-08-07
# 183.2 percent is done
# 11610
# retrieving 2024-08-08
# 184.2 percent is done
# 11700
# retrieving 2024-08-09
# 185.2 percent is done
# 11790
# retrieving 2024-08-10
# 186.2 percent is done
# 11790
# retrieving 2024-08-11
# 187.2 percent is done
# 11790
# retrieving 2024-08-12
# 188.2 percent is done
# 11880
# retrieving 2024-08-13
# 189.2 percent is done
# 11970
# retrieving 2024-08-14
# 190.2 percent is done
# 12060
# retrieving 2024-08-15
# 191.2 percent is done
# 12150
# retrieving 2024-08-16
# 192.2 percent is done
# 12240
# retrieving 2024-08-17
# 193.2 percent is done
# 12240
# retrieving 2024-08-18
# 194.2 percent is done
# 12240
# retrieving 2024-08-19
# 195.2 percent is done
# 12330
# retrieving 2024-08-20
# 196.2 percent is done
# 12420
# retrieving 2024-08-21
# 197.2 percent is done
# 12510
# retrieving 2024-08-22
# 198.2 percent is done
# 12600
# retrieving 2024-08-23
# 199.2 percent is done
# 12690
# retrieving 2024-08-24
# 200.2 percent is done
# 12690
# retrieving 2024-08-25
# 201.2 percent is done
# 12690
# retrieving 2024-08-26
# 202.2 percent is done
# 12780
# retrieving 2024-08-27
# 203.2 percent is done
# 12870
# retrieving 2024-08-28
# 204.2 percent is done
# 12960
# retrieving 2024-08-29
# 205.2 percent is done
# 13050
# retrieving 2024-08-30
# 206.2 percent is done
# 13140
# retrieving 2024-08-31
# 207.2 percent is done
# 13140
# retrieving 2024-09-01
# 208.2 percent is done
# 13140
# retrieving 2024-09-03
# 209.2 percent is done
# 13230
# retrieving 2024-09-04
# 210.2 percent is done
# 13320
# retrieving 2024-09-05
# 211.2 percent is done
# 13410
# retrieving 2024-09-06
# 212.2 percent is done
# 13500
# retrieving 2024-09-07
# 213.2 percent is done
# 13500
# retrieving 2024-09-08
# 214.2 percent is done
# 13500
# retrieving 2024-09-09
# 215.2 percent is done
# 13590
# retrieving 2024-09-10
# 216.2 percent is done
# 13680
# retrieving 2024-09-11
# 217.2 percent is done
# 13770
# retrieving 2024-09-12
# 218.2 percent is done
# 13860
# retrieving 2024-09-13
# 219.2 percent is done
# 13950
# retrieving 2024-09-14
# 220.2 percent is done
# 13950
# retrieving 2024-09-15
# 221.2 percent is done
# 13950
# retrieving 2024-09-16
# 222.2 percent is done
# 14040
# retrieving 2024-09-17
# 223.2 percent is done
# 14130
# retrieving 2024-09-18
# 224.2 percent is done
# 14220
# retrieving 2024-09-19
# 225.2 percent is done
# 14310
# retrieving 2024-09-20
# 226.2 percent is done
# 14400
# retrieving 2024-09-21
# 227.2 percent is done
# 14400
# retrieving 2024-09-22
# 228.2 percent is done
# 14400
# retrieving 2024-09-23
# 229.2 percent is done
# 14490
# retrieving 2024-09-24
# 230.2 percent is done
# 14580
# retrieving 2024-09-25
# 231.2 percent is done
# 14670
# retrieving 2024-09-26
# 232.2 percent is done
# 14760
# retrieving 2024-09-27
# 233.2 percent is done
# 14850
# retrieving 2024-09-28
# 234.2 percent is done
# 14850
# retrieving 2024-09-29
# 235.2 percent is done
# 14850
# retrieving 2024-09-30
# 236.2 percent is done
# 14940
# retrieving 2024-10-01
# 237.2 percent is done
# 15030
# retrieving 2024-10-02
# 238.2 percent is done
# 15120
# retrieving 2024-10-03
# 239.2 percent is done
# 15210
# retrieving 2024-10-04
# 240.2 percent is done
# 15300
# retrieving 2024-10-05
# 241.2 percent is done
# 15300
# retrieving 2024-10-06
# 242.2 percent is done
# 15300
# retrieving 2024-10-07
# 243.2 percent is done
# 15390
# retrieving 2024-10-08
# 244.2 percent is done
# 15480
# retrieving 2024-10-09
# 245.2 percent is done
# 15570
# retrieving 2024-10-10
# 246.2 percent is done
# 15660
# retrieving 2024-10-11
# 247.2 percent is done
# 15750
# retrieving 2024-10-12
# 248.2 percent is done
# 15750
# retrieving 2024-10-13
# 249.2 percent is done
# 15750
# retrieving 2024-10-14
# 250.2 percent is done
# 15840
# retrieving 2024-10-15
# 251.2 percent is done
# 15930
# retrieving 2024-10-16
# 252.2 percent is done
# 16020
# retrieving 2024-10-17
# 253.2 percent is done
# 16110
# retrieving 2024-10-18
# 254.2 percent is done
# 16200
# retrieving 2024-10-19
# 255.2 percent is done
# 16200
# retrieving 2024-10-20
# 256.2 percent is done
# 16200
# retrieving 2024-10-21
# 257.2 percent is done
# 16290
# retrieving 2024-10-22
# 258.2 percent is done
# 16380
# retrieving 2024-10-23
# 259.2 percent is done
# 16470
# retrieving 2024-10-24
# 260.2 percent is done
# 16560
# retrieving 2024-10-25
# 261.2 percent is done
# 16650
# retrieving 2024-10-26
# 262.2 percent is done
# 16650
# retrieving 2024-10-27
# 263.2 percent is done
# 16650
# retrieving 2024-10-28
# 264.2 percent is done
# 16740
# retrieving 2024-10-29
# 265.2 percent is done
# 16830
# retrieving 2024-10-30
# 266.2 percent is done
# 16920
# retrieving 2024-10-31
# 267.2 percent is done
# 17010
# retrieving 2024-11-01
# 268.2 percent is done
# 17100
# retrieving 2024-11-02
# 269.2 percent is done
# 17100
# retrieving 2024-11-03
# 270.2 percent is done
# 17100
# retrieving 2024-11-04
# 271.2 percent is done
# 17190
# retrieving 2024-11-05
# 272.2 percent is done
# 17280
# retrieving 2024-11-06
# 273.2 percent is done
# 17370
# retrieving 2024-11-07
# 274.2 percent is done
# 17460
# retrieving 2024-11-08
# 275.2 percent is done
# 17550
# retrieving 2024-11-09
# 276.2 percent is done
# 17550
# retrieving 2024-11-10
# 277.2 percent is done
# 17550
# retrieving 2024-11-11
# 278.2 percent is done
# 17640
# retrieving 2024-11-12
# 279.2 percent is done
# 17730
# retrieving 2024-11-13
# 280.2 percent is done
# 17820
# retrieving 2024-11-14
# 281.2 percent is done
# 17910
# retrieving 2024-11-15
# 282.2 percent is done
# 18000
# retrieving 2024-11-16
# 283.2 percent is done
# 18000
# retrieving 2024-11-17
# 284.2 percent is done
# 18000
# retrieving 2024-11-18
# 285.2 percent is done
# 18090
# retrieving 2024-11-19
# 286.2 percent is done
# 18180
# retrieving 2024-11-20
# 287.2 percent is done
# 18270
# retrieving 2024-11-21
# 288.2 percent is done
# 18360
# retrieving 2024-11-22
# 289.2 percent is done
# 18450
# retrieving 2024-11-23
# 290.2 percent is done
# 18450
# retrieving 2024-11-24
# 291.2 percent is done
# 18450
# retrieving 2024-11-25
# 292.2 percent is done
# 18540
# retrieving 2024-11-26
# 293.2 percent is done
# 18630
# retrieving 2024-11-27
# 294.2 percent is done
# 18720
# retrieving 2024-11-30
# 295.2 percent is done
# 18720
# retrieving 2024-12-01
# 296.2 percent is done
# 18720
# retrieving 2024-12-02
# 297.2 percent is done
# 18810
# retrieving 2024-12-03
# 298.2 percent is done
# 18900
# retrieving 2024-12-04
# 299.2 percent is done
# 18990
# retrieving 2024-12-05
# 300.2 percent is done
# 19080
# retrieving 2024-12-06
# 301.2 percent is done
# 19170
# retrieving 2024-12-07
# 302.2 percent is done
# 19170
# retrieving 2024-12-08
# 303.2 percent is done
# 19170
# retrieving 2024-12-09
# 304.2 percent is done
# 19260
# retrieving 2024-12-10
# 305.2 percent is done
# 19350
# retrieving 2024-12-11
# 306.2 percent is done
# 19440
# retrieving 2024-12-12
# 307.2 percent is done
# 19530
# retrieving 2024-12-13
# 308.2 percent is done
# 19620
# retrieving 2024-12-14
# 309.2 percent is done
# 19620
# retrieving 2024-12-15
# 310.2 percent is done
# 19620
# retrieving 2024-12-16
# 311.2 percent is done
# 19710
# retrieving 2024-12-17
# 312.2 percent is done
# 19800
# retrieving 2024-12-18
# 313.2 percent is done
# 19890
# retrieving 2024-12-19
# 314.2 percent is done
# 19980
# retrieving 2024-12-20
# 315.2 percent is done
# 20070
# retrieving 2024-12-21
# 316.2 percent is done
# 20070
# retrieving 2024-12-22
# 317.2 percent is done
# 20070
# retrieving 2024-12-23
# 318.2 percent is done
# 20160
# retrieving 2024-12-24
# 319.2 percent is done
# 20160
# retrieving 2024-12-26
# 320.2 percent is done
# 20250
# retrieving 2024-12-27
# 321.2 percent is done
# 20340
# retrieving 2024-12-28
# 322.2 percent is done
# 20340
# retrieving 2024-12-29
# 323.2 percent is done
# 20340
# retrieving 2024-12-30
# 324.2 percent is done
# 20430
# retrieving 2024-12-31
# 325.2 percent is done
# 20520
# retrieving 2025-01-02
# 326.2 percent is done
# 20610
# retrieving 2025-01-03
# 327.2 percent is done
# 20700
# retrieving 2025-01-04
# 328.2 percent is done
# 20700
# retrieving 2025-01-05
# 329.2 percent is done
# 20700
# retrieving 2025-01-06
# 330.2 percent is done
# 20790
# retrieving 2025-01-07
# 331.2 percent is done
# 20880
# retrieving 2025-01-08
# 332.2 percent is done
# 20880
# retrieving 2025-01-09
# 333.2 percent is done
# 20880
# retrieving 2025-01-10
# 334.2 percent is done
# 20970
# retrieving 2025-01-11
# 335.2 percent is done
# 20970
# retrieving 2025-01-12
# 336.2 percent is done
# 20970
# retrieving 2025-01-13
# 337.2 percent is done
# 21060
# retrieving 2025-01-14
# 338.2 percent is done
# 21150
# retrieving 2025-01-15
# 339.2 percent is done
# 21240
# retrieving 2025-01-16
# 340.2 percent is done
# 21330
# retrieving 2025-01-17
# 341.2 percent is done
# 21420
# retrieving 2025-01-18
# 342.2 percent is done
# 21420
# retrieving 2025-01-19
# 343.2 percent is done
# 21420
# retrieving 2025-01-21
# 344.2 percent is done
# 21510
# retrieving 2025-01-22
# 345.2 percent is done
# 21600
# retrieving 2025-01-23
# 346.2 percent is done
# 21690
# retrieving 2025-01-24
# 347.2 percent is done
# 21780
# retrieving 2025-01-25
# 348.2 percent is done
# 21780
# retrieving 2025-01-26
# 349.2 percent is done
# 21780
# retrieving 2025-01-27
# 350.2 percent is done
# 21870
# retrieving 2025-01-28
# 351.2 percent is done
# 21960
# retrieving 2025-01-29
# 352.2 percent is done
# 22050
# retrieving 2025-01-30
# 353.2 percent is done
# 22140
# retrieving 2025-01-31
# 354.2 percent is done
# 22230
# retrieving 2025-02-01
# 355.2 percent is done
# 22230
# retrieving 2025-02-02
# 356.2 percent is done
# 22230
# retrieving 2025-02-03
# 357.2 percent is done
# 22320
# retrieving 2025-02-04
# 358.2 percent is done
# 22410
# retrieving 2025-02-05
# 359.2 percent is done
# 22500
# retrieving 2025-02-06
# 360.2 percent is done
# 22590
# retrieving 2025-02-07
# 361.2 percent is done
# 22680
# retrieving 2025-02-08
# 362.2 percent is done
# 22680
# retrieving 2025-02-09
# 363.2 percent is done
# 22680
# retrieving 2025-02-10
# 364.2 percent is done
# 22770
# retrieving 2025-02-11
# 365.2 percent is done
# 22860
# retrieving 2025-02-12
# 366.2 percent is done
# 22950
# retrieving 2025-02-13
# 367.2 percent is done
# 23040
# retrieving 2025-02-14
# 368.2 percent is done
# 23130
# retrieving 2025-02-15
# 369.2 percent is done
# 23130
# retrieving 2025-02-16
# 370.2 percent is done
# 23130
# retrieving 2025-02-18
# 371.2 percent is done
# 23220
# retrieving 2025-02-19
# 372.2 percent is done
# 23310
# retrieving 2025-02-20
# 373.2 percent is done
# 23400
# retrieving 2025-02-21
# 374.2 percent is done
# 23490
# retrieving 2025-02-22
# 375.2 percent is done
# 23490
# retrieving 2025-02-23
# 376.2 percent is done
# 23490
# retrieving 2025-02-24
# 377.2 percent is done
# 23580
# retrieving 2025-02-25
# 378.2 percent is done
# 23670
# retrieving 2025-02-26
# 379.2 percent is done
# 23760
# retrieving 2025-02-27
# 380.2 percent is done
# 23850
# retrieving 2025-02-28
# 381.2 percent is done
# 23940
# retrieving 2025-03-01
# 382.2 percent is done
# 23940
# retrieving 2025-03-02
# 383.2 percent is done
# 23940
# retrieving 2025-03-03
# 384.2 percent is done
# 24030
# retrieving 2025-03-04
# 385.2 percent is done
# 24120
# retrieving 2025-03-05
# 386.2 percent is done
# 24210
# retrieving 2025-03-06
# 387.2 percent is done
# 24300
# retrieving 2025-03-07
# 388.2 percent is done
# 24390
# retrieving 2025-03-08
# 389.2 percent is done
# 24390
# retrieving 2025-03-09
# 390.2 percent is done
# 24390
# retrieving 2025-03-10
# 391.2 percent is done
# 24480
# retrieving 2025-03-11
# 392.2 percent is done
# 24570
# retrieving 2025-03-12
# 393.2 percent is done
# 24660
# retrieving 2025-03-13
# 394.2 percent is done
# 24750
# retrieving 2025-03-14
# 395.2 percent is done
# 24840
# retrieving 2025-03-15
# 396.2 percent is done
# 24840
# retrieving 2025-03-16
# 397.2 percent is done
# 24840
# retrieving 2025-03-17
# 398.2 percent is done
# 24930
# retrieving 2025-03-18
# 399.2 percent is done
# 25020
# retrieving 2025-03-19
# 400.2 percent is done
# 25110
# retrieving 2025-03-20
# 401.2 percent is done
# 25200
# retrieving 2025-03-21
# 402.2 percent is done
# 25290
# retrieving 2025-03-22
# 403.2 percent is done
# 25290
# retrieving 2025-03-23
# 404.2 percent is done
# 25290
# retrieving 2025-03-24
# 405.2 percent is done
# 25380
# retrieving 2025-03-25
# 406.2 percent is done
# 25470
# retrieving 2025-03-26
# 407.2 percent is done
# 25560
# retrieving 2025-03-27
# 408.2 percent is done
# 25650
# retrieving 2025-03-28
# 409.2 percent is done
# 25740
# retrieving 2025-03-29
# 410.2 percent is done
# 25740
# retrieving 2025-03-30
# 411.2 percent is done
# 25740
# retrieving 2025-03-31
# 412.2 percent is done
# 25830
# retrieving 2025-04-01
# 413.2 percent is done
# 0
# 1
# 2

# %%
df_all_days_stock
# Out:
#                             date    open    high     low   close    volume  \
# 0      2024-02-01 09:30:00-05:00  393.96  396.03  393.66  395.48  305515.0
# 1      2024-02-01 09:31:00-05:00  395.41  396.38  394.68  396.38   83112.0
# 2      2024-02-01 09:32:00-05:00  396.34  397.79  396.26  397.20  131978.0
# 3      2024-02-01 09:33:00-05:00  397.21  398.23  397.10  397.25  122000.0
# 4      2024-02-01 09:34:00-05:00  397.22  399.45  397.00  399.20  154192.0
# ...                          ...     ...     ...     ...     ...       ...
# 113515 2025-04-01 15:55:00-04:00  586.51  587.37  585.49  585.74   51718.0
# 113516 2025-04-01 15:56:00-04:00  585.78  586.14  585.44  586.02   55195.0
# 113517 2025-04-01 15:57:00-04:00  586.10  586.20  585.74  585.93   43672.0
# 113518 2025-04-01 15:58:00-04:00  585.95  586.35  585.82  586.31   63359.0
# 113519 2025-04-01 15:59:00-04:00  586.29  586.29  585.58  585.95  115878.0
#
#         average  barCount   Date_Only
# 0       394.495       760  2024-02-01
# 1       395.372       435  2024-02-01
# 2       397.086       786  2024-02-01
# 3       397.734       666  2024-02-01
# 4       398.259       784  2024-02-01
# ...         ...       ...         ...
# 113515  586.359       386  2025-04-01
# 113516  585.823       399  2025-04-01
# 113517  585.957       339  2025-04-01
# 113518  586.068       517  2025-04-01
# 113519  585.885       924  2025-04-01
#
# [113520 rows x 9 columns]

# %%
df_all_days_stock.shape
# Out:
# (112320, 9)

# %%
df_VIX.shape
# Out:
# (112320, 9)

# %%
df_TQQQ.shape
# Out:
# (112320, 9)

# %%
for d in biz_dates:
    for df in df_TQQQ:
        if len(df_TQQQ[df_TQQQ['Date_Only']==d]) !=390:
            print(d)
# Out:
# 2024-07-03
# 2024-07-03
# 2024-07-03
# 2024-07-03
# 2024-07-03
# 2024-07-03
# 2024-07-03
# 2024-07-03
# 2024-07-03
# 2024-12-24
# 2024-12-24
# 2024-12-24
# 2024-12-24
# 2024-12-24
# 2024-12-24
# 2024-12-24
# 2024-12-24
# 2024-12-24
# 2025-01-08
# 2025-01-08
# 2025-01-08
# 2025-01-08
# 2025-01-08
# 2025-01-08
# 2025-01-08
# 2025-01-08
# 2025-01-08
# 2025-01-09
# 2025-01-09
# 2025-01-09
# 2025-01-09
# 2025-01-09
# 2025-01-09
# 2025-01-09
# 2025-01-09
# 2025-01-09

# %%
df_VIX_clean = df_VIX[(df_VIX['Date_Only'] !=date(2024,7,3)) &  (df_VIX['Date_Only'] != date(2024,12,24)) & (df_VIX['Date_Only'] != date(2025,1,8)) &(df_VIX['Date_Only'] != date(2025,1,9)) ]

# %%
df_stock_clean = df_all_days_stock[(df_all_days_stock['Date_Only'] !=date(2024,7,3)) &  (df_all_days_stock['Date_Only'] != date(2024,12,24)) & (df_all_days_stock['Date_Only'] != date(2025,1,8)) &(df_all_days_stock['Date_Only'] != date(2025,1,9)) ]

# %%
df_TQQQ_clean = df_TQQQ[(df_TQQQ['Date_Only'] !=date(2024,7,3)) &  (df_TQQQ['Date_Only'] != date(2024,12,24)) & (df_TQQQ['Date_Only'] != date(2025,1,8)) &(df_TQQQ['Date_Only'] != date(2025,1,9)) ]

# %%
df_TQQQ.shape
# Out:
# (112320, 9)

# %%
# switching
df_VIX = pd.DataFrame()
df_VIX = df_VIX_clean.copy()

df_TQQQ = pd.DataFrame()
df_TQQQ = df_TQQQ_clean.copy()

df_all_days_stock = pd.DataFrame()
df_all_days_stock = df_stock_clean.copy()

# %%
df_group_train_vix, *_  = data_sparcing_construc(df_VIX, all_dates, cut_time= cut_time)
df_group_train_tqqq, *_ = data_sparcing_construc(df_TQQQ, all_dates, cut_time= cut_time)
# Out:
# 0
# retrieving 2024-02-01
# 0.2 percent is done
# 300
# retrieving 2024-02-02
# 1.2 percent is done
# 600
# retrieving 2024-02-03
# 2.2 percent is done
# 600
# retrieving 2024-02-04
# 3.2 percent is done
# 600
# retrieving 2024-02-05
# 4.2 percent is done
# 900
# retrieving 2024-02-06
# 5.2 percent is done
# 1200
# retrieving 2024-02-07
# 6.2 percent is done
# 1500
# retrieving 2024-02-08
# 7.2 percent is done
# 1800
# retrieving 2024-02-09
# 8.2 percent is done
# 2100
# retrieving 2024-02-10
# 9.2 percent is done
# 2100
# retrieving 2024-02-11
# 10.2 percent is done
# 2100
# retrieving 2024-02-12
# 11.2 percent is done
# 2400
# retrieving 2024-02-13
# 12.2 percent is done
# 2700
# retrieving 2024-02-14
# 13.2 percent is done
# 3000
# retrieving 2024-02-15
# 14.2 percent is done
# 3300
# retrieving 2024-02-16
# 15.2 percent is done
# 3600
# retrieving 2024-02-17
# 16.2 percent is done
# 3600
# retrieving 2024-02-18
# 17.2 percent is done
# 3600
# retrieving 2024-02-20
# 18.2 percent is done
# 3900
# retrieving 2024-02-21
# 19.2 percent is done
# 4200
# retrieving 2024-02-22
# 20.2 percent is done
# 4500
# retrieving 2024-02-23
# 21.2 percent is done
# 4800
# retrieving 2024-02-24
# 22.2 percent is done
# 4800
# retrieving 2024-02-25
# 23.2 percent is done
# 4800
# retrieving 2024-02-26
# 24.2 percent is done
# 5100
# retrieving 2024-02-27
# 25.2 percent is done
# 5400
# retrieving 2024-02-28
# 26.2 percent is done
# 5700
# retrieving 2024-02-29
# 27.2 percent is done
# 6000
# retrieving 2024-03-01
# 28.2 percent is done
# 6300
# retrieving 2024-03-02
# 29.2 percent is done
# 6300
# retrieving 2024-03-03
# 30.2 percent is done
# 6300
# retrieving 2024-03-04
# 31.2 percent is done
# 6600
# retrieving 2024-03-05
# 32.2 percent is done
# 6900
# retrieving 2024-03-06
# 33.2 percent is done
# 7200
# retrieving 2024-03-07
# 34.2 percent is done
# 7500
# retrieving 2024-03-08
# 35.2 percent is done
# 7800
# retrieving 2024-03-09
# 36.2 percent is done
# 7800
# retrieving 2024-03-10
# 37.2 percent is done
# 7800
# retrieving 2024-03-11
# 38.2 percent is done
# 8100
# retrieving 2024-03-12
# 39.2 percent is done
# 8400
# retrieving 2024-03-13
# 40.2 percent is done
# 8700
# retrieving 2024-03-14
# 41.2 percent is done
# 9000
# retrieving 2024-03-15
# 42.2 percent is done
# 9300
# retrieving 2024-03-16
# 43.2 percent is done
# 9300
# retrieving 2024-03-17
# 44.2 percent is done
# 9300
# retrieving 2024-03-18
# 45.2 percent is done
# 9600
# retrieving 2024-03-19
# 46.2 percent is done
# 9900
# retrieving 2024-03-20
# 47.2 percent is done
# 10200
# retrieving 2024-03-21
# 48.2 percent is done
# 10500
# retrieving 2024-03-22
# 49.2 percent is done
# 10800
# retrieving 2024-03-23
# 50.2 percent is done
# 10800
# retrieving 2024-03-24
# 51.2 percent is done
# 10800
# retrieving 2024-03-25
# 52.2 percent is done
# 11100
# retrieving 2024-03-26
# 53.2 percent is done
# 11400
# retrieving 2024-03-27
# 54.2 percent is done
# 11700
# retrieving 2024-03-28
# 55.2 percent is done
# 12000
# retrieving 2024-03-30
# 56.2 percent is done
# 12000
# retrieving 2024-03-31
# 57.2 percent is done
# 12000
# retrieving 2024-04-01
# 58.2 percent is done
# 12300
# retrieving 2024-04-02
# 59.2 percent is done
# 12600
# retrieving 2024-04-03
# 60.2 percent is done
# 12900
# retrieving 2024-04-04
# 61.2 percent is done
# 13200
# retrieving 2024-04-05
# 62.2 percent is done
# 13500
# retrieving 2024-04-06
# 63.2 percent is done
# 13500
# retrieving 2024-04-07
# 64.2 percent is done
# 13500
# retrieving 2024-04-08
# 65.2 percent is done
# 13800
# retrieving 2024-04-09
# 66.2 percent is done
# 14100
# retrieving 2024-04-10
# 67.2 percent is done
# 14400
# retrieving 2024-04-11
# 68.2 percent is done
# 14700
# retrieving 2024-04-12
# 69.2 percent is done
# 15000
# retrieving 2024-04-13
# 70.2 percent is done
# 15000
# retrieving 2024-04-14
# 71.2 percent is done
# 15000
# retrieving 2024-04-15
# 72.2 percent is done
# 15300
# retrieving 2024-04-16
# 73.2 percent is done
# 15600
# retrieving 2024-04-17
# 74.2 percent is done
# 15900
# retrieving 2024-04-18
# 75.2 percent is done
# 16200
# retrieving 2024-04-19
# 76.2 percent is done
# 16500
# retrieving 2024-04-20
# 77.2 percent is done
# 16500
# retrieving 2024-04-21
# 78.2 percent is done
# 16500
# retrieving 2024-04-22
# 79.2 percent is done
# 16800
# retrieving 2024-04-23
# 80.2 percent is done
# 17100
# retrieving 2024-04-24
# 81.2 percent is done
# 17400
# retrieving 2024-04-25
# 82.2 percent is done
# 17700
# retrieving 2024-04-26
# 83.2 percent is done
# 18000
# retrieving 2024-04-27
# 84.2 percent is done
# 18000
# retrieving 2024-04-28
# 85.2 percent is done
# 18000
# retrieving 2024-04-29
# 86.2 percent is done
# 18300
# retrieving 2024-04-30
# 87.2 percent is done
# 18600
# retrieving 2024-05-01
# 88.2 percent is done
# 18900
# retrieving 2024-05-02
# 89.2 percent is done
# 19200
# retrieving 2024-05-03
# 90.2 percent is done
# 19500
# retrieving 2024-05-04
# 91.2 percent is done
# 19500
# retrieving 2024-05-05
# 92.2 percent is done
# 19500
# retrieving 2024-05-06
# 93.2 percent is done
# 19800
# retrieving 2024-05-07
# 94.2 percent is done
# 20100
# retrieving 2024-05-08
# 95.2 percent is done
# 20400
# retrieving 2024-05-09
# 96.2 percent is done
# 20700
# retrieving 2024-05-10
# 97.2 percent is done
# 21000
# retrieving 2024-05-11
# 98.2 percent is done
# 21000
# retrieving 2024-05-12
# 99.2 percent is done
# 21000
# retrieving 2024-05-13
# 100.2 percent is done
# 21300
# retrieving 2024-05-14
# 101.2 percent is done
# 21600
# retrieving 2024-05-15
# 102.2 percent is done
# 21900
# retrieving 2024-05-16
# 103.2 percent is done
# 22200
# retrieving 2024-05-17
# 104.2 percent is done
# 22500
# retrieving 2024-05-18
# 105.2 percent is done
# 22500
# retrieving 2024-05-19
# 106.2 percent is done
# 22500
# retrieving 2024-05-20
# 107.2 percent is done
# 22800
# retrieving 2024-05-21
# 108.2 percent is done
# 23100
# retrieving 2024-05-22
# 109.2 percent is done
# 23400
# retrieving 2024-05-23
# 110.2 percent is done
# 23700
# retrieving 2024-05-24
# 111.2 percent is done
# 24000
# retrieving 2024-05-25
# 112.2 percent is done
# 24000
# retrieving 2024-05-26
# 113.2 percent is done
# 24000
# retrieving 2024-05-28
# 114.2 percent is done
# 24300
# retrieving 2024-05-29
# 115.2 percent is done
# 24600
# retrieving 2024-05-30
# 116.2 percent is done
# 24900
# retrieving 2024-05-31
# 117.2 percent is done
# 25200
# retrieving 2024-06-01
# 118.2 percent is done
# 25200
# retrieving 2024-06-02
# 119.2 percent is done
# 25200
# retrieving 2024-06-03
# 120.2 percent is done
# 25500
# retrieving 2024-06-04
# 121.2 percent is done
# 25800
# retrieving 2024-06-05
# 122.2 percent is done
# 26100
# retrieving 2024-06-06
# 123.2 percent is done
# 26400
# retrieving 2024-06-07
# 124.2 percent is done
# 26700
# retrieving 2024-06-08
# 125.2 percent is done
# 26700
# retrieving 2024-06-09
# 126.2 percent is done
# 26700
# retrieving 2024-06-10
# 127.2 percent is done
# 27000
# retrieving 2024-06-11
# 128.2 percent is done
# 27300
# retrieving 2024-06-12
# 129.2 percent is done
# 27600
# retrieving 2024-06-13
# 130.2 percent is done
# 27900
# retrieving 2024-06-14
# 131.2 percent is done
# 28200
# retrieving 2024-06-15
# 132.2 percent is done
# 28200
# retrieving 2024-06-16
# 133.2 percent is done
# 28200
# retrieving 2024-06-17
# 134.2 percent is done
# 28500
# retrieving 2024-06-18
# 135.2 percent is done
# 28800
# retrieving 2024-06-20
# 136.2 percent is done
# 29100
# retrieving 2024-06-21
# 137.2 percent is done
# 29400
# retrieving 2024-06-22
# 138.2 percent is done
# 29400
# retrieving 2024-06-23
# 139.2 percent is done
# 29400
# retrieving 2024-06-24
# 140.2 percent is done
# 29700
# retrieving 2024-06-25
# 141.2 percent is done
# 30000
# retrieving 2024-06-26
# 142.2 percent is done
# 30300
# retrieving 2024-06-27
# 143.2 percent is done
# 30600
# retrieving 2024-06-28
# 144.2 percent is done
# 30900
# retrieving 2024-06-29
# 145.2 percent is done
# 30900
# retrieving 2024-06-30
# 146.2 percent is done
# 30900
# retrieving 2024-07-01
# 147.2 percent is done
# 31200
# retrieving 2024-07-02
# 148.2 percent is done
# 31500
# retrieving 2024-07-03
# 149.2 percent is done
# 31500
# retrieving 2024-07-05
# 150.2 percent is done
# 31800
# retrieving 2024-07-06
# 151.2 percent is done
# 31800
# retrieving 2024-07-07
# 152.2 percent is done
# 31800
# retrieving 2024-07-08
# 153.2 percent is done
# 32100
# retrieving 2024-07-09
# 154.2 percent is done
# 32400
# retrieving 2024-07-10
# 155.2 percent is done
# 32700
# retrieving 2024-07-11
# 156.2 percent is done
# 33000
# retrieving 2024-07-12
# 157.2 percent is done
# 33300
# retrieving 2024-07-13
# 158.2 percent is done
# 33300
# retrieving 2024-07-14
# 159.2 percent is done
# 33300
# retrieving 2024-07-15
# 160.2 percent is done
# 33600
# retrieving 2024-07-16
# 161.2 percent is done
# 33900
# retrieving 2024-07-17
# 162.2 percent is done
# 34200
# retrieving 2024-07-18
# 163.2 percent is done
# 34500
# retrieving 2024-07-19
# 164.2 percent is done
# 34800
# retrieving 2024-07-20
# 165.2 percent is done
# 34800
# retrieving 2024-07-21
# 166.2 percent is done
# 34800
# retrieving 2024-07-22
# 167.2 percent is done
# 35100
# retrieving 2024-07-23
# 168.2 percent is done
# 35400
# retrieving 2024-07-24
# 169.2 percent is done
# 35700
# retrieving 2024-07-25
# 170.2 percent is done
# 36000
# retrieving 2024-07-26
# 171.2 percent is done
# 36300
# retrieving 2024-07-27
# 172.2 percent is done
# 36300
# retrieving 2024-07-28
# 173.2 percent is done
# 36300
# retrieving 2024-07-29
# 174.2 percent is done
# 36600
# retrieving 2024-07-30
# 175.2 percent is done
# 36900
# retrieving 2024-07-31
# 176.2 percent is done
# 37200
# retrieving 2024-08-01
# 177.2 percent is done
# 37500
# retrieving 2024-08-02
# 178.2 percent is done
# 37800
# retrieving 2024-08-03
# 179.2 percent is done
# 37800
# retrieving 2024-08-04
# 180.2 percent is done
# 37800
# retrieving 2024-08-05
# 181.2 percent is done
# 38100
# retrieving 2024-08-06
# 182.2 percent is done
# 38400
# retrieving 2024-08-07
# 183.2 percent is done
# 38700
# retrieving 2024-08-08
# 184.2 percent is done
# 39000
# retrieving 2024-08-09
# 185.2 percent is done
# 39300
# retrieving 2024-08-10
# 186.2 percent is done
# 39300
# retrieving 2024-08-11
# 187.2 percent is done
# 39300
# retrieving 2024-08-12
# 188.2 percent is done
# 39600
# retrieving 2024-08-13
# 189.2 percent is done
# 39900
# retrieving 2024-08-14
# 190.2 percent is done
# 40200
# retrieving 2024-08-15
# 191.2 percent is done
# 40500
# retrieving 2024-08-16
# 192.2 percent is done
# 40800
# retrieving 2024-08-17
# 193.2 percent is done
# 40800
# retrieving 2024-08-18
# 194.2 percent is done
# 40800
# retrieving 2024-08-19
# 195.2 percent is done
# 41100
# retrieving 2024-08-20
# 196.2 percent is done
# 41400
# retrieving 2024-08-21
# 197.2 percent is done
# 41700
# retrieving 2024-08-22
# 198.2 percent is done
# 42000
# retrieving 2024-08-23
# 199.2 percent is done
# 42300
# retrieving 2024-08-24
# 200.2 percent is done
# 42300
# retrieving 2024-08-25
# 201.2 percent is done
# 42300
# retrieving 2024-08-26
# 202.2 percent is done
# 42600
# retrieving 2024-08-27
# 203.2 percent is done
# 42900
# retrieving 2024-08-28
# 204.2 percent is done
# 43200
# retrieving 2024-08-29
# 205.2 percent is done
# 43500
# retrieving 2024-08-30
# 206.2 percent is done
# 43800
# retrieving 2024-08-31
# 207.2 percent is done
# 43800
# retrieving 2024-09-01
# 208.2 percent is done
# 43800
# retrieving 2024-09-03
# 209.2 percent is done
# 44100
# retrieving 2024-09-04
# 210.2 percent is done
# 44400
# retrieving 2024-09-05
# 211.2 percent is done
# 44700
# retrieving 2024-09-06
# 212.2 percent is done
# 45000
# retrieving 2024-09-07
# 213.2 percent is done
# 45000
# retrieving 2024-09-08
# 214.2 percent is done
# 45000
# retrieving 2024-09-09
# 215.2 percent is done
# 45300
# retrieving 2024-09-10
# 216.2 percent is done
# 45600
# retrieving 2024-09-11
# 217.2 percent is done
# 45900
# retrieving 2024-09-12
# 218.2 percent is done
# 46200
# retrieving 2024-09-13
# 219.2 percent is done
# 46500
# retrieving 2024-09-14
# 220.2 percent is done
# 46500
# retrieving 2024-09-15
# 221.2 percent is done
# 46500
# retrieving 2024-09-16
# 222.2 percent is done
# 46800
# retrieving 2024-09-17
# 223.2 percent is done
# 47100
# retrieving 2024-09-18
# 224.2 percent is done
# 47400
# retrieving 2024-09-19
# 225.2 percent is done
# 47700
# retrieving 2024-09-20
# 226.2 percent is done
# 48000
# retrieving 2024-09-21
# 227.2 percent is done
# 48000
# retrieving 2024-09-22
# 228.2 percent is done
# 48000
# retrieving 2024-09-23
# 229.2 percent is done
# 48300
# retrieving 2024-09-24
# 230.2 percent is done
# 48600
# retrieving 2024-09-25
# 231.2 percent is done
# 48900
# retrieving 2024-09-26
# 232.2 percent is done
# 49200
# retrieving 2024-09-27
# 233.2 percent is done
# 49500
# retrieving 2024-09-28
# 234.2 percent is done
# 49500
# retrieving 2024-09-29
# 235.2 percent is done
# 49500
# retrieving 2024-09-30
# 236.2 percent is done
# 49800
# retrieving 2024-10-01
# 237.2 percent is done
# 50100
# retrieving 2024-10-02
# 238.2 percent is done
# 50400
# retrieving 2024-10-03
# 239.2 percent is done
# 50700
# retrieving 2024-10-04
# 240.2 percent is done
# 51000
# retrieving 2024-10-05
# 241.2 percent is done
# 51000
# retrieving 2024-10-06
# 242.2 percent is done
# 51000
# retrieving 2024-10-07
# 243.2 percent is done
# 51300
# retrieving 2024-10-08
# 244.2 percent is done
# 51600
# retrieving 2024-10-09
# 245.2 percent is done
# 51900
# retrieving 2024-10-10
# 246.2 percent is done
# 52200
# retrieving 2024-10-11
# 247.2 percent is done
# 52500
# retrieving 2024-10-12
# 248.2 percent is done
# 52500
# retrieving 2024-10-13
# 249.2 percent is done
# 52500
# retrieving 2024-10-14
# 250.2 percent is done
# 52800
# retrieving 2024-10-15
# 251.2 percent is done
# 53100
# retrieving 2024-10-16
# 252.2 percent is done
# 53400
# retrieving 2024-10-17
# 253.2 percent is done
# 53700
# retrieving 2024-10-18
# 254.2 percent is done
# 54000
# retrieving 2024-10-19
# 255.2 percent is done
# 54000
# retrieving 2024-10-20
# 256.2 percent is done
# 54000
# retrieving 2024-10-21
# 257.2 percent is done
# 54300
# retrieving 2024-10-22
# 258.2 percent is done
# 54600
# retrieving 2024-10-23
# 259.2 percent is done
# 54900
# retrieving 2024-10-24
# 260.2 percent is done
# 55200
# retrieving 2024-10-25
# 261.2 percent is done
# 55500
# retrieving 2024-10-26
# 262.2 percent is done
# 55500
# retrieving 2024-10-27
# 263.2 percent is done
# 55500
# retrieving 2024-10-28
# 264.2 percent is done
# 55800
# retrieving 2024-10-29
# 265.2 percent is done
# 56100
# retrieving 2024-10-30
# 266.2 percent is done
# 56400
# retrieving 2024-10-31
# 267.2 percent is done
# 56700
# retrieving 2024-11-01
# 268.2 percent is done
# 57000
# retrieving 2024-11-02
# 269.2 percent is done
# 57000
# retrieving 2024-11-03
# 270.2 percent is done
# 57000
# retrieving 2024-11-04
# 271.2 percent is done
# 57300
# retrieving 2024-11-05
# 272.2 percent is done
# 57600
# retrieving 2024-11-06
# 273.2 percent is done
# 57900
# retrieving 2024-11-07
# 274.2 percent is done
# 58200
# retrieving 2024-11-08
# 275.2 percent is done
# 58500
# retrieving 2024-11-09
# 276.2 percent is done
# 58500
# retrieving 2024-11-10
# 277.2 percent is done
# 58500
# retrieving 2024-11-11
# 278.2 percent is done
# 58800
# retrieving 2024-11-12
# 279.2 percent is done
# 59100
# retrieving 2024-11-13
# 280.2 percent is done
# 59400
# retrieving 2024-11-14
# 281.2 percent is done
# 59700
# retrieving 2024-11-15
# 282.2 percent is done
# 60000
# retrieving 2024-11-16
# 283.2 percent is done
# 60000
# retrieving 2024-11-17
# 284.2 percent is done
# 60000
# retrieving 2024-11-18
# 285.2 percent is done
# 60300
# retrieving 2024-11-19
# 286.2 percent is done
# 60600
# retrieving 2024-11-20
# 287.2 percent is done
# 60900
# retrieving 2024-11-21
# 288.2 percent is done
# 61200
# retrieving 2024-11-22
# 289.2 percent is done
# 61500
# retrieving 2024-11-23
# 290.2 percent is done
# 61500
# retrieving 2024-11-24
# 291.2 percent is done
# 61500
# retrieving 2024-11-25
# 292.2 percent is done
# 61800
# retrieving 2024-11-26
# 293.2 percent is done
# 62100
# retrieving 2024-11-27
# 294.2 percent is done
# 62400
# retrieving 2024-11-30
# 295.2 percent is done
# 62400
# retrieving 2024-12-01
# 296.2 percent is done
# 62400
# retrieving 2024-12-02
# 297.2 percent is done
# 62700
# retrieving 2024-12-03
# 298.2 percent is done
# 63000
# retrieving 2024-12-04
# 299.2 percent is done
# 63300
# retrieving 2024-12-05
# 300.2 percent is done
# 63600
# retrieving 2024-12-06
# 301.2 percent is done
# 63900
# retrieving 2024-12-07
# 302.2 percent is done
# 63900
# retrieving 2024-12-08
# 303.2 percent is done
# 63900
# retrieving 2024-12-09
# 304.2 percent is done
# 64200
# retrieving 2024-12-10
# 305.2 percent is done
# 64500
# retrieving 2024-12-11
# 306.2 percent is done
# 64800
# retrieving 2024-12-12
# 307.2 percent is done
# 65100
# retrieving 2024-12-13
# 308.2 percent is done
# 65400
# retrieving 2024-12-14
# 309.2 percent is done
# 65400
# retrieving 2024-12-15
# 310.2 percent is done
# 65400
# retrieving 2024-12-16
# 311.2 percent is done
# 65700
# retrieving 2024-12-17
# 312.2 percent is done
# 66000
# retrieving 2024-12-18
# 313.2 percent is done
# 66300
# retrieving 2024-12-19
# 314.2 percent is done
# 66600
# retrieving 2024-12-20
# 315.2 percent is done
# 66900
# retrieving 2024-12-21
# 316.2 percent is done
# 66900
# retrieving 2024-12-22
# 317.2 percent is done
# 66900
# retrieving 2024-12-23
# 318.2 percent is done
# 67200
# retrieving 2024-12-24
# 319.2 percent is done
# 67200
# retrieving 2024-12-26
# 320.2 percent is done
# 67500
# retrieving 2024-12-27
# 321.2 percent is done
# 67800
# retrieving 2024-12-28
# 322.2 percent is done
# 67800
# retrieving 2024-12-29
# 323.2 percent is done
# 67800
# retrieving 2024-12-30
# 324.2 percent is done
# 68100
# retrieving 2024-12-31
# 325.2 percent is done
# 68400
# retrieving 2025-01-02
# 326.2 percent is done
# 68700
# retrieving 2025-01-03
# 327.2 percent is done
# 69000
# retrieving 2025-01-04
# 328.2 percent is done
# 69000
# retrieving 2025-01-05
# 329.2 percent is done
# 69000
# retrieving 2025-01-06
# 330.2 percent is done
# 69300
# retrieving 2025-01-07
# 331.2 percent is done
# 69600
# retrieving 2025-01-08
# 332.2 percent is done
# 69600
# retrieving 2025-01-09
# 333.2 percent is done
# 69600
# retrieving 2025-01-10
# 334.2 percent is done
# 69900
# retrieving 2025-01-11
# 335.2 percent is done
# 69900
# retrieving 2025-01-12
# 336.2 percent is done
# 69900
# retrieving 2025-01-13
# 337.2 percent is done
# 70200
# retrieving 2025-01-14
# 338.2 percent is done
# 70500
# retrieving 2025-01-15
# 339.2 percent is done
# 70800
# retrieving 2025-01-16
# 340.2 percent is done
# 71100
# retrieving 2025-01-17
# 341.2 percent is done
# 71400
# retrieving 2025-01-18
# 342.2 percent is done
# 71400
# retrieving 2025-01-19
# 343.2 percent is done
# 71400
# retrieving 2025-01-21
# 344.2 percent is done
# 71700
# retrieving 2025-01-22
# 345.2 percent is done
# 72000
# retrieving 2025-01-23
# 346.2 percent is done
# 72300
# retrieving 2025-01-24
# 347.2 percent is done
# 72600
# retrieving 2025-01-25
# 348.2 percent is done
# 72600
# retrieving 2025-01-26
# 349.2 percent is done
# 72600
# retrieving 2025-01-27
# 350.2 percent is done
# 72900
# retrieving 2025-01-28
# 351.2 percent is done
# 73200
# retrieving 2025-01-29
# 352.2 percent is done
# 73500
# retrieving 2025-01-30
# 353.2 percent is done
# 73800
# retrieving 2025-01-31
# 354.2 percent is done
# 74100
# retrieving 2025-02-01
# 355.2 percent is done
# 74100
# retrieving 2025-02-02
# 356.2 percent is done
# 74100
# retrieving 2025-02-03
# 357.2 percent is done
# 74400
# retrieving 2025-02-04
# 358.2 percent is done
# 74700
# retrieving 2025-02-05
# 359.2 percent is done
# 75000
# retrieving 2025-02-06
# 360.2 percent is done
# 75300
# retrieving 2025-02-07
# 361.2 percent is done
# 75600
# retrieving 2025-02-08
# 362.2 percent is done
# 75600
# retrieving 2025-02-09
# 363.2 percent is done
# 75600
# retrieving 2025-02-10
# 364.2 percent is done
# 75900
# retrieving 2025-02-11
# 365.2 percent is done
# 76200
# retrieving 2025-02-12
# 366.2 percent is done
# 76500
# retrieving 2025-02-13
# 367.2 percent is done
# 76800
# retrieving 2025-02-14
# 368.2 percent is done
# 77100
# retrieving 2025-02-15
# 369.2 percent is done
# 77100
# retrieving 2025-02-16
# 370.2 percent is done
# 77100
# retrieving 2025-02-18
# 371.2 percent is done
# 77400
# retrieving 2025-02-19
# 372.2 percent is done
# 77700
# retrieving 2025-02-20
# 373.2 percent is done
# 78000
# retrieving 2025-02-21
# 374.2 percent is done
# 78300
# retrieving 2025-02-22
# 375.2 percent is done
# 78300
# retrieving 2025-02-23
# 376.2 percent is done
# 78300
# retrieving 2025-02-24
# 377.2 percent is done
# 78600
# retrieving 2025-02-25
# 378.2 percent is done
# 78900
# retrieving 2025-02-26
# 379.2 percent is done
# 79200
# retrieving 2025-02-27
# 380.2 percent is done
# 79500
# retrieving 2025-02-28
# 381.2 percent is done
# 79800
# retrieving 2025-03-01
# 382.2 percent is done
# 79800
# retrieving 2025-03-02
# 383.2 percent is done
# 79800
# retrieving 2025-03-03
# 384.2 percent is done
# 80100
# retrieving 2025-03-04
# 385.2 percent is done
# 80400
# retrieving 2025-03-05
# 386.2 percent is done
# 80700
# retrieving 2025-03-06
# 387.2 percent is done
# 81000
# retrieving 2025-03-07
# 388.2 percent is done
# 81300
# retrieving 2025-03-08
# 389.2 percent is done
# 81300
# retrieving 2025-03-09
# 390.2 percent is done
# 81300
# retrieving 2025-03-10
# 391.2 percent is done
# 81600
# retrieving 2025-03-11
# 392.2 percent is done
# 81900
# retrieving 2025-03-12
# 393.2 percent is done
# 82200
# retrieving 2025-03-13
# 394.2 percent is done
# 82500
# retrieving 2025-03-14
# 395.2 percent is done
# 82800
# retrieving 2025-03-15
# 396.2 percent is done
# 82800
# retrieving 2025-03-16
# 397.2 percent is done
# 82800
# retrieving 2025-03-17
# 398.2 percent is done
# 83100
# retrieving 2025-03-18
# 399.2 percent is done
# 83400
# retrieving 2025-03-19
# 400.2 percent is done
# 83700
# retrieving 2025-03-20
# 401.2 percent is done
# 84000
# retrieving 2025-03-21
# 402.2 percent is done
# 84300
# retrieving 2025-03-22
# 403.2 percent is done
# 84300
# retrieving 2025-03-23
# 404.2 percent is done
# 84300
# retrieving 2025-03-24
# 405.2 percent is done
# 84600
# retrieving 2025-03-25
# 406.2 percent is done
# 84900
# retrieving 2025-03-26
# 407.2 percent is done
# 85200
# retrieving 2025-03-27
# 408.2 percent is done
# 85500
# retrieving 2025-03-28
# 409.2 percent is done
# 85800
# retrieving 2025-03-29
# 410.2 percent is done
# 85800
# retrieving 2025-03-30
# 411.2 percent is done
# 85800
# retrieving 2025-03-31
# 412.2 percent is done
# 86100
# retrieving 2025-04-01
# 413.2 percent is done
# 0
# retrieving 2024-02-01
# 0.2 percent is done
# 90
# retrieving 2024-02-02
# 1.2 percent is done
# 180
# retrieving 2024-02-03
# 2.2 percent is done
# 180
# retrieving 2024-02-04
# 3.2 percent is done
# 180
# retrieving 2024-02-05
# 4.2 percent is done
# 270
# retrieving 2024-02-06
# 5.2 percent is done
# 360
# retrieving 2024-02-07
# 6.2 percent is done
# 450
# retrieving 2024-02-08
# 7.2 percent is done
# 540
# retrieving 2024-02-09
# 8.2 percent is done
# 630
# retrieving 2024-02-10
# 9.2 percent is done
# 630
# retrieving 2024-02-11
# 10.2 percent is done
# 630
# retrieving 2024-02-12
# 11.2 percent is done
# 720
# retrieving 2024-02-13
# 12.2 percent is done
# 810
# retrieving 2024-02-14
# 13.2 percent is done
# 900
# retrieving 2024-02-15
# 14.2 percent is done
# 990
# retrieving 2024-02-16
# 15.2 percent is done
# 1080
# retrieving 2024-02-17
# 16.2 percent is done
# 1080
# retrieving 2024-02-18
# 17.2 percent is done
# 1080
# retrieving 2024-02-20
# 18.2 percent is done
# 1170
# retrieving 2024-02-21
# 19.2 percent is done
# 1260
# retrieving 2024-02-22
# 20.2 percent is done
# 1350
# retrieving 2024-02-23
# 21.2 percent is done
# 1440
# retrieving 2024-02-24
# 22.2 percent is done
# 1440
# retrieving 2024-02-25
# 23.2 percent is done
# 1440
# retrieving 2024-02-26
# 24.2 percent is done
# 1530
# retrieving 2024-02-27
# 25.2 percent is done
# 1620
# retrieving 2024-02-28
# 26.2 percent is done
# 1710
# retrieving 2024-02-29
# 27.2 percent is done
# 1800
# retrieving 2024-03-01
# 28.2 percent is done
# 1890
# retrieving 2024-03-02
# 29.2 percent is done
# 1890
# retrieving 2024-03-03
# 30.2 percent is done
# 1890
# retrieving 2024-03-04
# 31.2 percent is done
# 1980
# retrieving 2024-03-05
# 32.2 percent is done
# 2070
# retrieving 2024-03-06
# 33.2 percent is done
# 2160
# retrieving 2024-03-07
# 34.2 percent is done
# 2250
# retrieving 2024-03-08
# 35.2 percent is done
# 2340
# retrieving 2024-03-09
# 36.2 percent is done
# 2340
# retrieving 2024-03-10
# 37.2 percent is done
# 2340
# retrieving 2024-03-11
# 38.2 percent is done
# 2430
# retrieving 2024-03-12
# 39.2 percent is done
# 2520
# retrieving 2024-03-13
# 40.2 percent is done
# 2610
# retrieving 2024-03-14
# 41.2 percent is done
# 2700
# retrieving 2024-03-15
# 42.2 percent is done
# 2790
# retrieving 2024-03-16
# 43.2 percent is done
# 2790
# retrieving 2024-03-17
# 44.2 percent is done
# 2790
# retrieving 2024-03-18
# 45.2 percent is done
# 2880
# retrieving 2024-03-19
# 46.2 percent is done
# 2970
# retrieving 2024-03-20
# 47.2 percent is done
# 3060
# retrieving 2024-03-21
# 48.2 percent is done
# 3150
# retrieving 2024-03-22
# 49.2 percent is done
# 3240
# retrieving 2024-03-23
# 50.2 percent is done
# 3240
# retrieving 2024-03-24
# 51.2 percent is done
# 3240
# retrieving 2024-03-25
# 52.2 percent is done
# 3330
# retrieving 2024-03-26
# 53.2 percent is done
# 3420
# retrieving 2024-03-27
# 54.2 percent is done
# 3510
# retrieving 2024-03-28
# 55.2 percent is done
# 3600
# retrieving 2024-03-30
# 56.2 percent is done
# 3600
# retrieving 2024-03-31
# 57.2 percent is done
# 3600
# retrieving 2024-04-01
# 58.2 percent is done
# 3690
# retrieving 2024-04-02
# 59.2 percent is done
# 3780
# retrieving 2024-04-03
# 60.2 percent is done
# 3870
# retrieving 2024-04-04
# 61.2 percent is done
# 3960
# retrieving 2024-04-05
# 62.2 percent is done
# 4050
# retrieving 2024-04-06
# 63.2 percent is done
# 4050
# retrieving 2024-04-07
# 64.2 percent is done
# 4050
# retrieving 2024-04-08
# 65.2 percent is done
# 4140
# retrieving 2024-04-09
# 66.2 percent is done
# 4230
# retrieving 2024-04-10
# 67.2 percent is done
# 4320
# retrieving 2024-04-11
# 68.2 percent is done
# 4410
# retrieving 2024-04-12
# 69.2 percent is done
# 4500
# retrieving 2024-04-13
# 70.2 percent is done
# 4500
# retrieving 2024-04-14
# 71.2 percent is done
# 4500
# retrieving 2024-04-15
# 72.2 percent is done
# 4590
# retrieving 2024-04-16
# 73.2 percent is done
# 4680
# retrieving 2024-04-17
# 74.2 percent is done
# 4770
# retrieving 2024-04-18
# 75.2 percent is done
# 4860
# retrieving 2024-04-19
# 76.2 percent is done
# 4950
# retrieving 2024-04-20
# 77.2 percent is done
# 4950
# retrieving 2024-04-21
# 78.2 percent is done
# 4950
# retrieving 2024-04-22
# 79.2 percent is done
# 5040
# retrieving 2024-04-23
# 80.2 percent is done
# 5130
# retrieving 2024-04-24
# 81.2 percent is done
# 5220
# retrieving 2024-04-25
# 82.2 percent is done
# 5310
# retrieving 2024-04-26
# 83.2 percent is done
# 5400
# retrieving 2024-04-27
# 84.2 percent is done
# 5400
# retrieving 2024-04-28
# 85.2 percent is done
# 5400
# retrieving 2024-04-29
# 86.2 percent is done
# 5490
# retrieving 2024-04-30
# 87.2 percent is done
# 5580
# retrieving 2024-05-01
# 88.2 percent is done
# 5670
# retrieving 2024-05-02
# 89.2 percent is done
# 5760
# retrieving 2024-05-03
# 90.2 percent is done
# 5850
# retrieving 2024-05-04
# 91.2 percent is done
# 5850
# retrieving 2024-05-05
# 92.2 percent is done
# 5850
# retrieving 2024-05-06
# 93.2 percent is done
# 5940
# retrieving 2024-05-07
# 94.2 percent is done
# 6030
# retrieving 2024-05-08
# 95.2 percent is done
# 6120
# retrieving 2024-05-09
# 96.2 percent is done
# 6210
# retrieving 2024-05-10
# 97.2 percent is done
# 6300
# retrieving 2024-05-11
# 98.2 percent is done
# 6300
# retrieving 2024-05-12
# 99.2 percent is done
# 6300
# retrieving 2024-05-13
# 100.2 percent is done
# 6390
# retrieving 2024-05-14
# 101.2 percent is done
# 6480
# retrieving 2024-05-15
# 102.2 percent is done
# 6570
# retrieving 2024-05-16
# 103.2 percent is done
# 6660
# retrieving 2024-05-17
# 104.2 percent is done
# 6750
# retrieving 2024-05-18
# 105.2 percent is done
# 6750
# retrieving 2024-05-19
# 106.2 percent is done
# 6750
# retrieving 2024-05-20
# 107.2 percent is done
# 6840
# retrieving 2024-05-21
# 108.2 percent is done
# 6930
# retrieving 2024-05-22
# 109.2 percent is done
# 7020
# retrieving 2024-05-23
# 110.2 percent is done
# 7110
# retrieving 2024-05-24
# 111.2 percent is done
# 7200
# retrieving 2024-05-25
# 112.2 percent is done
# 7200
# retrieving 2024-05-26
# 113.2 percent is done
# 7200
# retrieving 2024-05-28
# 114.2 percent is done
# 7290
# retrieving 2024-05-29
# 115.2 percent is done
# 7380
# retrieving 2024-05-30
# 116.2 percent is done
# 7470
# retrieving 2024-05-31
# 117.2 percent is done
# 7560
# retrieving 2024-06-01
# 118.2 percent is done
# 7560
# retrieving 2024-06-02
# 119.2 percent is done
# 7560
# retrieving 2024-06-03
# 120.2 percent is done
# 7650
# retrieving 2024-06-04
# 121.2 percent is done
# 7740
# retrieving 2024-06-05
# 122.2 percent is done
# 7830
# retrieving 2024-06-06
# 123.2 percent is done
# 7920
# retrieving 2024-06-07
# 124.2 percent is done
# 8010
# retrieving 2024-06-08
# 125.2 percent is done
# 8010
# retrieving 2024-06-09
# 126.2 percent is done
# 8010
# retrieving 2024-06-10
# 127.2 percent is done
# 8100
# retrieving 2024-06-11
# 128.2 percent is done
# 8190
# retrieving 2024-06-12
# 129.2 percent is done
# 8280
# retrieving 2024-06-13
# 130.2 percent is done
# 8370
# retrieving 2024-06-14
# 131.2 percent is done
# 8460
# retrieving 2024-06-15
# 132.2 percent is done
# 8460
# retrieving 2024-06-16
# 133.2 percent is done
# 8460
# retrieving 2024-06-17
# 134.2 percent is done
# 8550
# retrieving 2024-06-18
# 135.2 percent is done
# 8640
# retrieving 2024-06-20
# 136.2 percent is done
# 8730
# retrieving 2024-06-21
# 137.2 percent is done
# 8820
# retrieving 2024-06-22
# 138.2 percent is done
# 8820
# retrieving 2024-06-23
# 139.2 percent is done
# 8820
# retrieving 2024-06-24
# 140.2 percent is done
# 8910
# retrieving 2024-06-25
# 141.2 percent is done
# 9000
# retrieving 2024-06-26
# 142.2 percent is done
# 9090
# retrieving 2024-06-27
# 143.2 percent is done
# 9180
# retrieving 2024-06-28
# 144.2 percent is done
# 9270
# retrieving 2024-06-29
# 145.2 percent is done
# 9270
# retrieving 2024-06-30
# 146.2 percent is done
# 9270
# retrieving 2024-07-01
# 147.2 percent is done
# 9360
# retrieving 2024-07-02
# 148.2 percent is done
# 9450
# retrieving 2024-07-03
# 149.2 percent is done
# 9450
# retrieving 2024-07-05
# 150.2 percent is done
# 9540
# retrieving 2024-07-06
# 151.2 percent is done
# 9540
# retrieving 2024-07-07
# 152.2 percent is done
# 9540
# retrieving 2024-07-08
# 153.2 percent is done
# 9630
# retrieving 2024-07-09
# 154.2 percent is done
# 9720
# retrieving 2024-07-10
# 155.2 percent is done
# 9810
# retrieving 2024-07-11
# 156.2 percent is done
# 9900
# retrieving 2024-07-12
# 157.2 percent is done
# 9990
# retrieving 2024-07-13
# 158.2 percent is done
# 9990
# retrieving 2024-07-14
# 159.2 percent is done
# 9990
# retrieving 2024-07-15
# 160.2 percent is done
# 10080
# retrieving 2024-07-16
# 161.2 percent is done
# 10170
# retrieving 2024-07-17
# 162.2 percent is done
# 10260
# retrieving 2024-07-18
# 163.2 percent is done
# 10350
# retrieving 2024-07-19
# 164.2 percent is done
# 10440
# retrieving 2024-07-20
# 165.2 percent is done
# 10440
# retrieving 2024-07-21
# 166.2 percent is done
# 10440
# retrieving 2024-07-22
# 167.2 percent is done
# 10530
# retrieving 2024-07-23
# 168.2 percent is done
# 10620
# retrieving 2024-07-24
# 169.2 percent is done
# 10710
# retrieving 2024-07-25
# 170.2 percent is done
# 10800
# retrieving 2024-07-26
# 171.2 percent is done
# 10890
# retrieving 2024-07-27
# 172.2 percent is done
# 10890
# retrieving 2024-07-28
# 173.2 percent is done
# 10890
# retrieving 2024-07-29
# 174.2 percent is done
# 10980
# retrieving 2024-07-30
# 175.2 percent is done
# 11070
# retrieving 2024-07-31
# 176.2 percent is done
# 11160
# retrieving 2024-08-01
# 177.2 percent is done
# 11250
# retrieving 2024-08-02
# 178.2 percent is done
# 11340
# retrieving 2024-08-03
# 179.2 percent is done
# 11340
# retrieving 2024-08-04
# 180.2 percent is done
# 11340
# retrieving 2024-08-05
# 181.2 percent is done
# 11430
# retrieving 2024-08-06
# 182.2 percent is done
# 11520
# retrieving 2024-08-07
# 183.2 percent is done
# 11610
# retrieving 2024-08-08
# 184.2 percent is done
# 11700
# retrieving 2024-08-09
# 185.2 percent is done
# 11790
# retrieving 2024-08-10
# 186.2 percent is done
# 11790
# retrieving 2024-08-11
# 187.2 percent is done
# 11790
# retrieving 2024-08-12
# 188.2 percent is done
# 11880
# retrieving 2024-08-13
# 189.2 percent is done
# 11970
# retrieving 2024-08-14
# 190.2 percent is done
# 12060
# retrieving 2024-08-15
# 191.2 percent is done
# 12150
# retrieving 2024-08-16
# 192.2 percent is done
# 12240
# retrieving 2024-08-17
# 193.2 percent is done
# 12240
# retrieving 2024-08-18
# 194.2 percent is done
# 12240
# retrieving 2024-08-19
# 195.2 percent is done
# 12330
# retrieving 2024-08-20
# 196.2 percent is done
# 12420
# retrieving 2024-08-21
# 197.2 percent is done
# 12510
# retrieving 2024-08-22
# 198.2 percent is done
# 12600
# retrieving 2024-08-23
# 199.2 percent is done
# 12690
# retrieving 2024-08-24
# 200.2 percent is done
# 12690
# retrieving 2024-08-25
# 201.2 percent is done
# 12690
# retrieving 2024-08-26
# 202.2 percent is done
# 12780
# retrieving 2024-08-27
# 203.2 percent is done
# 12870
# retrieving 2024-08-28
# 204.2 percent is done
# 12960
# retrieving 2024-08-29
# 205.2 percent is done
# 13050
# retrieving 2024-08-30
# 206.2 percent is done
# 13140
# retrieving 2024-08-31
# 207.2 percent is done
# 13140
# retrieving 2024-09-01
# 208.2 percent is done
# 13140
# retrieving 2024-09-03
# 209.2 percent is done
# 13230
# retrieving 2024-09-04
# 210.2 percent is done
# 13320
# retrieving 2024-09-05
# 211.2 percent is done
# 13410
# retrieving 2024-09-06
# 212.2 percent is done
# 13500
# retrieving 2024-09-07
# 213.2 percent is done
# 13500
# retrieving 2024-09-08
# 214.2 percent is done
# 13500
# retrieving 2024-09-09
# 215.2 percent is done
# 13590
# retrieving 2024-09-10
# 216.2 percent is done
# 13680
# retrieving 2024-09-11
# 217.2 percent is done
# 13770
# retrieving 2024-09-12
# 218.2 percent is done
# 13860
# retrieving 2024-09-13
# 219.2 percent is done
# 13950
# retrieving 2024-09-14
# 220.2 percent is done
# 13950
# retrieving 2024-09-15
# 221.2 percent is done
# 13950
# retrieving 2024-09-16
# 222.2 percent is done
# 14040
# retrieving 2024-09-17
# 223.2 percent is done
# 14130
# retrieving 2024-09-18
# 224.2 percent is done
# 14220
# retrieving 2024-09-19
# 225.2 percent is done
# 14310
# retrieving 2024-09-20
# 226.2 percent is done
# 14400
# retrieving 2024-09-21
# 227.2 percent is done
# 14400
# retrieving 2024-09-22
# 228.2 percent is done
# 14400
# retrieving 2024-09-23
# 229.2 percent is done
# 14490
# retrieving 2024-09-24
# 230.2 percent is done
# 14580
# retrieving 2024-09-25
# 231.2 percent is done
# 14670
# retrieving 2024-09-26
# 232.2 percent is done
# 14760
# retrieving 2024-09-27
# 233.2 percent is done
# 14850
# retrieving 2024-09-28
# 234.2 percent is done
# 14850
# retrieving 2024-09-29
# 235.2 percent is done
# 14850
# retrieving 2024-09-30
# 236.2 percent is done
# 14940
# retrieving 2024-10-01
# 237.2 percent is done
# 15030
# retrieving 2024-10-02
# 238.2 percent is done
# 15120
# retrieving 2024-10-03
# 239.2 percent is done
# 15210
# retrieving 2024-10-04
# 240.2 percent is done
# 15300
# retrieving 2024-10-05
# 241.2 percent is done
# 15300
# retrieving 2024-10-06
# 242.2 percent is done
# 15300
# retrieving 2024-10-07
# 243.2 percent is done
# 15390
# retrieving 2024-10-08
# 244.2 percent is done
# 15480
# retrieving 2024-10-09
# 245.2 percent is done
# 15570
# retrieving 2024-10-10
# 246.2 percent is done
# 15660
# retrieving 2024-10-11
# 247.2 percent is done
# 15750
# retrieving 2024-10-12
# 248.2 percent is done
# 15750
# retrieving 2024-10-13
# 249.2 percent is done
# 15750
# retrieving 2024-10-14
# 250.2 percent is done
# 15840
# retrieving 2024-10-15
# 251.2 percent is done
# 15930
# retrieving 2024-10-16
# 252.2 percent is done
# 16020
# retrieving 2024-10-17
# 253.2 percent is done
# 16110
# retrieving 2024-10-18
# 254.2 percent is done
# 16200
# retrieving 2024-10-19
# 255.2 percent is done
# 16200
# retrieving 2024-10-20
# 256.2 percent is done
# 16200
# retrieving 2024-10-21
# 257.2 percent is done
# 16290
# retrieving 2024-10-22
# 258.2 percent is done
# 16380
# retrieving 2024-10-23
# 259.2 percent is done
# 16470
# retrieving 2024-10-24
# 260.2 percent is done
# 16560
# retrieving 2024-10-25
# 261.2 percent is done
# 16650
# retrieving 2024-10-26
# 262.2 percent is done
# 16650
# retrieving 2024-10-27
# 263.2 percent is done
# 16650
# retrieving 2024-10-28
# 264.2 percent is done
# 16740
# retrieving 2024-10-29
# 265.2 percent is done
# 16830
# retrieving 2024-10-30
# 266.2 percent is done
# 16920
# retrieving 2024-10-31
# 267.2 percent is done
# 17010
# retrieving 2024-11-01
# 268.2 percent is done
# 17100
# retrieving 2024-11-02
# 269.2 percent is done
# 17100
# retrieving 2024-11-03
# 270.2 percent is done
# 17100
# retrieving 2024-11-04
# 271.2 percent is done
# 17190
# retrieving 2024-11-05
# 272.2 percent is done
# 17280
# retrieving 2024-11-06
# 273.2 percent is done
# 17370
# retrieving 2024-11-07
# 274.2 percent is done
# 17460
# retrieving 2024-11-08
# 275.2 percent is done
# 17550
# retrieving 2024-11-09
# 276.2 percent is done
# 17550
# retrieving 2024-11-10
# 277.2 percent is done
# 17550
# retrieving 2024-11-11
# 278.2 percent is done
# 17640
# retrieving 2024-11-12
# 279.2 percent is done
# 17730
# retrieving 2024-11-13
# 280.2 percent is done
# 17820
# retrieving 2024-11-14
# 281.2 percent is done
# 17910
# retrieving 2024-11-15
# 282.2 percent is done
# 18000
# retrieving 2024-11-16
# 283.2 percent is done
# 18000
# retrieving 2024-11-17
# 284.2 percent is done
# 18000
# retrieving 2024-11-18
# 285.2 percent is done
# 18090
# retrieving 2024-11-19
# 286.2 percent is done
# 18180
# retrieving 2024-11-20
# 287.2 percent is done
# 18270
# retrieving 2024-11-21
# 288.2 percent is done
# 18360
# retrieving 2024-11-22
# 289.2 percent is done
# 18450
# retrieving 2024-11-23
# 290.2 percent is done
# 18450
# retrieving 2024-11-24
# 291.2 percent is done
# 18450
# retrieving 2024-11-25
# 292.2 percent is done
# 18540
# retrieving 2024-11-26
# 293.2 percent is done
# 18630
# retrieving 2024-11-27
# 294.2 percent is done
# 18720
# retrieving 2024-11-30
# 295.2 percent is done
# 18720
# retrieving 2024-12-01
# 296.2 percent is done
# 18720
# retrieving 2024-12-02
# 297.2 percent is done
# 18810
# retrieving 2024-12-03
# 298.2 percent is done
# 18900
# retrieving 2024-12-04
# 299.2 percent is done
# 18990
# retrieving 2024-12-05
# 300.2 percent is done
# 19080
# retrieving 2024-12-06
# 301.2 percent is done
# 19170
# retrieving 2024-12-07
# 302.2 percent is done
# 19170
# retrieving 2024-12-08
# 303.2 percent is done
# 19170
# retrieving 2024-12-09
# 304.2 percent is done
# 19260
# retrieving 2024-12-10
# 305.2 percent is done
# 19350
# retrieving 2024-12-11
# 306.2 percent is done
# 19440
# retrieving 2024-12-12
# 307.2 percent is done
# 19530
# retrieving 2024-12-13
# 308.2 percent is done
# 19620
# retrieving 2024-12-14
# 309.2 percent is done
# 19620
# retrieving 2024-12-15
# 310.2 percent is done
# 19620
# retrieving 2024-12-16
# 311.2 percent is done
# 19710
# retrieving 2024-12-17
# 312.2 percent is done
# 19800
# retrieving 2024-12-18
# 313.2 percent is done
# 19890
# retrieving 2024-12-19
# 314.2 percent is done
# 19980
# retrieving 2024-12-20
# 315.2 percent is done
# 20070
# retrieving 2024-12-21
# 316.2 percent is done
# 20070
# retrieving 2024-12-22
# 317.2 percent is done
# 20070
# retrieving 2024-12-23
# 318.2 percent is done
# 20160
# retrieving 2024-12-24
# 319.2 percent is done
# 20160
# retrieving 2024-12-26
# 320.2 percent is done
# 20250
# retrieving 2024-12-27
# 321.2 percent is done
# 20340
# retrieving 2024-12-28
# 322.2 percent is done
# 20340
# retrieving 2024-12-29
# 323.2 percent is done
# 20340
# retrieving 2024-12-30
# 324.2 percent is done
# 20430
# retrieving 2024-12-31
# 325.2 percent is done
# 20520
# retrieving 2025-01-02
# 326.2 percent is done
# 20610
# retrieving 2025-01-03
# 327.2 percent is done
# 20700
# retrieving 2025-01-04
# 328.2 percent is done
# 20700
# retrieving 2025-01-05
# 329.2 percent is done
# 20700
# retrieving 2025-01-06
# 330.2 percent is done
# 20790
# retrieving 2025-01-07
# 331.2 percent is done
# 20880
# retrieving 2025-01-08
# 332.2 percent is done
# 20880
# retrieving 2025-01-09
# 333.2 percent is done
# 20880
# retrieving 2025-01-10
# 334.2 percent is done
# 20970
# retrieving 2025-01-11
# 335.2 percent is done
# 20970
# retrieving 2025-01-12
# 336.2 percent is done
# 20970
# retrieving 2025-01-13
# 337.2 percent is done
# 21060
# retrieving 2025-01-14
# 338.2 percent is done
# 21150
# retrieving 2025-01-15
# 339.2 percent is done
# 21240
# retrieving 2025-01-16
# 340.2 percent is done
# 21330
# retrieving 2025-01-17
# 341.2 percent is done
# 21420
# retrieving 2025-01-18
# 342.2 percent is done
# 21420
# retrieving 2025-01-19
# 343.2 percent is done
# 21420
# retrieving 2025-01-21
# 344.2 percent is done
# 21510
# retrieving 2025-01-22
# 345.2 percent is done
# 21600
# retrieving 2025-01-23
# 346.2 percent is done
# 21690
# retrieving 2025-01-24
# 347.2 percent is done
# 21780
# retrieving 2025-01-25
# 348.2 percent is done
# 21780
# retrieving 2025-01-26
# 349.2 percent is done
# 21780
# retrieving 2025-01-27
# 350.2 percent is done
# 21870
# retrieving 2025-01-28
# 351.2 percent is done
# 21960
# retrieving 2025-01-29
# 352.2 percent is done
# 22050
# retrieving 2025-01-30
# 353.2 percent is done
# 22140
# retrieving 2025-01-31
# 354.2 percent is done
# 22230
# retrieving 2025-02-01
# 355.2 percent is done
# 22230
# retrieving 2025-02-02
# 356.2 percent is done
# 22230
# retrieving 2025-02-03
# 357.2 percent is done
# 22320
# retrieving 2025-02-04
# 358.2 percent is done
# 22410
# retrieving 2025-02-05
# 359.2 percent is done
# 22500
# retrieving 2025-02-06
# 360.2 percent is done
# 22590
# retrieving 2025-02-07
# 361.2 percent is done
# 22680
# retrieving 2025-02-08
# 362.2 percent is done
# 22680
# retrieving 2025-02-09
# 363.2 percent is done
# 22680
# retrieving 2025-02-10
# 364.2 percent is done
# 22770
# retrieving 2025-02-11
# 365.2 percent is done
# 22860
# retrieving 2025-02-12
# 366.2 percent is done
# 22950
# retrieving 2025-02-13
# 367.2 percent is done
# 23040
# retrieving 2025-02-14
# 368.2 percent is done
# 23130
# retrieving 2025-02-15
# 369.2 percent is done
# 23130
# retrieving 2025-02-16
# 370.2 percent is done
# 23130
# retrieving 2025-02-18
# 371.2 percent is done
# 23220
# retrieving 2025-02-19
# 372.2 percent is done
# 23310
# retrieving 2025-02-20
# 373.2 percent is done
# 23400
# retrieving 2025-02-21
# 374.2 percent is done
# 23490
# retrieving 2025-02-22
# 375.2 percent is done
# 23490
# retrieving 2025-02-23
# 376.2 percent is done
# 23490
# retrieving 2025-02-24
# 377.2 percent is done
# 23580
# retrieving 2025-02-25
# 378.2 percent is done
# 23670
# retrieving 2025-02-26
# 379.2 percent is done
# 23760
# retrieving 2025-02-27
# 380.2 percent is done
# 23850
# retrieving 2025-02-28
# 381.2 percent is done
# 23940
# retrieving 2025-03-01
# 382.2 percent is done
# 23940
# retrieving 2025-03-02
# 383.2 percent is done
# 23940
# retrieving 2025-03-03
# 384.2 percent is done
# 24030
# retrieving 2025-03-04
# 385.2 percent is done
# 24120
# retrieving 2025-03-05
# 386.2 percent is done
# 24210
# retrieving 2025-03-06
# 387.2 percent is done
# 24300
# retrieving 2025-03-07
# 388.2 percent is done
# 24390
# retrieving 2025-03-08
# 389.2 percent is done
# 24390
# retrieving 2025-03-09
# 390.2 percent is done
# 24390
# retrieving 2025-03-10
# 391.2 percent is done
# 24480
# retrieving 2025-03-11
# 392.2 percent is done
# 24570
# retrieving 2025-03-12
# 393.2 percent is done
# 24660
# retrieving 2025-03-13
# 394.2 percent is done
# 24750
# retrieving 2025-03-14
# 395.2 percent is done
# 24840
# retrieving 2025-03-15
# 396.2 percent is done
# 24840
# retrieving 2025-03-16
# 397.2 percent is done
# 24840
# retrieving 2025-03-17
# 398.2 percent is done
# 24930
# retrieving 2025-03-18
# 399.2 percent is done
# 25020
# retrieving 2025-03-19
# 400.2 percent is done
# 25110
# retrieving 2025-03-20
# 401.2 percent is done
# 25200
# retrieving 2025-03-21
# 402.2 percent is done
# 25290
# retrieving 2025-03-22
# 403.2 percent is done
# 25290
# retrieving 2025-03-23
# 404.2 percent is done
# 25290
# retrieving 2025-03-24
# 405.2 percent is done
# 25380
# retrieving 2025-03-25
# 406.2 percent is done
# 25470
# retrieving 2025-03-26
# 407.2 percent is done
# 25560
# retrieving 2025-03-27
# 408.2 percent is done
# 25650
# retrieving 2025-03-28
# 409.2 percent is done
# 25740
# retrieving 2025-03-29
# 410.2 percent is done
# 25740
# retrieving 2025-03-30
# 411.2 percent is done
# 25740
# retrieving 2025-03-31
# 412.2 percent is done
# 25830
# retrieving 2025-04-01
# 413.2 percent is done
# 0
# 1
# 2
# 0
# retrieving 2024-02-01
# 0.2 percent is done
# 300
# retrieving 2024-02-02
# 1.2 percent is done
# 600
# retrieving 2024-02-03
# 2.2 percent is done
# 600
# retrieving 2024-02-04
# 3.2 percent is done
# 600
# retrieving 2024-02-05
# 4.2 percent is done
# 900
# retrieving 2024-02-06
# 5.2 percent is done
# 1200
# retrieving 2024-02-07
# 6.2 percent is done
# 1500
# retrieving 2024-02-08
# 7.2 percent is done
# 1800
# retrieving 2024-02-09
# 8.2 percent is done
# 2100
# retrieving 2024-02-10
# 9.2 percent is done
# 2100
# retrieving 2024-02-11
# 10.2 percent is done
# 2100
# retrieving 2024-02-12
# 11.2 percent is done
# 2400
# retrieving 2024-02-13
# 12.2 percent is done
# 2700
# retrieving 2024-02-14
# 13.2 percent is done
# 3000
# retrieving 2024-02-15
# 14.2 percent is done
# 3300
# retrieving 2024-02-16
# 15.2 percent is done
# 3600
# retrieving 2024-02-17
# 16.2 percent is done
# 3600
# retrieving 2024-02-18
# 17.2 percent is done
# 3600
# retrieving 2024-02-20
# 18.2 percent is done
# 3900
# retrieving 2024-02-21
# 19.2 percent is done
# 4200
# retrieving 2024-02-22
# 20.2 percent is done
# 4500
# retrieving 2024-02-23
# 21.2 percent is done
# 4800
# retrieving 2024-02-24
# 22.2 percent is done
# 4800
# retrieving 2024-02-25
# 23.2 percent is done
# 4800
# retrieving 2024-02-26
# 24.2 percent is done
# 5100
# retrieving 2024-02-27
# 25.2 percent is done
# 5400
# retrieving 2024-02-28
# 26.2 percent is done
# 5700
# retrieving 2024-02-29
# 27.2 percent is done
# 6000
# retrieving 2024-03-01
# 28.2 percent is done
# 6300
# retrieving 2024-03-02
# 29.2 percent is done
# 6300
# retrieving 2024-03-03
# 30.2 percent is done
# 6300
# retrieving 2024-03-04
# 31.2 percent is done
# 6600
# retrieving 2024-03-05
# 32.2 percent is done
# 6900
# retrieving 2024-03-06
# 33.2 percent is done
# 7200
# retrieving 2024-03-07
# 34.2 percent is done
# 7500
# retrieving 2024-03-08
# 35.2 percent is done
# 7800
# retrieving 2024-03-09
# 36.2 percent is done
# 7800
# retrieving 2024-03-10
# 37.2 percent is done
# 7800
# retrieving 2024-03-11
# 38.2 percent is done
# 8100
# retrieving 2024-03-12
# 39.2 percent is done
# 8400
# retrieving 2024-03-13
# 40.2 percent is done
# 8700
# retrieving 2024-03-14
# 41.2 percent is done
# 9000
# retrieving 2024-03-15
# 42.2 percent is done
# 9300
# retrieving 2024-03-16
# 43.2 percent is done
# 9300
# retrieving 2024-03-17
# 44.2 percent is done
# 9300
# retrieving 2024-03-18
# 45.2 percent is done
# 9600
# retrieving 2024-03-19
# 46.2 percent is done
# 9900
# retrieving 2024-03-20
# 47.2 percent is done
# 10200
# retrieving 2024-03-21
# 48.2 percent is done
# 10500
# retrieving 2024-03-22
# 49.2 percent is done
# 10800
# retrieving 2024-03-23
# 50.2 percent is done
# 10800
# retrieving 2024-03-24
# 51.2 percent is done
# 10800
# retrieving 2024-03-25
# 52.2 percent is done
# 11100
# retrieving 2024-03-26
# 53.2 percent is done
# 11400
# retrieving 2024-03-27
# 54.2 percent is done
# 11700
# retrieving 2024-03-28
# 55.2 percent is done
# 12000
# retrieving 2024-03-30
# 56.2 percent is done
# 12000
# retrieving 2024-03-31
# 57.2 percent is done
# 12000
# retrieving 2024-04-01
# 58.2 percent is done
# 12300
# retrieving 2024-04-02
# 59.2 percent is done
# 12600
# retrieving 2024-04-03
# 60.2 percent is done
# 12900
# retrieving 2024-04-04
# 61.2 percent is done
# 13200
# retrieving 2024-04-05
# 62.2 percent is done
# 13500
# retrieving 2024-04-06
# 63.2 percent is done
# 13500
# retrieving 2024-04-07
# 64.2 percent is done
# 13500
# retrieving 2024-04-08
# 65.2 percent is done
# 13800
# retrieving 2024-04-09
# 66.2 percent is done
# 14100
# retrieving 2024-04-10
# 67.2 percent is done
# 14400
# retrieving 2024-04-11
# 68.2 percent is done
# 14700
# retrieving 2024-04-12
# 69.2 percent is done
# 15000
# retrieving 2024-04-13
# 70.2 percent is done
# 15000
# retrieving 2024-04-14
# 71.2 percent is done
# 15000
# retrieving 2024-04-15
# 72.2 percent is done
# 15300
# retrieving 2024-04-16
# 73.2 percent is done
# 15600
# retrieving 2024-04-17
# 74.2 percent is done
# 15900
# retrieving 2024-04-18
# 75.2 percent is done
# 16200
# retrieving 2024-04-19
# 76.2 percent is done
# 16500
# retrieving 2024-04-20
# 77.2 percent is done
# 16500
# retrieving 2024-04-21
# 78.2 percent is done
# 16500
# retrieving 2024-04-22
# 79.2 percent is done
# 16800
# retrieving 2024-04-23
# 80.2 percent is done
# 17100
# retrieving 2024-04-24
# 81.2 percent is done
# 17400
# retrieving 2024-04-25
# 82.2 percent is done
# 17700
# retrieving 2024-04-26
# 83.2 percent is done
# 18000
# retrieving 2024-04-27
# 84.2 percent is done
# 18000
# retrieving 2024-04-28
# 85.2 percent is done
# 18000
# retrieving 2024-04-29
# 86.2 percent is done
# 18300
# retrieving 2024-04-30
# 87.2 percent is done
# 18600
# retrieving 2024-05-01
# 88.2 percent is done
# 18900
# retrieving 2024-05-02
# 89.2 percent is done
# 19200
# retrieving 2024-05-03
# 90.2 percent is done
# 19500
# retrieving 2024-05-04
# 91.2 percent is done
# 19500
# retrieving 2024-05-05
# 92.2 percent is done
# 19500
# retrieving 2024-05-06
# 93.2 percent is done
# 19800
# retrieving 2024-05-07
# 94.2 percent is done
# 20100
# retrieving 2024-05-08
# 95.2 percent is done
# 20400
# retrieving 2024-05-09
# 96.2 percent is done
# 20700
# retrieving 2024-05-10
# 97.2 percent is done
# 21000
# retrieving 2024-05-11
# 98.2 percent is done
# 21000
# retrieving 2024-05-12
# 99.2 percent is done
# 21000
# retrieving 2024-05-13
# 100.2 percent is done
# 21300
# retrieving 2024-05-14
# 101.2 percent is done
# 21600
# retrieving 2024-05-15
# 102.2 percent is done
# 21900
# retrieving 2024-05-16
# 103.2 percent is done
# 22200
# retrieving 2024-05-17
# 104.2 percent is done
# 22500
# retrieving 2024-05-18
# 105.2 percent is done
# 22500
# retrieving 2024-05-19
# 106.2 percent is done
# 22500
# retrieving 2024-05-20
# 107.2 percent is done
# 22800
# retrieving 2024-05-21
# 108.2 percent is done
# 23100
# retrieving 2024-05-22
# 109.2 percent is done
# 23400
# retrieving 2024-05-23
# 110.2 percent is done
# 23700
# retrieving 2024-05-24
# 111.2 percent is done
# 24000
# retrieving 2024-05-25
# 112.2 percent is done
# 24000
# retrieving 2024-05-26
# 113.2 percent is done
# 24000
# retrieving 2024-05-28
# 114.2 percent is done
# 24300
# retrieving 2024-05-29
# 115.2 percent is done
# 24600
# retrieving 2024-05-30
# 116.2 percent is done
# 24900
# retrieving 2024-05-31
# 117.2 percent is done
# 25200
# retrieving 2024-06-01
# 118.2 percent is done
# 25200
# retrieving 2024-06-02
# 119.2 percent is done
# 25200
# retrieving 2024-06-03
# 120.2 percent is done
# 25500
# retrieving 2024-06-04
# 121.2 percent is done
# 25800
# retrieving 2024-06-05
# 122.2 percent is done
# 26100
# retrieving 2024-06-06
# 123.2 percent is done
# 26400
# retrieving 2024-06-07
# 124.2 percent is done
# 26700
# retrieving 2024-06-08
# 125.2 percent is done
# 26700
# retrieving 2024-06-09
# 126.2 percent is done
# 26700
# retrieving 2024-06-10
# 127.2 percent is done
# 27000
# retrieving 2024-06-11
# 128.2 percent is done
# 27300
# retrieving 2024-06-12
# 129.2 percent is done
# 27600
# retrieving 2024-06-13
# 130.2 percent is done
# 27900
# retrieving 2024-06-14
# 131.2 percent is done
# 28200
# retrieving 2024-06-15
# 132.2 percent is done
# 28200
# retrieving 2024-06-16
# 133.2 percent is done
# 28200
# retrieving 2024-06-17
# 134.2 percent is done
# 28500
# retrieving 2024-06-18
# 135.2 percent is done
# 28800
# retrieving 2024-06-20
# 136.2 percent is done
# 29100
# retrieving 2024-06-21
# 137.2 percent is done
# 29400
# retrieving 2024-06-22
# 138.2 percent is done
# 29400
# retrieving 2024-06-23
# 139.2 percent is done
# 29400
# retrieving 2024-06-24
# 140.2 percent is done
# 29700
# retrieving 2024-06-25
# 141.2 percent is done
# 30000
# retrieving 2024-06-26
# 142.2 percent is done
# 30300
# retrieving 2024-06-27
# 143.2 percent is done
# 30600
# ...
# 5850
# retrieving 2024-05-06
# 93.2 percent is done
# 5940
# retrieving 2024-05-07
# 94.2 percent is done
# 6030
# retrieving 2024-05-08
# 95.2 percent is done
# 6120
# retrieving 2024-05-09
# 96.2 percent is done
# 6210
# retrieving 2024-05-10
# 97.2 percent is done
# 6300
# retrieving 2024-05-11
# 98.2 percent is done
# 6300
# retrieving 2024-05-12
# 99.2 percent is done
# 6300
# retrieving 2024-05-13
# 100.2 percent is done
# 6390
# retrieving 2024-05-14
# 101.2 percent is done
# 6480
# retrieving 2024-05-15
# 102.2 percent is done
# 6570
# retrieving 2024-05-16
# 103.2 percent is done
# 6660
# retrieving 2024-05-17
# 104.2 percent is done
# 6750
# retrieving 2024-05-18
# 105.2 percent is done
# 6750
# retrieving 2024-05-19
# 106.2 percent is done
# 6750
# retrieving 2024-05-20
# 107.2 percent is done
# 6840
# retrieving 2024-05-21
# 108.2 percent is done
# 6930
# retrieving 2024-05-22
# 109.2 percent is done
# 7020
# retrieving 2024-05-23
# 110.2 percent is done
# 7110
# retrieving 2024-05-24
# 111.2 percent is done
# 7200
# retrieving 2024-05-25
# 112.2 percent is done
# 7200
# retrieving 2024-05-26
# 113.2 percent is done
# 7200
# retrieving 2024-05-28
# 114.2 percent is done
# 7290
# retrieving 2024-05-29
# 115.2 percent is done
# 7380
# retrieving 2024-05-30
# 116.2 percent is done
# 7470
# retrieving 2024-05-31
# 117.2 percent is done
# 7560
# retrieving 2024-06-01
# 118.2 percent is done
# 7560
# retrieving 2024-06-02
# 119.2 percent is done
# 7560
# retrieving 2024-06-03
# 120.2 percent is done
# 7650
# retrieving 2024-06-04
# 121.2 percent is done
# 7740
# retrieving 2024-06-05
# 122.2 percent is done
# 7830
# retrieving 2024-06-06
# 123.2 percent is done
# 7920
# retrieving 2024-06-07
# 124.2 percent is done
# 8010
# retrieving 2024-06-08
# 125.2 percent is done
# 8010
# retrieving 2024-06-09
# 126.2 percent is done
# 8010
# retrieving 2024-06-10
# 127.2 percent is done
# 8100
# retrieving 2024-06-11
# 128.2 percent is done
# 8190
# retrieving 2024-06-12
# 129.2 percent is done
# 8280
# retrieving 2024-06-13
# 130.2 percent is done
# 8370
# retrieving 2024-06-14
# 131.2 percent is done
# 8460
# retrieving 2024-06-15
# 132.2 percent is done
# 8460
# retrieving 2024-06-16
# 133.2 percent is done
# 8460
# retrieving 2024-06-17
# 134.2 percent is done
# 8550
# retrieving 2024-06-18
# 135.2 percent is done
# 8640
# retrieving 2024-06-20
# 136.2 percent is done
# 8730
# retrieving 2024-06-21
# 137.2 percent is done
# 8820
# retrieving 2024-06-22
# 138.2 percent is done
# 8820
# retrieving 2024-06-23
# 139.2 percent is done
# 8820
# retrieving 2024-06-24
# 140.2 percent is done
# 8910
# retrieving 2024-06-25
# 141.2 percent is done
# 9000
# retrieving 2024-06-26
# 142.2 percent is done
# 9090
# retrieving 2024-06-27
# 143.2 percent is done
# 9180
# retrieving 2024-06-28
# 144.2 percent is done
# 9270
# retrieving 2024-06-29
# 145.2 percent is done
# 9270
# retrieving 2024-06-30
# 146.2 percent is done
# 9270
# retrieving 2024-07-01
# 147.2 percent is done
# 9360
# retrieving 2024-07-02
# 148.2 percent is done
# 9450
# retrieving 2024-07-03
# 149.2 percent is done
# 9450
# retrieving 2024-07-05
# 150.2 percent is done
# 9540
# retrieving 2024-07-06
# 151.2 percent is done
# 9540
# retrieving 2024-07-07
# 152.2 percent is done
# 9540
# retrieving 2024-07-08
# 153.2 percent is done
# 9630
# retrieving 2024-07-09
# 154.2 percent is done
# 9720
# retrieving 2024-07-10
# 155.2 percent is done
# 9810
# retrieving 2024-07-11
# 156.2 percent is done
# 9900
# retrieving 2024-07-12
# 157.2 percent is done
# 9990
# retrieving 2024-07-13
# 158.2 percent is done
# 9990
# retrieving 2024-07-14
# 159.2 percent is done
# 9990
# retrieving 2024-07-15
# 160.2 percent is done
# 10080
# retrieving 2024-07-16
# 161.2 percent is done
# 10170
# retrieving 2024-07-17
# 162.2 percent is done
# 10260
# retrieving 2024-07-18
# 163.2 percent is done
# 10350
# retrieving 2024-07-19
# 164.2 percent is done
# 10440
# retrieving 2024-07-20
# 165.2 percent is done
# 10440
# retrieving 2024-07-21
# 166.2 percent is done
# 10440
# retrieving 2024-07-22
# 167.2 percent is done
# 10530
# retrieving 2024-07-23
# 168.2 percent is done
# 10620
# retrieving 2024-07-24
# 169.2 percent is done
# 10710
# retrieving 2024-07-25
# 170.2 percent is done
# 10800
# retrieving 2024-07-26
# 171.2 percent is done
# 10890
# retrieving 2024-07-27
# 172.2 percent is done
# 10890
# retrieving 2024-07-28
# 173.2 percent is done
# 10890
# retrieving 2024-07-29
# 174.2 percent is done
# 10980
# retrieving 2024-07-30
# 175.2 percent is done
# 11070
# retrieving 2024-07-31
# 176.2 percent is done
# 11160
# retrieving 2024-08-01
# 177.2 percent is done
# 11250
# retrieving 2024-08-02
# 178.2 percent is done
# 11340
# retrieving 2024-08-03
# 179.2 percent is done
# 11340
# retrieving 2024-08-04
# 180.2 percent is done
# 11340
# retrieving 2024-08-05
# 181.2 percent is done
# 11430
# retrieving 2024-08-06
# 182.2 percent is done
# 11520
# retrieving 2024-08-07
# 183.2 percent is done
# 11610
# retrieving 2024-08-08
# 184.2 percent is done
# 11700
# retrieving 2024-08-09
# 185.2 percent is done
# 11790
# retrieving 2024-08-10
# 186.2 percent is done
# 11790
# retrieving 2024-08-11
# 187.2 percent is done
# 11790
# retrieving 2024-08-12
# 188.2 percent is done
# 11880
# retrieving 2024-08-13
# 189.2 percent is done
# 11970
# retrieving 2024-08-14
# 190.2 percent is done
# 12060
# retrieving 2024-08-15
# 191.2 percent is done
# 12150
# retrieving 2024-08-16
# 192.2 percent is done
# 12240
# retrieving 2024-08-17
# 193.2 percent is done
# 12240
# retrieving 2024-08-18
# 194.2 percent is done
# 12240
# retrieving 2024-08-19
# 195.2 percent is done
# 12330
# retrieving 2024-08-20
# 196.2 percent is done
# 12420
# retrieving 2024-08-21
# 197.2 percent is done
# 12510
# retrieving 2024-08-22
# 198.2 percent is done
# 12600
# retrieving 2024-08-23
# 199.2 percent is done
# 12690
# retrieving 2024-08-24
# 200.2 percent is done
# 12690
# retrieving 2024-08-25
# 201.2 percent is done
# 12690
# retrieving 2024-08-26
# 202.2 percent is done
# 12780
# retrieving 2024-08-27
# 203.2 percent is done
# 12870
# retrieving 2024-08-28
# 204.2 percent is done
# 12960
# retrieving 2024-08-29
# 205.2 percent is done
# 13050
# retrieving 2024-08-30
# 206.2 percent is done
# 13140
# retrieving 2024-08-31
# 207.2 percent is done
# 13140
# retrieving 2024-09-01
# 208.2 percent is done
# 13140
# retrieving 2024-09-03
# 209.2 percent is done
# 13230
# retrieving 2024-09-04
# 210.2 percent is done
# 13320
# retrieving 2024-09-05
# 211.2 percent is done
# 13410
# retrieving 2024-09-06
# 212.2 percent is done
# 13500
# retrieving 2024-09-07
# 213.2 percent is done
# 13500
# retrieving 2024-09-08
# 214.2 percent is done
# 13500
# retrieving 2024-09-09
# 215.2 percent is done
# 13590
# retrieving 2024-09-10
# 216.2 percent is done
# 13680
# retrieving 2024-09-11
# 217.2 percent is done
# 13770
# retrieving 2024-09-12
# 218.2 percent is done
# 13860
# retrieving 2024-09-13
# 219.2 percent is done
# 13950
# retrieving 2024-09-14
# 220.2 percent is done
# 13950
# retrieving 2024-09-15
# 221.2 percent is done
# 13950
# retrieving 2024-09-16
# 222.2 percent is done
# 14040
# retrieving 2024-09-17
# 223.2 percent is done
# 14130
# retrieving 2024-09-18
# 224.2 percent is done
# 14220
# retrieving 2024-09-19
# 225.2 percent is done
# 14310
# retrieving 2024-09-20
# 226.2 percent is done
# 14400
# retrieving 2024-09-21
# 227.2 percent is done
# 14400
# retrieving 2024-09-22
# 228.2 percent is done
# 14400
# retrieving 2024-09-23
# 229.2 percent is done
# 14490
# retrieving 2024-09-24
# 230.2 percent is done
# 14580
# retrieving 2024-09-25
# 231.2 percent is done
# 14670
# retrieving 2024-09-26
# 232.2 percent is done
# 14760
# retrieving 2024-09-27
# 233.2 percent is done
# 14850
# retrieving 2024-09-28
# 234.2 percent is done
# 14850
# retrieving 2024-09-29
# 235.2 percent is done
# 14850
# retrieving 2024-09-30
# 236.2 percent is done
# 14940
# retrieving 2024-10-01
# 237.2 percent is done
# 15030
# retrieving 2024-10-02
# 238.2 percent is done
# 15120
# retrieving 2024-10-03
# 239.2 percent is done
# 15210
# retrieving 2024-10-04
# 240.2 percent is done
# 15300
# retrieving 2024-10-05
# 241.2 percent is done
# 15300
# retrieving 2024-10-06
# 242.2 percent is done
# 15300
# retrieving 2024-10-07
# 243.2 percent is done
# 15390
# retrieving 2024-10-08
# 244.2 percent is done
# 15480
# retrieving 2024-10-09
# 245.2 percent is done
# 15570
# retrieving 2024-10-10
# 246.2 percent is done
# 15660
# retrieving 2024-10-11
# 247.2 percent is done
# 15750
# retrieving 2024-10-12
# 248.2 percent is done
# 15750
# retrieving 2024-10-13
# 249.2 percent is done
# 15750
# retrieving 2024-10-14
# 250.2 percent is done
# 15840
# retrieving 2024-10-15
# 251.2 percent is done
# 15930
# retrieving 2024-10-16
# 252.2 percent is done
# 16020
# retrieving 2024-10-17
# 253.2 percent is done
# 16110
# retrieving 2024-10-18
# 254.2 percent is done
# 16200
# retrieving 2024-10-19
# 255.2 percent is done
# 16200
# retrieving 2024-10-20
# 256.2 percent is done
# 16200
# retrieving 2024-10-21
# 257.2 percent is done
# 16290
# retrieving 2024-10-22
# 258.2 percent is done
# 16380
# retrieving 2024-10-23
# 259.2 percent is done
# 16470
# retrieving 2024-10-24
# 260.2 percent is done
# 16560
# retrieving 2024-10-25
# 261.2 percent is done
# 16650
# retrieving 2024-10-26
# 262.2 percent is done
# 16650
# retrieving 2024-10-27
# 263.2 percent is done
# 16650
# retrieving 2024-10-28
# 264.2 percent is done
# 16740
# retrieving 2024-10-29
# 265.2 percent is done
# 16830
# retrieving 2024-10-30
# 266.2 percent is done
# 16920
# retrieving 2024-10-31
# 267.2 percent is done
# 17010
# retrieving 2024-11-01
# 268.2 percent is done
# 17100
# retrieving 2024-11-02
# 269.2 percent is done
# 17100
# retrieving 2024-11-03
# 270.2 percent is done
# 17100
# retrieving 2024-11-04
# 271.2 percent is done
# 17190
# retrieving 2024-11-05
# 272.2 percent is done
# 17280
# retrieving 2024-11-06
# 273.2 percent is done
# 17370
# retrieving 2024-11-07
# 274.2 percent is done
# 17460
# retrieving 2024-11-08
# 275.2 percent is done
# 17550
# retrieving 2024-11-09
# 276.2 percent is done
# 17550
# retrieving 2024-11-10
# 277.2 percent is done
# 17550
# retrieving 2024-11-11
# 278.2 percent is done
# 17640
# retrieving 2024-11-12
# 279.2 percent is done
# 17730
# retrieving 2024-11-13
# 280.2 percent is done
# 17820
# retrieving 2024-11-14
# 281.2 percent is done
# 17910
# retrieving 2024-11-15
# 282.2 percent is done
# 18000
# retrieving 2024-11-16
# 283.2 percent is done
# 18000
# retrieving 2024-11-17
# 284.2 percent is done
# 18000
# retrieving 2024-11-18
# 285.2 percent is done
# 18090
# retrieving 2024-11-19
# 286.2 percent is done
# 18180
# retrieving 2024-11-20
# 287.2 percent is done
# 18270
# retrieving 2024-11-21
# 288.2 percent is done
# 18360
# retrieving 2024-11-22
# 289.2 percent is done
# 18450
# retrieving 2024-11-23
# 290.2 percent is done
# 18450
# retrieving 2024-11-24
# 291.2 percent is done
# 18450
# retrieving 2024-11-25
# 292.2 percent is done
# 18540
# retrieving 2024-11-26
# 293.2 percent is done
# 18630
# retrieving 2024-11-27
# 294.2 percent is done
# 18720
# retrieving 2024-11-30
# 295.2 percent is done
# 18720
# retrieving 2024-12-01
# 296.2 percent is done
# 18720
# retrieving 2024-12-02
# 297.2 percent is done
# 18810
# retrieving 2024-12-03
# 298.2 percent is done
# 18900
# retrieving 2024-12-04
# 299.2 percent is done
# 18990
# retrieving 2024-12-05
# 300.2 percent is done
# 19080
# retrieving 2024-12-06
# 301.2 percent is done
# 19170
# retrieving 2024-12-07
# 302.2 percent is done
# 19170
# retrieving 2024-12-08
# 303.2 percent is done
# 19170
# retrieving 2024-12-09
# 304.2 percent is done
# 19260
# retrieving 2024-12-10
# 305.2 percent is done
# 19350
# retrieving 2024-12-11
# 306.2 percent is done
# 19440
# retrieving 2024-12-12
# 307.2 percent is done
# 19530
# retrieving 2024-12-13
# 308.2 percent is done
# 19620
# retrieving 2024-12-14
# 309.2 percent is done
# 19620
# retrieving 2024-12-15
# 310.2 percent is done
# 19620
# retrieving 2024-12-16
# 311.2 percent is done
# 19710
# retrieving 2024-12-17
# 312.2 percent is done
# 19800
# retrieving 2024-12-18
# 313.2 percent is done
# 19890
# retrieving 2024-12-19
# 314.2 percent is done
# 19980
# retrieving 2024-12-20
# 315.2 percent is done
# 20070
# retrieving 2024-12-21
# 316.2 percent is done
# 20070
# retrieving 2024-12-22
# 317.2 percent is done
# 20070
# retrieving 2024-12-23
# 318.2 percent is done
# 20160
# retrieving 2024-12-24
# 319.2 percent is done
# 20160
# retrieving 2024-12-26
# 320.2 percent is done
# 20250
# retrieving 2024-12-27
# 321.2 percent is done
# 20340
# retrieving 2024-12-28
# 322.2 percent is done
# 20340
# retrieving 2024-12-29
# 323.2 percent is done
# 20340
# retrieving 2024-12-30
# 324.2 percent is done
# 20430
# retrieving 2024-12-31
# 325.2 percent is done
# 20520
# retrieving 2025-01-02
# 326.2 percent is done
# 20610
# retrieving 2025-01-03
# 327.2 percent is done
# 20700
# retrieving 2025-01-04
# 328.2 percent is done
# 20700
# retrieving 2025-01-05
# 329.2 percent is done
# 20700
# retrieving 2025-01-06
# 330.2 percent is done
# 20790
# retrieving 2025-01-07
# 331.2 percent is done
# 20880
# retrieving 2025-01-08
# 332.2 percent is done
# 20880
# retrieving 2025-01-09
# 333.2 percent is done
# 20880
# retrieving 2025-01-10
# 334.2 percent is done
# 20970
# retrieving 2025-01-11
# 335.2 percent is done
# 20970
# retrieving 2025-01-12
# 336.2 percent is done
# 20970
# retrieving 2025-01-13
# 337.2 percent is done
# 21060
# retrieving 2025-01-14
# 338.2 percent is done
# 21150
# retrieving 2025-01-15
# 339.2 percent is done
# 21240
# retrieving 2025-01-16
# 340.2 percent is done
# 21330
# retrieving 2025-01-17
# 341.2 percent is done
# 21420
# retrieving 2025-01-18
# 342.2 percent is done
# 21420
# retrieving 2025-01-19
# 343.2 percent is done
# 21420
# retrieving 2025-01-21
# 344.2 percent is done
# 21510
# retrieving 2025-01-22
# 345.2 percent is done
# 21600
# retrieving 2025-01-23
# 346.2 percent is done
# 21690
# retrieving 2025-01-24
# 347.2 percent is done
# 21780
# retrieving 2025-01-25
# 348.2 percent is done
# 21780
# retrieving 2025-01-26
# 349.2 percent is done
# 21780
# retrieving 2025-01-27
# 350.2 percent is done
# 21870
# retrieving 2025-01-28
# 351.2 percent is done
# 21960
# retrieving 2025-01-29
# 352.2 percent is done
# 22050
# retrieving 2025-01-30
# 353.2 percent is done
# 22140
# retrieving 2025-01-31
# 354.2 percent is done
# 22230
# retrieving 2025-02-01
# 355.2 percent is done
# 22230
# retrieving 2025-02-02
# 356.2 percent is done
# 22230
# retrieving 2025-02-03
# 357.2 percent is done
# 22320
# retrieving 2025-02-04
# 358.2 percent is done
# 22410
# retrieving 2025-02-05
# 359.2 percent is done
# 22500
# retrieving 2025-02-06
# 360.2 percent is done
# 22590
# retrieving 2025-02-07
# 361.2 percent is done
# 22680
# retrieving 2025-02-08
# 362.2 percent is done
# 22680
# retrieving 2025-02-09
# 363.2 percent is done
# 22680
# retrieving 2025-02-10
# 364.2 percent is done
# 22770
# retrieving 2025-02-11
# 365.2 percent is done
# 22860
# retrieving 2025-02-12
# 366.2 percent is done
# 22950
# retrieving 2025-02-13
# 367.2 percent is done
# 23040
# retrieving 2025-02-14
# 368.2 percent is done
# 23130
# retrieving 2025-02-15
# 369.2 percent is done
# 23130
# retrieving 2025-02-16
# 370.2 percent is done
# 23130
# retrieving 2025-02-18
# 371.2 percent is done
# 23220
# retrieving 2025-02-19
# 372.2 percent is done
# 23310
# retrieving 2025-02-20
# 373.2 percent is done
# 23400
# retrieving 2025-02-21
# 374.2 percent is done
# 23490
# retrieving 2025-02-22
# 375.2 percent is done
# 23490
# retrieving 2025-02-23
# 376.2 percent is done
# 23490
# retrieving 2025-02-24
# 377.2 percent is done
# 23580
# retrieving 2025-02-25
# 378.2 percent is done
# 23670
# retrieving 2025-02-26
# 379.2 percent is done
# 23760
# retrieving 2025-02-27
# 380.2 percent is done
# 23850
# retrieving 2025-02-28
# 381.2 percent is done
# 23940
# retrieving 2025-03-01
# 382.2 percent is done
# 23940
# retrieving 2025-03-02
# 383.2 percent is done
# 23940
# retrieving 2025-03-03
# 384.2 percent is done
# 24030
# retrieving 2025-03-04
# 385.2 percent is done
# 24120
# retrieving 2025-03-05
# 386.2 percent is done
# 24210
# retrieving 2025-03-06
# 387.2 percent is done
# 24300
# retrieving 2025-03-07
# 388.2 percent is done
# 24390
# retrieving 2025-03-08
# 389.2 percent is done
# 24390
# retrieving 2025-03-09
# 390.2 percent is done
# 24390
# retrieving 2025-03-10
# 391.2 percent is done
# 24480
# retrieving 2025-03-11
# 392.2 percent is done
# 24570
# retrieving 2025-03-12
# 393.2 percent is done
# 24660
# retrieving 2025-03-13
# 394.2 percent is done
# 24750
# retrieving 2025-03-14
# 395.2 percent is done
# 24840
# retrieving 2025-03-15
# 396.2 percent is done
# 24840
# retrieving 2025-03-16
# 397.2 percent is done
# 24840
# retrieving 2025-03-17
# 398.2 percent is done
# 24930
# retrieving 2025-03-18
# 399.2 percent is done
# 25020
# retrieving 2025-03-19
# 400.2 percent is done
# 25110
# retrieving 2025-03-20
# 401.2 percent is done
# 25200
# retrieving 2025-03-21
# 402.2 percent is done
# 25290
# retrieving 2025-03-22
# 403.2 percent is done
# 25290
# retrieving 2025-03-23
# 404.2 percent is done
# 25290
# retrieving 2025-03-24
# 405.2 percent is done
# 25380
# retrieving 2025-03-25
# 406.2 percent is done
# 25470
# retrieving 2025-03-26
# 407.2 percent is done
# 25560
# retrieving 2025-03-27
# 408.2 percent is done
# 25650
# retrieving 2025-03-28
# 409.2 percent is done
# 25740
# retrieving 2025-03-29
# 410.2 percent is done
# 25740
# retrieving 2025-03-30
# 411.2 percent is done
# 25740
# retrieving 2025-03-31
# 412.2 percent is done
# 25830
# retrieving 2025-04-01
# 413.2 percent is done
# 0
# 1
# 2

# %%
df_group_train_tqqq
# Out:
#             Target_std  Target_spread  prior_std      prior_Vol  prior_spread  \
# Date_Only
# 2024-02-01    0.157610           0.63   0.329090  179495.303333          1.30
# 2024-02-02    0.079812           0.30   0.611902  229504.093333          2.70
# 2024-02-05    0.165655           0.65   0.410078  169410.313333          1.69
# 2024-02-06    0.162608           0.57   0.365961  168546.906667          1.92
# 2024-02-07    0.073213           0.29   0.338455  162977.396667          1.45
# ...                ...            ...        ...            ...           ...
# 2025-03-26    0.239224           0.95   0.975800  180336.183333          3.84
# 2025-03-27    0.278571           1.37   0.511152  167367.360000          2.36
# 2025-03-28    0.168169           0.68   1.230583  216589.716667          4.57
# 2025-03-31    0.284283           1.24   0.734290  228802.953333          3.40
# 2025-04-01    0.538818           1.92   0.810529  226256.846667          3.24
#
#             prior_range  cut_open  cut_1hr  cut_2hr  cut_3hr
# Date_Only
# 2024-02-01         1.29     54.12     0.21     0.48     1.06
# 2024-02-02         2.71     57.40     0.33    -0.04     0.68
# 2024-02-05         1.68     57.09     0.30     0.22     0.96
# 2024-02-06         1.92     55.96    -0.14    -0.10    -0.60
# 2024-02-07         1.45     58.33    -0.07     0.22     0.12
# ...                 ...       ...      ...      ...      ...
# 2025-03-26         3.83     63.70     0.19    -0.64    -1.32
# 2025-03-27         2.34     63.02     0.60    -0.07    -0.59
# 2025-03-28         4.56     57.51     0.24    -0.20    -1.13
# 2025-03-31         3.44     56.40     0.97     0.64     1.49
# 2025-04-01         3.25     56.90    -1.04    -1.33    -1.40
#
# [288 rows x 10 columns]

# %%
df_final_jointed_vix=pd.DataFrame()
df_final_jointed_all=pd.DataFrame()

df_group_train_vix.columns =['vix_std','vix_spread','vix_prior_std','vix_Vol', 'vix_pr_spread','vix_prior_range','vix_cut_open','vix_cut_1hr','vix_cut_2hr','vix_cut_3hr']
df_final_jointed_vix = pd.concat([df_group_train,df_group_train_vix], axis=1)
df_group_train_tqqq.columns =['tqqq_std','tqqq_spread','tqqq_prior_std','tqqq_Vol','tqqq_pr_spread','tqqq_prior_range','tqqq_cut_open','tqqq_cut_1hr','tqqq_cut_2hr','tqqq_cut_3hr']
df_final_jointed_all = pd.concat([df_final_jointed_vix,df_group_train_tqqq], axis=1)
df_final_jointed_all.drop(['vix_std','vix_Vol','tqqq_std'], axis=1, inplace=True)

# %%
df_final_jointed_all
# Out:
#             Target_std  Target_spread  prior_std      prior_Vol  prior_spread  \
# Date_Only
# 2024-02-01    0.844811           3.26   1.691430   31344.016667          6.71
# 2024-02-02    2.322338           8.01   4.712763  156749.593333         31.04
# 2024-02-05    2.048324           7.94   1.724566   68771.400000         10.29
# 2024-02-06    0.910985           3.12   2.308883   36062.643333         12.75
# 2024-02-07    0.765408           3.14   1.859712   40304.960000         13.58
# ...                ...            ...        ...            ...           ...
# 2025-03-26    1.298835           4.85   3.493051   19297.573333         15.58
# 2025-03-27    1.403355           6.24   2.809916   13900.750000         12.78
# 2025-03-28    1.229460           5.72   5.344685   21354.313333         23.49
# 2025-03-31    1.129441           4.91   5.330998   27184.223333         21.80
# 2025-04-01    2.164275           7.14   4.159379   19495.916667         18.82
#
#             prior_range  cut_open  cut_1hr  cut_2hr  cut_3hr  ...  \
# Date_Only                                                     ...
# 2024-02-01         6.67    395.19     0.09    -0.37    -0.47  ...
# 2024-02-02        31.27    478.94     2.13    -2.85     1.92  ...
# 2024-02-05        10.36    462.41     1.89    -0.45     1.97  ...
# 2024-02-06        12.71    456.89    -0.49    -0.80    -1.43  ...
# 2024-02-07        13.72    467.23    -1.60    -1.36    -0.61  ...
# ...                 ...       ...      ...      ...      ...  ...
# 2025-03-26        15.59    611.47    -0.67    -3.43    -5.52  ...
# 2025-03-27        12.78    606.49     0.99    -1.25    -4.01  ...
# 2025-03-28        23.51    578.25    -3.48    -4.16    -7.86  ...
# 2025-03-31        22.41    575.47     4.25     3.75    10.77  ...
# 2025-04-01        16.56    579.59    -5.66    -6.43    -2.55  ...
#
#             vix_cut_3hr  tqqq_spread  tqqq_prior_std       tqqq_Vol  \
# Date_Only
# 2024-02-01        -0.21         0.63        0.329090  179495.303333
# 2024-02-02        -0.11         0.30        0.611902  229504.093333
# 2024-02-05        -0.18         0.65        0.410078  169410.313333
# 2024-02-06        -0.32         0.57        0.365961  168546.906667
# 2024-02-07        -0.17         0.29        0.338455  162977.396667
# ...                 ...          ...             ...            ...
# 2025-03-26         0.45         0.95        0.975800  180336.183333
# 2025-03-27        -0.28         1.37        0.511152  167367.360000
# 2025-03-28         0.33         0.68        1.230583  216589.716667
# 2025-03-31         0.06         1.24        0.734290  228802.953333
# 2025-04-01         0.13         1.92        0.810529  226256.846667
#
#             tqqq_pr_spread  tqqq_prior_range  tqqq_cut_open  tqqq_cut_1hr  \
# Date_Only
# 2024-02-01            1.30              1.29          54.12          0.21
# 2024-02-02            2.70              2.71          57.40          0.33
# 2024-02-05            1.69              1.68          57.09          0.30
# 2024-02-06            1.92              1.92          55.96         -0.14
# 2024-02-07            1.45              1.45          58.33         -0.07
# ...                    ...               ...            ...           ...
# 2025-03-26            3.84              3.83          63.70          0.19
# 2025-03-27            2.36              2.34          63.02          0.60
# 2025-03-28            4.57              4.56          57.51          0.24
# 2025-03-31            3.40              3.44          56.40          0.97
# 2025-04-01            3.24              3.25          56.90         -1.04
#
#             tqqq_cut_2hr  tqqq_cut_3hr
# Date_Only
# 2024-02-01          0.48          1.06
# 2024-02-02         -0.04          0.68
# 2024-02-05          0.22          0.96
# 2024-02-06         -0.10         -0.60
# 2024-02-07          0.22          0.12
# ...                  ...           ...
# 2025-03-26         -0.64         -1.32
# 2025-03-27         -0.07         -0.59
# 2025-03-28         -0.20         -1.13
# 2025-03-31          0.64          1.49
# 2025-04-01         -1.33         -1.40
#
# [288 rows x 27 columns]

# %%
df_final_jointed_all.columns
# Out:
# Index(['Target_std', 'Target_spread', 'prior_std', 'prior_Vol', 'prior_spread',
#        'prior_range', 'cut_open', 'cut_1hr', 'cut_2hr', 'cut_3hr',
#        'vix_spread', 'vix_prior_std', 'vix_pr_spread', 'vix_prior_range',
#        'vix_cut_open', 'vix_cut_1hr', 'vix_cut_2hr', 'vix_cut_3hr',
#        'tqqq_spread', 'tqqq_prior_std', 'tqqq_Vol', 'tqqq_pr_spread',
#        'tqqq_prior_range', 'tqqq_cut_open', 'tqqq_cut_1hr', 'tqqq_cut_2hr',
#        'tqqq_cut_3hr'],
#       dtype='object')

# %%
df_final_jointed_all.drop(['vix_spread','tqqq_spread'], axis=1, inplace =True)

# %%
df_final_jointed_all.columns
# Out:
# Index(['Target_std', 'Target_spread', 'prior_std', 'prior_Vol', 'prior_spread',
#        'prior_range', 'cut_open', 'cut_1hr', 'cut_2hr', 'cut_3hr',
#        'vix_prior_std', 'vix_pr_spread', 'vix_prior_range', 'vix_cut_open',
#        'vix_cut_1hr', 'vix_cut_2hr', 'vix_cut_3hr', 'tqqq_prior_std',
#        'tqqq_Vol', 'tqqq_pr_spread', 'tqqq_prior_range', 'tqqq_cut_open',
#        'tqqq_cut_1hr', 'tqqq_cut_2hr', 'tqqq_cut_3hr'],
#       dtype='object')

# %%
df_final_jointed_all.to_pickle('dev_df_final_jointed_all_train_beta.pkl')
